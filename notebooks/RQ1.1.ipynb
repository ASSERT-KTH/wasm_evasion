# %% [markdown]
# ## Some transformations help the classfiers
#
# In this notebook we do some analyses on why and how this is possible

# %% [markdown]
# ## Check the binaries that can be reproduced

# %% [markdown]
# Out of 33 binaries, which one we could reproduce. Then, we could check performance or differences in general.

# %%
# !pip3 install jsonschema2md
# Out:
# ...
# WARNING: You are using pip version 20.2.3; however, version 22.2.2 is available.
# You should consider upgrading via the '/Users/javierca/.pyenv/versions/3.9.4/bin/python3.9 -m pip install --upgrade pip' command.

# %% [markdown]
# ## Files
#
# # SEISMIC
#
# - 0d99646229ea6010fa510333161653955eadb11acdb51c6cc886d1108e2fc626.wasm
#
#   ### Meta from wasmbench
#
#   ```json
#   "files": [
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/WasmRay/wasmray.github.io/Data/SampleWasmFiles/0aba70602588d085.ok.wasm",
#                 "filename": "0aba70602588d085.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "WasmRay/wasmray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             },
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/wenhao1006/SEISMIC/CryptoNight/worker.wasm",
#                 "filename": "worker.wasm",
#                 "collection_method": "github",
#                 "repository": "wenhao1006/SEISMIC",
#                 "sibling_extensions": [],
#                 "stars": 2
#             },
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/wenhao1006/SEISMIC/CoinHive/64-bit/worker.wasm",
#                 "filename": "worker.wasm",
#                 "collection_method": "github",
#                 "repository": "wenhao1006/SEISMIC",
#                 "sibling_extensions": [],
#                 "stars": 2
#             },
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/wenhao1006/SEISMIC/CoinHive/32-bit/worker.wasm",
#                 "filename": "worker.wasm",
#                 "collection_method": "github",
#                 "repository": "wenhao1006/SEISMIC",
#                 "sibling_extensions": [
#                     "js",
#                     "wat"
#                 ],
#                 "stars": 2
#             },
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/miner-ray/miner-ray.github.io/Data/SampleWasmFiles/0aba70602588d085.ok.wasm",
#                 "filename": "0aba70602588d085.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "miner-ray/miner-ray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             }
#         ],
#         "size_bytes": 70972,
#         "wasm_validate": true,
#         "wasm_extensions": null,
#         "custom_sections": [
#             "name"
#         ],
#         "wasm_validate_no_extensions": true,
#         "producers": null,
#         "instruction_count": 30531
#     },
#   ```
#
#   This is taken from SEISMIC
#
#   - **Source**: GITHUB
#   - **SEISMIC paper**: https://personal.utdallas.edu/~hamlen/wang18esorics.pdf
#   - **Status**: 'Conhive site is dead' since ~2020. The domain was obtained by Troy Hunt and his team. They replaced the original coinhive js. The new .../coinhive.js is now an script that executes on your browser and let you know that before they bought the domain, that site tried to mine in your pc. However according to Avast, https://blog.avast.com/coinhive-shuts-down "Security companies blocking web-based cryptojacking might be one of many reasons why cryptojacking is on a decline" "A possible rise in Monero’s value could cause cybercriminals to mine more again, but they would likely do this using PCs"
#   - **Reproduction:** It can be repdoruced from https://github.com/wenhao1006/SEISMIC/tree/master/CoinHive/32-bit. However this is a version of 2019
#
#
# - 4cbdbbb1bc6880ecff2f1bc6cb66444b319cc57cf47e8a35f956c36f5bec2bbb.wasm
#   ### Meta from wasmbench
#
#
# ```json
# "4cbdbbb1bc6880ecff2f1bc6cb66444b319cc57cf47e8a35f956c36f5bec2bbb": {
#         "files": [
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/wenhao1006/SEISMIC/NFWebMiner/webminer_v1.wasm",
#                 "filename": "webminer_v1.wasm",
#                 "collection_method": "github",
#                 "repository": "wenhao1006/SEISMIC",
#                 "sibling_extensions": [],
#                 "stars": 2
#             }
#         ],
#         "size_bytes": 104666,
#         "wasm_validate": true,
#         "wasm_extensions": null,
#         "custom_sections": [
#             "name",
#             "sourceMappingURL"
#         ],
#         "wasm_validate_no_extensions": true,
#         "producers": null,
#         "instruction_count": 47916
#     },
# ```
#
#
#   This is taken from SEISMIC
#
#   - **Source**: GITHUB
#   - **SEISMIC paper**: https://personal.utdallas.edu/~hamlen/wang18esorics.pdf
#   - **Status**:  TODO
#   - **Reproduction:** It can be repdoruced from https://github.com/wenhao1006/SEISMIC/tree/master/NFWebMiner
#
# - aafff58765c917b0900726ecca11c715c38c3c25b1be9e0af130e0f5b170c14e.wasm
#   ### Meta from wasmbench
#
#
#   ```json
#
#     "aafff58765c917b0900726ecca11c715c38c3c25b1be9e0af130e0f5b170c14e": {
#         "files": [
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/wenhao1006/SEISMIC/CoinHive/64-bit/cryptonight_obfuscated.wasm",
#                 "filename": "cryptonight_obfuscated.wasm",
#                 "collection_method": "github",
#                 "repository": "wenhao1006/SEISMIC",
#                 "sibling_extensions": [],
#                 "stars": 2
#             }
#         ],
#         "size_bytes": 97551,
#         "wasm_validate": true,
#         "wasm_extensions": null,
#         "custom_sections": [],
#         "wasm_validate_no_extensions": true,
#         "producers": null,
#         "instruction_count": 47033
#     },
#   ```
#
#
#   This is taken from SEISMIC
#
#   - **Source**: GITHUB
#   - **SEISMIC paper**: https://personal.utdallas.edu/~hamlen/wang18esorics.pdf
#   - **Status**:  This form part of the coinhive and cryptonight. The crypto is composed by two files in this case, the worker and the actual miner.
#   - **Reproduction:** It is the same as reproducing the first entry
#
#
#
# - 47d299593572faf8941351f3ef8e46bc18eb684f679d87f9194bb635dd8aabc0.wasm
#   ### Meta from wasmbench
#
#   ```json
# "47d299593572faf8941351f3ef8e46bc18eb684f679d87f9194bb635dd8aabc0": {
#         "files": [
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/davbo/yara-rs/sample-miners/nightcrypto.wasm",
#                 "filename": "nightcrypto.wasm",
#                 "collection_method": "github",
#                 "repository": "davbo/yara-rs",
#                 "sibling_extensions": [],
#                 "stars": 2
#             },
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/pventuzelo/wasm_workshop/cryptonight/cryptonight.wasm",
#                 "filename": "cryptonight.wasm",
#                 "collection_method": "github",
#                 "repository": "pventuzelo/wasm_workshop",
#                 "sibling_extensions": [],
#                 "stars": 11
#             },
#             {
#                 "absolute_path": "wasm-study/web/own-crawler/tranco/network/maquinas.com/793-maquinas_com_cn_47d299593572faf8.wasm",
#                 "filename": "793-maquinas_com_cn_47d299593572faf8.wasm",
#                 "collection_method": "web/own-crawler",
#                 "seed_list": "tranco",
#                 "wasm_detection": "network",
#                 "domain": "maquinas.com",
#                 "sibling_extensions": []
#             }
#         ],
#         "size_bytes": 68796,
#         "wasm_validate": true,
#         "wasm_extensions": null,
#         "custom_sections": [],
#         "wasm_validate_no_extensions": true,
#         "producers": null,
#         "instruction_count": 30768
#     },
#   ```
#
#
# - 000415b2639c960e039299fde2a52e7e9c692c212c1fa6ca4701eec637ff6a30.wasm
#   ### Meta from wasmbench
#
#   ```json
# "000415b2639c960e039299fde2a52e7e9c692c212c1fa6ca4701eec637ff6a30": {
#         "files": [
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/wenhao1006/SEISMIC/anti-virus/worker_new_func_names.wasm",
#                 "filename": "worker_new_func_names.wasm",
#                 "collection_method": "github",
#                 "repository": "wenhao1006/SEISMIC",
#                 "sibling_extensions": [],
#                 "stars": 2
#             }
#         ],
#         "size_bytes": 62466,
#         "wasm_validate": true,
#         "wasm_extensions": null,
#         "custom_sections": [],
#         "wasm_validate_no_extensions": true,
#         "producers": null,
#         "instruction_count": 28339
#     },
#
#   ```
#
#   **Status:** This is probably a false positive
#
# - 24aae13ae29d012fdf36cacc6871640f6883f07a0d42eea40cfe277950ca16c9.wasm
#   ### Meta from wasmbench
#
#   ```json
# "24aae13ae29d012fdf36cacc6871640f6883f07a0d42eea40cfe277950ca16c9": {
#         "files": [
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/wenhao1006/SEISMIC/anti-virus/cryptonight_obfuscated.wasm",
#                 "filename": "cryptonight_obfuscated.wasm",
#                 "collection_method": "github",
#                 "repository": "wenhao1006/SEISMIC",
#                 "sibling_extensions": [],
#                 "stars": 2
#             }
#         ],
#         "size_bytes": 62458,
#         "wasm_validate": true,
#         "wasm_extensions": null,
#         "custom_sections": [],
#         "wasm_validate_no_extensions": true,
#         "producers": null,
#         "instruction_count": 28339
#     },
#   ```
#   **Status:** This is probably a false positive
#
#  # MinerRay
#
# - dc11d82d85b5745ff2c69e901b9b6b42da9e1c102ae45e856b0f23ed64de4309.wasm
#
#   ### Meta from wasmbench
#
# ```json
#
#    "files": [
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/WasmRay/wasmray.github.io/Data/SampleWasmFiles/1c976f694fb782f4.ok.wasm",
#                 "filename": "1c976f694fb782f4.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "WasmRay/wasmray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             },
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/miner-ray/miner-ray.github.io/Data/SampleWasmFiles/1c976f694fb782f4.ok.wasm",
#                 "filename": "1c976f694fb782f4.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "miner-ray/miner-ray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             }
#         ],
#         "size_bytes": 67496,
#         "wasm_validate": true,
#         "wasm_extensions": null,
#         "custom_sections": [],
#         "wasm_validate_no_extensions": true,
#         "producers": null,
#         "instruction_count": 30246
# ```
#
#   - **Source**: GITHUB
#   - **Scope**: https://github.com/miner-ray/miner-ray.github.io is a research project on preventing cryptominig. Paper at https://ieeexplore.ieee.org/document/9286112. The found binaries are part of the repo and not necesarilly exploitable
#   - **Reproduction:** The repository contains several sites for which cryptoming was detected, https://github.com/miner-ray/miner-ray.github.io/blob/master/Data/HashingSiteResultSamples.csv. TODO, read specific VT labels to see. But I could not find a way to reproduce this file for now. We need to map the files to https://github.com/miner-ray/miner-ray.github.io/blob/master/Data/sites.csv, to get the name of the binaries.
#
# - 942be4f7a78a50453f8949a0a20e1ae66a5b84a67db712fab66d3a9541087519.wasm
#
#   ### Meta from wasmbench
#  ```json
#
#    "files": [
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/WasmRay/wasmray.github.io/Data/SampleWasmFiles/81376b3ec282a00c.ok.wasm",
#                 "filename": "81376b3ec282a00c.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "WasmRay/wasmray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             },
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/miner-ray/miner-ray.github.io/Data/SampleWasmFiles/81376b3ec282a00c.ok.wasm",
#                 "filename": "81376b3ec282a00c.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "miner-ray/miner-ray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             }
#         ],
#         "size_bytes": 103520,
#         "wasm_validate": true,
#         "wasm_extensions": null,
#         "custom_sections": [],
#         "wasm_validate_no_extensions": true,
#         "producers": null,
#         "instruction_count": 46208
#     },
# ```
#
#   #### The same comments as before
#
#
#
# - 5bc5334382f650c8a7cc38d651b86db06eb755b64662eaef42c6040cf879f0ce.wasm
#   ### Meta from wasmbench
#
#  ```json
#   "files": [
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/WasmRay/wasmray.github.io/Data/SampleWasmFiles/16d527a273dc5caa.ok.wasm",
#                 "filename": "16d527a273dc5caa.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "WasmRay/wasmray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             },
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/miner-ray/miner-ray.github.io/Data/SampleWasmFiles/16d527a273dc5caa.ok.wasm",
#                 "filename": "16d527a273dc5caa.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "miner-ray/miner-ray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             }
#         ],
#         "size_bytes": 77572,
#         "wasm_validate": true,
#         "wasm_extensions": null,
#         "custom_sections": [],
#         "wasm_validate_no_extensions": true,
#         "producers": null,
#         "instruction_count": 34918
#  ```
#
#   #### The same comments as before
#
#
# - fb15929fb454d62f2dbabb306d9b73b3b1fe4526e6b4a76a7a23519273c6c519.wasm
#   ### Meta from wasmbench
#
#  ```json
#   "files": [
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/WasmRay/wasmray.github.io/Data/SampleWasmFiles/f54ff4e6d6ae042b.ok.wasm",
#                 "filename": "f54ff4e6d6ae042b.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "WasmRay/wasmray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             },
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/miner-ray/miner-ray.github.io/Data/SampleWasmFiles/f54ff4e6d6ae042b.ok.wasm",
#                 "filename": "f54ff4e6d6ae042b.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "miner-ray/miner-ray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             }
#         ],
#         "size_bytes": 77054,
#         "wasm_validate": true,
#         "wasm_extensions": null,
#         "custom_sections": [],
#         "wasm_validate_no_extensions": true,
#         "producers": null,
#         "instruction_count": 33562
#   ```
#
#    #### The same comments as before
#
#
#
# - f0b244090f9e4a9f599a68f42d7a89e003026202324cf86c6cd4a46ad8c98da8.wasm
#   ### Meta from wasmbench
#
#  ```json
#   "f0b244090f9e4a9f599a68f42d7a89e003026202324cf86c6cd4a46ad8c98da8": {
#         "files": [
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/WasmRay/wasmray.github.io/Data/SampleWasmFiles/8e61b43ddf8d78cd.ok.wasm",
#                 "filename": "8e61b43ddf8d78cd.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "WasmRay/wasmray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             },
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/miner-ray/miner-ray.github.io/Data/SampleWasmFiles/8e61b43ddf8d78cd.ok.wasm",
#                 "filename": "8e61b43ddf8d78cd.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "miner-ray/miner-ray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             }
#         ],
#         "size_bytes": 77572,
#         "wasm_validate": true,
#         "wasm_extensions": null,
#         "custom_sections": [],
#         "wasm_validate_no_extensions": true,
#         "producers": null,
#         "instruction_count": 34918
#     },
# ```
#
#     #### The same comments as before
#
#
#
# - d2141ff28b1c81a90177319d3f4ddc17ab5c493d165be73a4af7256474a4ed58.wasm
#   ### Meta from wasmbench
#
#  ```json
# {
#         "files": [
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/WasmRay/wasmray.github.io/Data/SampleWasmFiles/62299c3ae5b1418d.ok.wasm",
#                 "filename": "62299c3ae5b1418d.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "WasmRay/wasmray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             },
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/miner-ray/miner-ray.github.io/Data/SampleWasmFiles/62299c3ae5b1418d.ok.wasm",
#                 "filename": "62299c3ae5b1418d.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "miner-ray/miner-ray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             }
#         ],
#         "size_bytes": 70111,
#         "wasm_validate": true,
#         "wasm_extensions": null,
#         "custom_sections": [],
#         "wasm_validate_no_extensions": true,
#         "producers": null,
#         "instruction_count": 31783
#     },
#  ```
#
#     #### The same comments as before
#
#
#
# - a27b45ef89b961b8c8ff78b6ab580ce0d866647c3ae03c4ab0f37ba15c433f8f.wasm
#   ### Meta from wasmbench
#
#   ```json
#
#     "a27b45ef89b961b8c8ff78b6ab580ce0d866647c3ae03c4ab0f37ba15c433f8f": {
#         "files": [
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/WasmRay/wasmray.github.io/Data/SampleWasmFiles/c8a2e3c62d978ed4.ok.wasm",
#                 "filename": "c8a2e3c62d978ed4.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "WasmRay/wasmray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             },
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/miner-ray/miner-ray.github.io/Data/SampleWasmFiles/c8a2e3c62d978ed4.ok.wasm",
#                 "filename": "c8a2e3c62d978ed4.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "miner-ray/miner-ray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             }
#         ],
#         "size_bytes": 77572,
#         "wasm_validate": true,
#         "wasm_extensions": null,
#         "custom_sections": [],
#         "wasm_validate_no_extensions": true,
#         "producers": null,
#         "instruction_count": 34918
#     },
#   ```
#
#     #### The same comments as before
#
#
#
# - 6b8c789921d0ca5531295477c7703d2f5ec619a8bbb51db41928b5c4f1c3f6e4.wasm
#   ### Meta from wasmbench
#
#
# ```json
# "6b8c789921d0ca5531295477c7703d2f5ec619a8bbb51db41928b5c4f1c3f6e4": {
#         "files": [
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/WasmRay/wasmray.github.io/Data/SampleWasmFiles/88184f6632fb7a6a.ok.wasm",
#                 "filename": "88184f6632fb7a6a.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "WasmRay/wasmray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             },
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/miner-ray/miner-ray.github.io/Data/SampleWasmFiles/88184f6632fb7a6a.ok.wasm",
#                 "filename": "88184f6632fb7a6a.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "miner-ray/miner-ray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             }
#         ],
#         "size_bytes": 77572,
#         "wasm_validate": true,
#         "wasm_extensions": null,
#         "custom_sections": [],
#         "wasm_validate_no_extensions": true,
#         "producers": null,
#         "instruction_count": 34918
#
# ```
#
#     #### The same comments as before
#
#
#
# - c1be4071ccc59e468803cb9b9eae25ec3aaff24f1d37ee0b81ba9126f8334572.wasm
#   ### Meta from wasmbench
#
#
# ```json
# "c1be4071ccc59e468803cb9b9eae25ec3aaff24f1d37ee0b81ba9126f8334572": {
#         "files": [
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/WasmRay/wasmray.github.io/Data/SampleWasmFiles/9364f7b3b20ec836.ok.wasm",
#                 "filename": "9364f7b3b20ec836.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "WasmRay/wasmray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             },
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/miner-ray/miner-ray.github.io/Data/SampleWasmFiles/9364f7b3b20ec836.ok.wasm",
#                 "filename": "9364f7b3b20ec836.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "miner-ray/miner-ray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             }
#         ],
#         "size_bytes": 77572,
#         "wasm_validate": true,
#         "wasm_extensions": null,
#         "custom_sections": [],
#         "wasm_validate_no_extensions": true,
#         "producers": null,
#         "instruction_count": 34918
#     },
# ```
#
#     #### The same comments as before
#
#
#
# - 089dd3123f4322e38e3130b3c051b00f66b52070a5634242f4310a4c64709eac.wasm
#   ### Meta from wasmbench
#
#
# ```json
# "089dd3123f4322e38e3130b3c051b00f66b52070a5634242f4310a4c64709eac": {
#         "files": [
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/WasmRay/wasmray.github.io/Data/SampleWasmFiles/04a5d48f4d815149.ok.wasm",
#                 "filename": "04a5d48f4d815149.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "WasmRay/wasmray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             },
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/miner-ray/miner-ray.github.io/Data/SampleWasmFiles/04a5d48f4d815149.ok.wasm",
#                 "filename": "04a5d48f4d815149.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "miner-ray/miner-ray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             }
#         ],
#         "size_bytes": 79883,
#         "wasm_validate": true,
#         "wasm_extensions": null,
#         "custom_sections": [],
#         "wasm_validate_no_extensions": true,
#         "producers": null,
#         "instruction_count": 34989
#     },
# ```
#
#
#     #### The same comments as before
#
#
#
# - 046dc081076d9cea6831967619b862cc80fa8c2381346406ec639c899cda640f.wasm
#   ### Meta from wasmbench
#
#   ```json
#
#     "046dc081076d9cea6831967619b862cc80fa8c2381346406ec639c899cda640f": {
#         "files": [
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/WasmRay/wasmray.github.io/Data/SampleWasmFiles/dd3647ef1aaa6076.ok.wasm",
#                 "filename": "dd3647ef1aaa6076.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "WasmRay/wasmray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             },
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/miner-ray/miner-ray.github.io/Data/SampleWasmFiles/dd3647ef1aaa6076.ok.wasm",
#                 "filename": "dd3647ef1aaa6076.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "miner-ray/miner-ray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             }
#         ],
#         "size_bytes": 74099,
#         "wasm_validate": true,
#         "wasm_extensions": null,
#         "custom_sections": [
#             "name"
#         ],
#         "wasm_validate_no_extensions": true,
#         "producers": null,
#         "instruction_count": 31783
#     },
#   ```
#
# - 59955b4c538d0b45961e19b70c4ab7a101968561a353186045bde628c0d72dbb.wasm
#   ### Meta from wasmbench
#
#   ```json
# "59955b4c538d0b45961e19b70c4ab7a101968561a353186045bde628c0d72dbb": {
#         "files": [
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/WasmRay/wasmray.github.io/Data/SampleWasmFiles/9fceb0526190bdf3.ok.wasm",
#                 "filename": "9fceb0526190bdf3.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "WasmRay/wasmray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             },
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/miner-ray/miner-ray.github.io/Data/SampleWasmFiles/9fceb0526190bdf3.ok.wasm",
#                 "filename": "9fceb0526190bdf3.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "miner-ray/miner-ray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             }
#         ],
#         "size_bytes": 77572,
#         "wasm_validate": true,
#         "wasm_extensions": null,
#         "custom_sections": [],
#         "wasm_validate_no_extensions": true,
#         "producers": null,
#         "instruction_count": 34918
#     },
#   ```
#
# - 65debcbe8c6e64a04c9c3b75794b77644526a514d89a09f037f2cf53f2aa2f98.wasm
#   ### Meta from wasmbench
#
#   ```json
# "65debcbe8c6e64a04c9c3b75794b77644526a514d89a09f037f2cf53f2aa2f98": {
#         "files": [
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/WasmRay/wasmray.github.io/Data/SampleWasmFiles/f8b45e4c875951a2.ok.wasm",
#                 "filename": "f8b45e4c875951a2.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "WasmRay/wasmray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             },
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/miner-ray/miner-ray.github.io/Data/SampleWasmFiles/f8b45e4c875951a2.ok.wasm",
#                 "filename": "f8b45e4c875951a2.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "miner-ray/miner-ray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             }
#         ],
#         "size_bytes": 77572,
#         "wasm_validate": true,
#         "wasm_extensions": null,
#         "custom_sections": [],
#         "wasm_validate_no_extensions": true,
#         "producers": null,
#         "instruction_count": 34918
#     },
#
#   ```
# - 643116ff7be6f5a1e538ceeca66f7815e3e1f0c95033fe9824c83875d31d38fa.wasm
#   ### Meta from wasmbench
#
#   ```json
#  "643116ff7be6f5a1e538ceeca66f7815e3e1f0c95033fe9824c83875d31d38fa": {
#         "files": [
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/WasmRay/wasmray.github.io/Data/SampleWasmFiles/cdda7f45fb53de52.ok.wasm",
#                 "filename": "cdda7f45fb53de52.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "WasmRay/wasmray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             },
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/miner-ray/miner-ray.github.io/Data/SampleWasmFiles/cdda7f45fb53de52.ok.wasm",
#                 "filename": "cdda7f45fb53de52.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "miner-ray/miner-ray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             }
#         ],
#         "size_bytes": 73010,
#         "wasm_validate": true,
#         "wasm_extensions": null,
#         "custom_sections": [],
#         "wasm_validate_no_extensions": true,
#         "producers": null,
#         "instruction_count": 31866
#     },
#
#   ```
#
# - 89a3645c1680125a0a2bcf30c33456f30a8235efbfb3c731e94244fa1f925c46.wasm
#   ### Meta from wasmbench
#
#   ```json
# "89a3645c1680125a0a2bcf30c33456f30a8235efbfb3c731e94244fa1f925c46": {
#         "files": [
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/WasmRay/wasmray.github.io/Data/SampleWasmFiles/e923c07a85a24b45.ok.wasm",
#                 "filename": "e923c07a85a24b45.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "WasmRay/wasmray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             },
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/miner-ray/miner-ray.github.io/Data/SampleWasmFiles/e923c07a85a24b45.ok.wasm",
#                 "filename": "e923c07a85a24b45.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "miner-ray/miner-ray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             }
#         ],
#         "size_bytes": 75003,
#         "wasm_validate": true,
#         "wasm_extensions": null,
#         "custom_sections": [],
#         "wasm_validate_no_extensions": true,
#         "producers": null,
#         "instruction_count": 34134
#     },
#   ```
#
# - 7c36f462eacff709b8821154424abb0386373d7d763c45998d298c1aab7921b5.wasm
#   ### Meta from wasmbench
#
#   ```json
# "7c36f462eacff709b8821154424abb0386373d7d763c45998d298c1aab7921b5": {
#         "files": [
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/WasmRay/wasmray.github.io/Data/SampleWasmFiles/79eb42e12fc3cf7e.ok.wasm",
#                 "filename": "79eb42e12fc3cf7e.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "WasmRay/wasmray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             },
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/miner-ray/miner-ray.github.io/Data/SampleWasmFiles/79eb42e12fc3cf7e.ok.wasm",
#                 "filename": "79eb42e12fc3cf7e.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "miner-ray/miner-ray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             }
#         ],
#         "size_bytes": 121931,
#         "wasm_validate": true,
#         "wasm_extensions": null,
#         "custom_sections": [],
#         "wasm_validate_no_extensions": true,
#         "producers": null,
#         "instruction_count": 55839
#     },
#   ```
#
# - a74a7cb854cd33442d8ef481d341b4a0632b88d8def1d22852adb10de8f7cbf3.wasm
#   ### Meta from wasmbench
#
#   ```json
# "a74a7cb854cd33442d8ef481d341b4a0632b88d8def1d22852adb10de8f7cbf3": {
#         "files": [
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/WasmRay/wasmray.github.io/Data/SampleWasmFiles/4775b748fe395694.ok.wasm",
#                 "filename": "4775b748fe395694.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "WasmRay/wasmray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             },
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/miner-ray/miner-ray.github.io/Data/SampleWasmFiles/4775b748fe395694.ok.wasm",
#                 "filename": "4775b748fe395694.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "miner-ray/miner-ray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             }
#         ],
#         "size_bytes": 77572,
#         "wasm_validate": true,
#         "wasm_extensions": null,
#         "custom_sections": [],
#         "wasm_validate_no_extensions": true,
#         "producers": null,
#         "instruction_count": 34918
#     },
#   ```
#
# - e09c32c505dc641e678cc4c7095315454d8d7f1094d0e39a31f1160e995f2610.wasm
#   ### Meta from wasmbench
#
#   ```json
#   "e09c32c505dc641e678cc4c7095315454d8d7f1094d0e39a31f1160e995f2610": {
#         "files": [
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/WasmRay/wasmray.github.io/Data/SampleWasmFiles/56e35772a5d67edd.ok.wasm",
#                 "filename": "56e35772a5d67edd.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "WasmRay/wasmray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             },
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/miner-ray/miner-ray.github.io/Data/SampleWasmFiles/56e35772a5d67edd.ok.wasm",
#                 "filename": "56e35772a5d67edd.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "miner-ray/miner-ray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             }
#         ],
#         "size_bytes": 71955,
#         "wasm_validate": true,
#         "wasm_extensions": null,
#         "custom_sections": [],
#         "wasm_validate_no_extensions": true,
#         "producers": null,
#         "instruction_count": 32416
#     },
#   ```
#
# - 119c53ebaf6077a5f445262ad91d91dfa137dac4127f73d5ced76e297d022672.wasm
#   ### Meta from wasmbench
#
#   ```json
# "119c53ebaf6077a5f445262ad91d91dfa137dac4127f73d5ced76e297d022672": {
#         "files": [
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/wenhao1006/SEISMIC/NFWebMiner/webminer_v1.base_profiled.wasm",
#                 "filename": "webminer_v1.base_profiled.wasm",
#                 "collection_method": "github",
#                 "repository": "wenhao1006/SEISMIC",
#                 "sibling_extensions": [],
#                 "stars": 2
#             }
#         ],
#         "size_bytes": 137320,
#         "wasm_validate": true,
#         "wasm_extensions": null,
#         "custom_sections": [],
#         "wasm_validate_no_extensions": true,
#         "producers": null,
#         "instruction_count": 67069
#     },
#   ```
#
# - fbdd1efaa585e95d802322c976e39430e6abb21de467bec87f0849afeeeaaf2e.wasm
#   ### Meta from wasmbench
#
#   ```json
# "fbdd1efaa585e95d802322c976e39430e6abb21de467bec87f0849afeeeaaf2e": {
#         "files": [
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/wenhao1006/SEISMIC/CoinHive/32-bit/worker_profiled.wasm",
#                 "filename": "worker_profiled.wasm",
#                 "collection_method": "github",
#                 "repository": "wenhao1006/SEISMIC",
#                 "sibling_extensions": [],
#                 "stars": 2
#             }
#         ],
#         "size_bytes": 94270,
#         "wasm_validate": true,
#         "wasm_extensions": null,
#         "custom_sections": [],
#         "wasm_validate_no_extensions": true,
#         "producers": null,
#         "instruction_count": 45905
#     },
#   ```
#
# - 9d30e7f065cd00a47d8e10e27acc443a33977176484ca11077f08fc20b1a672c.wasm
#   ### Meta from wasmbench
#
#   ```json
# "9d30e7f065cd00a47d8e10e27acc443a33977176484ca11077f08fc20b1a672c": {
#         "files": [
#             {
#                 "absolute_path": "wasm-study/web/httparchive/monero.cit/203-monero.cit.net.wasm",
#                 "filename": "203-monero.cit.net.wasm",
#                 "collection_method": "web/httparchive-query",
#                 "domain": "monero.cit",
#                 "sibling_extensions": []
#             }
#         ],
#         "size_bytes": 68796,
#         "wasm_validate": true,
#         "wasm_extensions": null,
#         "custom_sections": [],
#         "wasm_validate_no_extensions": true,
#         "producers": null,
#         "instruction_count": 30768
#     },
#   ```
#
# - dceaf65bf86d2de5bc460eef3b3c858ccdc82f478469752555e95c749324e7e2.wasm
#   ### Meta from wasmbench
#
#   ```json
# "dceaf65bf86d2de5bc460eef3b3c858ccdc82f478469752555e95c749324e7e2": {
#         "files": [
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/WasmRay/wasmray.github.io/Data/SampleWasmFiles/6b936036702c733c.ok.wasm",
#                 "filename": "6b936036702c733c.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "WasmRay/wasmray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             },
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/miner-ray/miner-ray.github.io/Data/SampleWasmFiles/6b936036702c733c.ok.wasm",
#                 "filename": "6b936036702c733c.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "miner-ray/miner-ray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             }
#         ],
#         "size_bytes": 77575,
#         "wasm_validate": true,
#         "wasm_extensions": null,
#         "custom_sections": [],
#         "wasm_validate_no_extensions": true,
#         "producers": null,
#         "instruction_count": 34901
#     },
#   ```
#
# - 006b2fb61de05aa4fec89f479ce45b6295c6080d6ec4bd919059c39fa2b93b31.wasm
#   ### Meta from wasmbench
#
#   ```json
# "006b2fb61de05aa4fec89f479ce45b6295c6080d6ec4bd919059c39fa2b93b31": {
#         "files": [
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/deepwn/deepMiner/web/lib/cryptonight.wasm",
#                 "filename": "cryptonight.wasm",
#                 "collection_method": "github",
#                 "repository": "deepwn/deepMiner",
#                 "sibling_extensions": [
#                     "js"
#                 ],
#                 "stars": 482
#             }
#         ],
#         "size_bytes": 87502,
#         "wasm_validate": true,
#         "wasm_extensions": null,
#         "custom_sections": [],
#         "wasm_validate_no_extensions": true,
#         "producers": null,
#         "instruction_count": 39544
#     },
#   ```
#
# - a32a6f4bbd1918accf9ce8206bbf8e1346eb93c283d44e3320b24c7cd7861b41.wasm
#   ### Meta from wasmbench
#
#   ```json
#          "a32a6f4bbd1918accf9ce8206bbf8e1346eb93c283d44e3320b24c7cd7861b41": {
#         "files": [
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/wenhao1006/SEISMIC/CoinHive/64-bit/worker64_profiled.wasm",
#                 "filename": "worker64_profiled.wasm",
#                 "collection_method": "github",
#                 "repository": "wenhao1006/SEISMIC",
#                 "sibling_extensions": [
#                     "wat"
#                 ],
#                 "stars": 2
#             }
#         ],
#         "size_bytes": 94461,
#         "wasm_validate": true,
#         "wasm_extensions": null,
#         "custom_sections": [],
#         "wasm_validate_no_extensions": true,
#         "producers": null,
#         "instruction_count": 45940
#     },
#     ```
#
# - 68ca7c0e99a5df6d36e52008df1b20c108d1821f28a40c349c1516900bc30322.wasm
#   ### Meta from wasmbench
#
#   ```json
# "68ca7c0e99a5df6d36e52008df1b20c108d1821f28a40c349c1516900bc30322": {
#         "files": [
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/WasmRay/wasmray.github.io/Data/SampleWasmFiles/ba2b842fe7b9e0b2.ok.wasm",
#                 "filename": "ba2b842fe7b9e0b2.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "WasmRay/wasmray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             },
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/miner-ray/miner-ray.github.io/Data/SampleWasmFiles/ba2b842fe7b9e0b2.ok.wasm",
#                 "filename": "ba2b842fe7b9e0b2.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "miner-ray/miner-ray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             }
#         ],
#         "size_bytes": 77572,
#         "wasm_validate": true,
#         "wasm_extensions": null,
#         "custom_sections": [],
#         "wasm_validate_no_extensions": true,
#         "producers": null,
#         "instruction_count": 34918
#     },
#   ```
#
# - 15b86a25f45761119d9819ad9eaedce5239a23d66f12b3f123230ff3e742774b.wasm
#   ### Meta from wasmbench
#
#   ```json
# "15b86a25f45761119d9819ad9eaedce5239a23d66f12b3f123230ff3e742774b": {
#         "files": [
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/WasmRay/wasmray.github.io/Data/SampleWasmFiles/99d2307d0411addc.ok.wasm",
#                 "filename": "99d2307d0411addc.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "WasmRay/wasmray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             },
#             {
#                 "absolute_path": "wasm-study/github/clone/repos/miner-ray/miner-ray.github.io/Data/SampleWasmFiles/99d2307d0411addc.ok.wasm",
#                 "filename": "99d2307d0411addc.ok.wasm",
#                 "collection_method": "github",
#                 "repository": "miner-ray/miner-ray.github.io",
#                 "sibling_extensions": [],
#                 "stars": 0
#             }
#         ],
#         "size_bytes": 100755,
#         "wasm_validate": true,
#         "wasm_extensions": null,
#         "custom_sections": [],
#         "wasm_validate_no_extensions": true,
#         "producers": null,
#         "instruction_count": 45881
#     },
#   ```
#
#   # FROM WEB
#
# - 8ebf4e44c47b6b61d313bd2580bd788a1daa029541fe210cccfa13d1bb66cc89.wasm
#   ### Meta from wasmbench
#
#   ```json
# "8ebf4e44c47b6b61d313bd2580bd788a1daa029541fe210cccfa13d1bb66cc89": {
#         "files": [
#             {
#                 "absolute_path": "wasm-study/web/own-crawler/tranco/network/extratorrent.si/1149-extratorrent_si_8ebf4e44c47b6b61.wasm",
#                 "filename": "1149-extratorrent_si_8ebf4e44c47b6b61.wasm",
#                 "collection_method": "web/own-crawler",
#                 "seed_list": "tranco",
#                 "wasm_detection": "network",
#                 "domain": "extratorrent.si",
#                 "sibling_extensions": []
#             }
#         ],
#         "size_bytes": 68803,
#         "wasm_validate": true,
#         "wasm_extensions": null,
#         "custom_sections": [],
#         "wasm_validate_no_extensions": true,
#         "producers": null,
#         "instruction_count": 30768
#     },
#
#   ```
#
#   **Reproduction:** Set a proxy and replace the getting of the Wasm file by a pool. The wakoko extension can be used to detect and replace by another file to check for correctness. However, the most reliable way is to instrument chromium to detect every instantiation or call to a Wasm binary.

# %% [markdown]
# ## TODO: We need to check how many of them are variants from each other
#
# In theory $$33\times32/2$$ comparisons

# %% [markdown]
# # For example
# - 24aar... and 0004 are exactly the same binary with one being the obfuscation of the other.
# - The same case for 65debcbe8c6e64a04c9c3b75794b77644526a514d89a09f037f2cf53f2aa2f98 and 68ca7c0e99a5df6d36e52008df1b20c108d1821f28a40c349c1516900bc30322
# - malware/wat/5bc5334382f650c8a7cc38d651b86db06eb755b64662eaef42c6040cf879f0ce.wasm.wat malware/wat/f0b244090f9e4a9f599a68f42d7a89e003026202324cf86c6cd4a46ad8c98da8.wasm.wat
# - malware/wat/5bc5334382f650c8a7cc38d651b86db06eb755b64662eaef42c6040cf879f0ce.wasm.wat malware/wat/a27b45ef89b961b8c8ff78b6ab580ce0d866647c3ae03c4ab0f37ba15c433f8f.wasm.wat
# - malware/wat/5bc5334382f650c8a7cc38d651b86db06eb755b64662eaef42c6040cf879f0ce.wasm.wat malware/wat/6b8c789921d0ca5531295477c7703d2f5ec619a8bbb51db41928b5c4f1c3f6e4.wasm.wat
# - malware/wat/5bc5334382f650c8a7cc38d651b86db06eb755b64662eaef42c6040cf879f0ce.wasm.wat malware/wat/c1be4071ccc59e468803cb9b9eae25ec3aaff24f1d37ee0b81ba9126f8334572.wasm.wat
#
# - malware/wat/5bc5334382f650c8a7cc38d651b86db06eb755b64662eaef42c6040cf879f0ce.wasm.wat malware/wat/59955b4c538d0b45961e19b70c4ab7a101968561a353186045bde628c0d72dbb.wasm.wat
# - malware/wat/5bc5334382f650c8a7cc38d651b86db06eb755b64662eaef42c6040cf879f0ce.wasm.wat malware/wat/65debcbe8c6e64a04c9c3b75794b77644526a514d89a09f037f2cf53f2aa2f98.wasm.wat
#
# - malware/wat/5bc5334382f650c8a7cc38d651b86db06eb755b64662eaef42c6040cf879f0ce.wasm.wat malware/wat/a74a7cb854cd33442d8ef481d341b4a0632b88d8def1d22852adb10de8f7cbf3.wasm.wat
# - malware/wat/5bc5334382f650c8a7cc38d651b86db06eb755b64662eaef42c6040cf879f0ce.wasm.wat malware/wat/68ca7c0e99a5df6d36e52008df1b20c108d1821f28a40c349c1516900bc30322.wasm.wat
#
# - malware/wat/f0b244090f9e4a9f599a68f42d7a89e003026202324cf86c6cd4a46ad8c98da8.wasm.wat malware/wat/5bc5334382f650c8a7cc38d651b86db06eb755b64662eaef42c6040cf879f0ce.wasm.wat
#
# - malware/wat/f0b244090f9e4a9f599a68f42d7a89e003026202324cf86c6cd4a46ad8c98da8.wasm.wat malware/wat/a27b45ef89b961b8c8ff78b6ab580ce0d866647c3ae03c4ab0f37ba15c433f8f.wasm.wat
#
# - malware/wat/f0b244090f9e4a9f599a68f42d7a89e003026202324cf86c6cd4a46ad8c98da8.wasm.wat malware/wat/6b8c789921d0ca5531295477c7703d2f5ec619a8bbb51db41928b5c4f1c3f6e4.wasm.wat
# - malware/wat/f0b244090f9e4a9f599a68f42d7a89e003026202324cf86c6cd4a46ad8c98da8.wasm.wat malware/wat/c1be4071ccc59e468803cb9b9eae25ec3aaff24f1d37ee0b81ba9126f8334572.wasm.wat
# - malware/wat/f0b244090f9e4a9f599a68f42d7a89e003026202324cf86c6cd4a46ad8c98da8.wasm.wat malware/wat/59955b4c538d0b45961e19b70c4ab7a101968561a353186045bde628c0d72dbb.wasm.wat
# - malware/wat/f0b244090f9e4a9f599a68f42d7a89e003026202324cf86c6cd4a46ad8c98da8.wasm.wat malware/wat/65debcbe8c6e64a04c9c3b75794b77644526a514d89a09f037f2cf53f2aa2f98.wasm.wat
# - malware/wat/f0b244090f9e4a9f599a68f42d7a89e003026202324cf86c6cd4a46ad8c98da8.wasm.wat malware/wat/a74a7cb854cd33442d8ef481d341b4a0632b88d8def1d22852adb10de8f7cbf3.wasm.wat
#
# - malware/wat/f0b244090f9e4a9f599a68f42d7a89e003026202324cf86c6cd4a46ad8c98da8.wasm.wat malware/wat/68ca7c0e99a5df6d36e52008df1b20c108d1821f28a40c349c1516900bc30322.wasm.wat
#
# - malware/wat/a27b45ef89b961b8c8ff78b6ab580ce0d866647c3ae03c4ab0f37ba15c433f8f.wasm.wat malware/wat/5bc5334382f650c8a7cc38d651b86db06eb755b64662eaef42c6040cf879f0ce.wasm.wat

# %% [markdown]
# ```
# malware/wat/65debcbe8c6e64a04c9c3b75794b77644526a514d89a09f037f2cf53f2aa2f98.wasm.wat malware/wat/68ca7c0e99a5df6d36e52008df1b20c108d1821f28a40c349c1516900bc30322.wasm.wat
#   (export "_bBcDYnZGHoa_create" (func 46))                    |   (export "_sRjBEbREsTx_create" (func 46))
#   (export "_bBcDYnZGHoa_destroy" (func 45))                   |   (export "_sRjBEbREsTx_destroy" (func 45))
#   (export "_bBcDYnZGHoa_hash" (func 44))                      |   (export "_sRjBEbREsTx_hash" (func 44))
#   (data (;22;) (i32.const 12232) "bBcDYnZGHoa variant 1 needs |   (data (;22;) (i32.const 12232) "sRjBEbREsTx variant 1 needs
# ```
