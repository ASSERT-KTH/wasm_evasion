# %% [markdown]
# ## Feature selection experiment

# %%
import networkx as nx
import matplotlib.pyplot as plt
import itertools
import json
import pandas as pd
import re

resampple = r"sample (\d+)"
is_sampled = r"timeout (true|false)"




def load_mutable_csv(f, rename=""):
    f = f.replace(".csv", "")
    
    a = pd.read_csv(f"csv/{f}.csv",index_col = 'id')
    
    if rename:
        a.rename(columns = {'mutable_count': rename}, inplace = True)
        
        snapthots = [ "_t30.snapshot", "_t5.snapshot"]
        # Set the sample ratio then
        if len(a[a[rename] > 0]) == 0:
            # trying with the snapshots
            
            for c in snapthots:
                try:
                    print(f"Trying csv/{f}{c}.csv")
                    np = pd.read_csv(f"csv/{f}{c}.csv",index_col = 'id')
                    if len(np[np['mutable_count'] > 0]) > 0:
                        print(f"Taking {c} for {f}" )
                        a = np
                        a.rename(columns = {'mutable_count': rename}, inplace = True)
                except Exception as e:
                    print(e)
                    pass
            if len(a[a[rename] > 0]) == 0:
                print(">>>>> Zero count", rename, f)
        else:
            pass
            #print(rename)
        
    
    #display(a)
    a[rename] = a[rename] > 0
    return a

# %%
ratios = [
    
]



files = [('peep.i32.operator_or_neg1', 'i32.operator_or_neg1.csv'), 
         ('peep.i32.operator_or_neg_one1', 'i32.operator_or_neg_one1.csv'), 
         ('peep.i32.operator_or_commutative', 'i32.operator_or_commutative.csv'), 
         ('peep.i64.operator_or_commutative', 'i64.operator_or_commutative.csv'), 
         ('peep.i32.operator_and_commutative', 'i32.operator_and_commutative.csv'), 
         ('peep.i64.operator_and_commutative', 'i64.operator_and_commutative.csv'), 
         ('peep.select_same_branches', 'select_same_branches.csv'), 
         ('peep.i32.sub_zero', 'i32.sub_zero.csv'), 
         ('peep.i32.mul_1', 'i32.mul_1_t5.snapshot.csv'), 
         ('peep.i64.mul_1', 'i64.mul_1.csv'), 
         ('peep.f32.mul_1', 'f32.mul_1.csv'), 
         ('peep.f64.mul_1', 'f64.mul_1.csv'), 
         ('peep.i32.add_0', 'i32.add_0.csv'), 
         ('peep.i64.add_0', 'i64.add_0.csv'), 
         ('peep.f32.add_0', 'f32.add_0.csv'), 
         ('peep.f64.add_0', 'f64.add_0.csv'), 
         ('peep.i32.xor_0', 'i32.xor_0.csv'), 
         ('peep.i64.xor_0', 'i64.xor_0.csv'), 
         ('peep.i32.eq_0', 'i32.eq_0.csv'),
         ('peep.i64.eq_0', 'i64.eq_0.csv'), 
         ('peep.i32.shl_by_0', 'i32.shl_by_0.csv'), 
         ('peep.i64.shl_by_0', 'i64.shl_by_0.csv'), 
         ('peep.i32.shr_u_by_0', 'i32.shr_u_by_0.csv'), 
         ('peep.i64.shr_u_by_0', 'i64.shr_u_by_0.csv'), 
         ('peep.i32.shr_s_by_0', 'i32.shr_s_by_0.csv'), 
         ('peep.i64.shr_s_by_0', 'i64.shr_s_by_0.csv'), 
         ('peep.i64.operator_or_neg1', 'i64.operator_or_neg1.csv'), 
         ('peep.i64.sub_zero', 'i64.sub_zero.csv'), 
         ('peep.i32.add-commutes', 'i32.add-commutes.csv'), 
         ('peep.i64.add-commutes', 'i64.add-commutes.csv'), 
         ('peep.f32.add-commutes', 'f32.add-commutes.csv'), 
         ('peep.f64.add-commutes', 'f64.add-commutes.csv'), 
         ('peep.i32.mul-commutes', 'i32.mul-commutes.csv'), 
         ('peep.i64.mul-commutes', 'i64.mul-commutes.csv'), 
         ('peep.f32.mul-commutes', 'f32.mul-commutes.csv'), 
         ('peep.f64.mul-commutes', 'f64.mul-commutes.csv'), 
         ('peep.i32.and-commutes', 'i32.and-commutes.csv'), 
         ('peep.i64.and-commutes', 'i64.and-commutes.csv'), 
         ('peep.i32.or-commutes', 'i32.or-commutes.csv'), 
         ('peep.i64.or-commutes', 'i64.or-commutes.csv'), 
         ('peep.i32.xor-commutes', 'i32.xor-commutes.csv'), 
         ('peep.i64.xor-commutes', 'i64.xor-commutes.csv'), 
         ('peep.i32.eq-commutes', 'i32.eq-commutes.csv'), 
         ('peep.i64.eq-commutes', 'i64.eq-commutes.csv'), 
         ('peep.i32.mul-associates', 'i32.mul-associates.csv'), 
         ('peep.i64.mul-associates', 'i64.mul-associates.csv'), 
         ('peep.i32.add-associates', 'i32.add-associates.csv'), 
         ('peep.i32.and-associates', 'i32.and-associates.csv'), 
         ('peep.i32.or-associates', 'i32.or-associates.csv'), 
         ('peep.i64.or-associates', 'i64.or-associates.csv'), 
         ('peep.i32.xor-associates', 'i32.xor-associates.csv'), 
         ('peep.i64.xor-associates', 'i64.xor-associates.csv'), 
         ('peep.i32.eq-associates', 'i32.eq-associates.csv'), 
         ('peep.i64.eq-associates', 'i64.eq-associates.csv'), 
         ('peep.i32.mul-by-2', 'i32.mul-by-2.csv'), 
         ('peep.i64.mul-by-2', 'i64.mul-by-2.csv'), 
         ('peep.i32.mul-by-4', 'i32.mul-by-4.csv'), 
         ('peep.i64.mul-by-4', 'i64.mul-by-4.csv'), 
         ('peep.i32.mul-by-8', 'i32.mul-by-8.csv'), 
         ('peep.i64.mul-by-8', 'i64.mul-by-8.csv'), 
         ('peep.select-invert', 'select-invert.csv'), 
         ('peep.i32.add-x-x', 'i32.add-x-x.csv'), 
         ('peep.i64.add-x-x', 'i64.add-x-x.csv'), 
         ('peep.i32.drop-x', 'i32.drop-x.csv'), 
         ('peep.i64.drop-x', 'i64.drop-x.csv'), 
         ('peep.f32.drop-x', 'f32.drop-x.csv'), 
         ('peep.f64.drop-x', 'f64.drop-x.csv'), 
         ('peep.container-nop-x', 'container-nop-x.csv'), 
         ('peep.container-x-nop', 'container-x-nop.csv'), 
         ('peep.container-drop-i32.rand-x', 'container-drop-i32.rand-x.csv'), 
         ('peep.container-drop-i64.rand-x', 'container-drop-i64.rand-x.csv'), 
         ('peep.container-x-drop-i32.rand', 'container-x-drop-i32.rand.csv'), 
         ('peep.container-x-drop-i64.rand', 'container-x-drop-i64.rand.csv'), 
         ('peep.i32.use_of_global', 'i32.use_of_global.csv'), 
         ('peep.i64.use_of_global', 'i64.use_of_global.csv'), 
         ('peep.f32.use_of_global', 'f32.use_of_global.csv'), 
         ('peep.f64.use_of_global', 'f64.use_of_global.csv'), 
         ('peep.i32.unfold', 'i32.unfold.csv'), 
         ('peep.i64.unfold', 'i64.unfold_t30.csv'), 
         ('peep.replace-with-i32-1', 'replace-with-i32-1.csv'), 
         ('peep.replace-with-i64-1', 'replace-with-i64-1_t30.csv'),
         ('peep.replace-with-f32-1', 'replace-with-f32-1_t30.csv'), 
         ('peep.replace-with-f64-1', 'replace-with-f64-1_t30.csv'), 
         ('peep.replace-with-v128-1', 'replace-with-v128-1_t30.csv'), 
         ('peep.replace-with-i32.rand', 'replace-with-i32.rand_t30.csv'), 
         ('peep.replace-with-i64.rand', 'replace-with-i64.rand.csv'), 
         ('peep.replace-with-f32.rand', 'replace-with-f32.rand.csv'), 
         ('peep.replace-with-f64.rand', 'replace-with-f64.rand.csv'), 
         ('peep.replace-with-ref-null-func', 'replace-with-ref-null-func.csv'), 
         ('peep.replace-with-ref-null-extern', 'replace-with-ref-null-extern.csv'), 
         ('peep.remove-drop', 'remove-drop.csv'), 
         ('peep.remove-nop', 'remove-nop.csv'), 
         ('peep.remove-global.set.0', 'remove-global.set.0.csv'), 
         ('peep.remove-global.set.1', 'remove-global.set.1.csv'), 
         ('peep.remove-elem.drop.0', 'remove-elem.drop.0.csv'), 
         ('peep.remove-elem.drop.1', 'remove-elem.drop.1.csv'), 
         ('peep.remove-data.drop.0', 'remove-data.drop.0.csv'), 
         ('peep.remove-data.drop.1', 'remove-data.drop.1.csv'), 
         ('peep.i32.add-1', 'i32.add-1.csv'), 
         ('peep.i64.add-1', 'i64.add-1.csv'), 
         ('peep.i32.sub-1', 'i32.sub-1.csv'), 
         ('peep.i64.sub-1', 'i64.sub-1.csv'), 
         ('peep.i32.and-1', 'i32.and-1.csv'), 
         ('peep.i64.and-1', 'i64.and-1.csv'), 
         ('peep.i32.or-1', 'i32.or-1.csv'), 
         ('peep.i64.or-1', 'i64.or-1.csv'), 
         ('peep.i32.xor-1', 'i32.xor-1.csv'), 
         ('peep.i64.xor-1', 'i64.xor-1.csv'), 
         ('peep.i32.shl-1', 'i32.shl-1.csv'), 
         ('peep.i64.shl-1', 'i64.shl-1.csv'), 
         ('peep.i32.shr_u-1', 'i32.shr_u-1.csv'), 
         ('peep.i64.shr_u-1', 'i64.shr_u-1.csv'), 
         ('peep.i32.shr_s-1', 'i32.shr_s-1.csv'), 
         ('peep.i64.shr_s-1', 'i64.shr_s-1.csv'), 
         ('code_motion_ifs', 'code_motion_ifs.csv'), 
         ('code_motion_loops', 'code_motion_loops.csv'), 
         ('add_function', 'add_function.csv'), 
         ('add_type', 'add_type.csv'), 
         ('modify_custom_section', 'modify_custom_section_name.csv'), 
         ('modify_custom_section_name', 'modify_custom_section_name.csv'), 
         ('modify_custom_section_data', 'modify_custom_section_data.csv'), 
         ('function_body_unreachable', 'function_body_unreachable.csv'), 
         ('modify_data', 'modify_data.csv'), 
         ('modify_init_exprs', 'modify_init_exprs.csv'), 
         ('remove_exports', 'remove_exports.csv'), 
         ('remove_item_function', 'remove_item_function.csv'), 
         ('remove_item_table', 'remove_item_table.csv'), 
         ('remove_item_memory', 'remove_item_memory.csv'), 
         ('remove_item_global', 'remove_item_global.csv'), 
         ('remove_item_tag', 'remove_item_tag.csv'), 
         ('remove_item_type', 'remove_item_type.csv'), 
         ('remove_item_data', 'remove_item_data.csv'), 
         ('remove_item_element', 'remove_item_element.csv'), 
         ('rename_exports', 'rename_exports.csv'), 
         ('snip_function', 'snip_function.csv')]
alldf = pd.DataFrame()

for n, f in files:
    print(n)
    df = load_mutable_csv(f, n)
    alldf = pd.concat([df, alldf], axis=1)

# Replace 0 by non mutable :|
alldf=alldf.fillna(False)
alldf = alldf.loc[:,~alldf.columns.duplicated()].copy()

A = 1
# Out:
# peep.i32.operator_or_neg1
# peep.i32.operator_or_neg_one1
# Trying csv/i32.operator_or_neg_one1_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/i32.operator_or_neg_one1_t30.snapshot.csv'
# Trying csv/i32.operator_or_neg_one1_t5.snapshot.csv
# >>>>> Zero count peep.i32.operator_or_neg_one1 i32.operator_or_neg_one1
# peep.i32.operator_or_commutative
# peep.i64.operator_or_commutative
# peep.i32.operator_and_commutative
# peep.i64.operator_and_commutative
# peep.select_same_branches
# peep.i32.sub_zero
# peep.i32.mul_1
# peep.i64.mul_1
# peep.f32.mul_1
# peep.f64.mul_1
# peep.i32.add_0
# peep.i64.add_0
# peep.f32.add_0
# peep.f64.add_0
# peep.i32.xor_0
# peep.i64.xor_0
# peep.i32.eq_0
# peep.i64.eq_0
# peep.i32.shl_by_0
# peep.i64.shl_by_0
# peep.i32.shr_u_by_0
# peep.i64.shr_u_by_0
# peep.i32.shr_s_by_0
# peep.i64.shr_s_by_0
# peep.i64.operator_or_neg1
# Trying csv/i64.operator_or_neg1_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/i64.operator_or_neg1_t30.snapshot.csv'
# Trying csv/i64.operator_or_neg1_t5.snapshot.csv
# >>>>> Zero count peep.i64.operator_or_neg1 i64.operator_or_neg1
# peep.i64.sub_zero
# peep.i32.add-commutes
# peep.i64.add-commutes
# peep.f32.add-commutes
# peep.f64.add-commutes
# peep.i32.mul-commutes
# peep.i64.mul-commutes
# peep.f32.mul-commutes
# peep.f64.mul-commutes
# peep.i32.and-commutes
# peep.i64.and-commutes
# peep.i32.or-commutes
# peep.i64.or-commutes
# peep.i32.xor-commutes
# peep.i64.xor-commutes
# peep.i32.eq-commutes
# peep.i64.eq-commutes
# peep.i32.mul-associates
# peep.i64.mul-associates
# peep.i32.add-associates
# peep.i32.and-associates
# peep.i32.or-associates
# peep.i64.or-associates
# peep.i32.xor-associates
# peep.i64.xor-associates
# peep.i32.eq-associates
# peep.i64.eq-associates
# Trying csv/i64.eq-associates_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/i64.eq-associates_t30.snapshot.csv'
# Trying csv/i64.eq-associates_t5.snapshot.csv
# >>>>> Zero count peep.i64.eq-associates i64.eq-associates
# peep.i32.mul-by-2
# peep.i64.mul-by-2
# peep.i32.mul-by-4
# peep.i64.mul-by-4
# peep.i32.mul-by-8
# Trying csv/i32.mul-by-8_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/i32.mul-by-8_t30.snapshot.csv'
# Trying csv/i32.mul-by-8_t5.snapshot.csv
# Taking _t5.snapshot for i32.mul-by-8
# peep.i64.mul-by-8
# peep.select-invert
# peep.i32.add-x-x
# Trying csv/i32.add-x-x_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/i32.add-x-x_t30.snapshot.csv'
# Trying csv/i32.add-x-x_t5.snapshot.csv
# Taking _t5.snapshot for i32.add-x-x
# peep.i64.add-x-x
# peep.i32.drop-x
# peep.i64.drop-x
# peep.f32.drop-x
# peep.f64.drop-x
# peep.container-nop-x
# peep.container-x-nop
# peep.container-drop-i32.rand-x
# Trying csv/container-drop-i32.rand-x_t30.snapshot.csv
# Taking _t30.snapshot for container-drop-i32.rand-x
# Trying csv/container-drop-i32.rand-x_t5.snapshot.csv
# Taking _t5.snapshot for container-drop-i32.rand-x
# peep.container-drop-i64.rand-x
# Trying csv/container-drop-i64.rand-x_t30.snapshot.csv
# Taking _t30.snapshot for container-drop-i64.rand-x
# Trying csv/container-drop-i64.rand-x_t5.snapshot.csv
# Taking _t5.snapshot for container-drop-i64.rand-x
# peep.container-x-drop-i32.rand
# peep.container-x-drop-i64.rand
# peep.i32.use_of_global
# peep.i64.use_of_global
# peep.f32.use_of_global
# peep.f64.use_of_global
# peep.i32.unfold
# peep.i64.unfold
# peep.replace-with-i32-1
# Trying csv/replace-with-i32-1_t30.snapshot.csv
# Trying csv/replace-with-i32-1_t5.snapshot.csv
# >>>>> Zero count peep.replace-with-i32-1 replace-with-i32-1
# peep.replace-with-i64-1
# Trying csv/replace-with-i64-1_t30_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/replace-with-i64-1_t30_t30.snapshot.csv'
# Trying csv/replace-with-i64-1_t30_t5.snapshot.csv
# [Errno 2] No such file or directory: 'csv/replace-with-i64-1_t30_t5.snapshot.csv'
# >>>>> Zero count peep.replace-with-i64-1 replace-with-i64-1_t30
# peep.replace-with-f32-1
# Trying csv/replace-with-f32-1_t30_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/replace-with-f32-1_t30_t30.snapshot.csv'
# Trying csv/replace-with-f32-1_t30_t5.snapshot.csv
# [Errno 2] No such file or directory: 'csv/replace-with-f32-1_t30_t5.snapshot.csv'
# >>>>> Zero count peep.replace-with-f32-1 replace-with-f32-1_t30
# peep.replace-with-f64-1
# Trying csv/replace-with-f64-1_t30_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/replace-with-f64-1_t30_t30.snapshot.csv'
# Trying csv/replace-with-f64-1_t30_t5.snapshot.csv
# [Errno 2] No such file or directory: 'csv/replace-with-f64-1_t30_t5.snapshot.csv'
# >>>>> Zero count peep.replace-with-f64-1 replace-with-f64-1_t30
# peep.replace-with-v128-1
# Trying csv/replace-with-v128-1_t30_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/replace-with-v128-1_t30_t30.snapshot.csv'
# Trying csv/replace-with-v128-1_t30_t5.snapshot.csv
# [Errno 2] No such file or directory: 'csv/replace-with-v128-1_t30_t5.snapshot.csv'
# >>>>> Zero count peep.replace-with-v128-1 replace-with-v128-1_t30
# peep.replace-with-i32.rand
# Trying csv/replace-with-i32.rand_t30_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/replace-with-i32.rand_t30_t30.snapshot.csv'
# Trying csv/replace-with-i32.rand_t30_t5.snapshot.csv
# [Errno 2] No such file or directory: 'csv/replace-with-i32.rand_t30_t5.snapshot.csv'
# >>>>> Zero count peep.replace-with-i32.rand replace-with-i32.rand_t30
# peep.replace-with-i64.rand
# Trying csv/replace-with-i64.rand_t30.snapshot.csv
# Trying csv/replace-with-i64.rand_t5.snapshot.csv
# >>>>> Zero count peep.replace-with-i64.rand replace-with-i64.rand
# peep.replace-with-f32.rand
# Trying csv/replace-with-f32.rand_t30.snapshot.csv
# Trying csv/replace-with-f32.rand_t5.snapshot.csv
# >>>>> Zero count peep.replace-with-f32.rand replace-with-f32.rand
# peep.replace-with-f64.rand
# Trying csv/replace-with-f64.rand_t30.snapshot.csv
# Trying csv/replace-with-f64.rand_t5.snapshot.csv
# >>>>> Zero count peep.replace-with-f64.rand replace-with-f64.rand
# peep.replace-with-ref-null-func
# Trying csv/replace-with-ref-null-func_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/replace-with-ref-null-func_t30.snapshot.csv'
# Trying csv/replace-with-ref-null-func_t5.snapshot.csv
# >>>>> Zero count peep.replace-with-ref-null-func replace-with-ref-null-func
# peep.replace-with-ref-null-extern
# Trying csv/replace-with-ref-null-extern_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/replace-with-ref-null-extern_t30.snapshot.csv'
# Trying csv/replace-with-ref-null-extern_t5.snapshot.csv
# >>>>> Zero count peep.replace-with-ref-null-extern replace-with-ref-null-extern
# peep.remove-drop
# Trying csv/remove-drop_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/remove-drop_t30.snapshot.csv'
# Trying csv/remove-drop_t5.snapshot.csv
# >>>>> Zero count peep.remove-drop remove-drop
# peep.remove-nop
# Trying csv/remove-nop_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/remove-nop_t30.snapshot.csv'
# Trying csv/remove-nop_t5.snapshot.csv
# >>>>> Zero count peep.remove-nop remove-nop
# peep.remove-global.set.0
# Trying csv/remove-global.set.0_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/remove-global.set.0_t30.snapshot.csv'
# Trying csv/remove-global.set.0_t5.snapshot.csv
# >>>>> Zero count peep.remove-global.set.0 remove-global.set.0
# peep.remove-global.set.1
# Trying csv/remove-global.set.1_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/remove-global.set.1_t30.snapshot.csv'
# Trying csv/remove-global.set.1_t5.snapshot.csv
# >>>>> Zero count peep.remove-global.set.1 remove-global.set.1
# peep.remove-elem.drop.0
# Trying csv/remove-elem.drop.0_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/remove-elem.drop.0_t30.snapshot.csv'
# Trying csv/remove-elem.drop.0_t5.snapshot.csv
# >>>>> Zero count peep.remove-elem.drop.0 remove-elem.drop.0
# peep.remove-elem.drop.1
# Trying csv/remove-elem.drop.1_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/remove-elem.drop.1_t30.snapshot.csv'
# Trying csv/remove-elem.drop.1_t5.snapshot.csv
# >>>>> Zero count peep.remove-elem.drop.1 remove-elem.drop.1
# peep.remove-data.drop.0
# Trying csv/remove-data.drop.0_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/remove-data.drop.0_t30.snapshot.csv'
# Trying csv/remove-data.drop.0_t5.snapshot.csv
# >>>>> Zero count peep.remove-data.drop.0 remove-data.drop.0
# peep.remove-data.drop.1
# Trying csv/remove-data.drop.1_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/remove-data.drop.1_t30.snapshot.csv'
# Trying csv/remove-data.drop.1_t5.snapshot.csv
# >>>>> Zero count peep.remove-data.drop.1 remove-data.drop.1
# peep.i32.add-1
# Trying csv/i32.add-1_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/i32.add-1_t30.snapshot.csv'
# Trying csv/i32.add-1_t5.snapshot.csv
# >>>>> Zero count peep.i32.add-1 i32.add-1
# peep.i64.add-1
# Trying csv/i64.add-1_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/i64.add-1_t30.snapshot.csv'
# Trying csv/i64.add-1_t5.snapshot.csv
# >>>>> Zero count peep.i64.add-1 i64.add-1
# peep.i32.sub-1
# Trying csv/i32.sub-1_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/i32.sub-1_t30.snapshot.csv'
# Trying csv/i32.sub-1_t5.snapshot.csv
# >>>>> Zero count peep.i32.sub-1 i32.sub-1
# peep.i64.sub-1
# Trying csv/i64.sub-1_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/i64.sub-1_t30.snapshot.csv'
# Trying csv/i64.sub-1_t5.snapshot.csv
# >>>>> Zero count peep.i64.sub-1 i64.sub-1
# peep.i32.and-1
# Trying csv/i32.and-1_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/i32.and-1_t30.snapshot.csv'
# Trying csv/i32.and-1_t5.snapshot.csv
# >>>>> Zero count peep.i32.and-1 i32.and-1
# peep.i64.and-1
# Trying csv/i64.and-1_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/i64.and-1_t30.snapshot.csv'
# Trying csv/i64.and-1_t5.snapshot.csv
# >>>>> Zero count peep.i64.and-1 i64.and-1
# peep.i32.or-1
# Trying csv/i32.or-1_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/i32.or-1_t30.snapshot.csv'
# Trying csv/i32.or-1_t5.snapshot.csv
# >>>>> Zero count peep.i32.or-1 i32.or-1
# peep.i64.or-1
# Trying csv/i64.or-1_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/i64.or-1_t30.snapshot.csv'
# Trying csv/i64.or-1_t5.snapshot.csv
# >>>>> Zero count peep.i64.or-1 i64.or-1
# peep.i32.xor-1
# Trying csv/i32.xor-1_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/i32.xor-1_t30.snapshot.csv'
# Trying csv/i32.xor-1_t5.snapshot.csv
# >>>>> Zero count peep.i32.xor-1 i32.xor-1
# peep.i64.xor-1
# Trying csv/i64.xor-1_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/i64.xor-1_t30.snapshot.csv'
# Trying csv/i64.xor-1_t5.snapshot.csv
# >>>>> Zero count peep.i64.xor-1 i64.xor-1
# peep.i32.shl-1
# Trying csv/i32.shl-1_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/i32.shl-1_t30.snapshot.csv'
# Trying csv/i32.shl-1_t5.snapshot.csv
# >>>>> Zero count peep.i32.shl-1 i32.shl-1
# peep.i64.shl-1
# Trying csv/i64.shl-1_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/i64.shl-1_t30.snapshot.csv'
# Trying csv/i64.shl-1_t5.snapshot.csv
# >>>>> Zero count peep.i64.shl-1 i64.shl-1
# peep.i32.shr_u-1
# Trying csv/i32.shr_u-1_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/i32.shr_u-1_t30.snapshot.csv'
# Trying csv/i32.shr_u-1_t5.snapshot.csv
# >>>>> Zero count peep.i32.shr_u-1 i32.shr_u-1
# peep.i64.shr_u-1
# Trying csv/i64.shr_u-1_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/i64.shr_u-1_t30.snapshot.csv'
# Trying csv/i64.shr_u-1_t5.snapshot.csv
# >>>>> Zero count peep.i64.shr_u-1 i64.shr_u-1
# peep.i32.shr_s-1
# Trying csv/i32.shr_s-1_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/i32.shr_s-1_t30.snapshot.csv'
# Trying csv/i32.shr_s-1_t5.snapshot.csv
# >>>>> Zero count peep.i32.shr_s-1 i32.shr_s-1
# peep.i64.shr_s-1
# Trying csv/i64.shr_s-1_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/i64.shr_s-1_t30.snapshot.csv'
# Trying csv/i64.shr_s-1_t5.snapshot.csv
# >>>>> Zero count peep.i64.shr_s-1 i64.shr_s-1
# code_motion_ifs
# code_motion_loops
# add_function
# add_type
# modify_custom_section
# modify_custom_section_name
# modify_custom_section_data
# function_body_unreachable
# Trying csv/function_body_unreachable_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/function_body_unreachable_t30.snapshot.csv'
# Trying csv/function_body_unreachable_t5.snapshot.csv
# [Errno 2] No such file or directory: 'csv/function_body_unreachable_t5.snapshot.csv'
# >>>>> Zero count function_body_unreachable function_body_unreachable
# modify_data
# Trying csv/modify_data_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/modify_data_t30.snapshot.csv'
# Trying csv/modify_data_t5.snapshot.csv
# [Errno 2] No such file or directory: 'csv/modify_data_t5.snapshot.csv'
# >>>>> Zero count modify_data modify_data
# modify_init_exprs
# Trying csv/modify_init_exprs_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/modify_init_exprs_t30.snapshot.csv'
# Trying csv/modify_init_exprs_t5.snapshot.csv
# [Errno 2] No such file or directory: 'csv/modify_init_exprs_t5.snapshot.csv'
# >>>>> Zero count modify_init_exprs modify_init_exprs
# remove_exports
# Trying csv/remove_exports_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/remove_exports_t30.snapshot.csv'
# Trying csv/remove_exports_t5.snapshot.csv
# [Errno 2] No such file or directory: 'csv/remove_exports_t5.snapshot.csv'
# >>>>> Zero count remove_exports remove_exports
# remove_item_function
# Trying csv/remove_item_function_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/remove_item_function_t30.snapshot.csv'
# Trying csv/remove_item_function_t5.snapshot.csv
# Taking _t5.snapshot for remove_item_function
# remove_item_table
# remove_item_memory
# remove_item_global
# remove_item_tag
# Trying csv/remove_item_tag_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/remove_item_tag_t30.snapshot.csv'
# Trying csv/remove_item_tag_t5.snapshot.csv
# [Errno 2] No such file or directory: 'csv/remove_item_tag_t5.snapshot.csv'
# >>>>> Zero count remove_item_tag remove_item_tag
# remove_item_type
# remove_item_data
# Trying csv/remove_item_data_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/remove_item_data_t30.snapshot.csv'
# Trying csv/remove_item_data_t5.snapshot.csv
# [Errno 2] No such file or directory: 'csv/remove_item_data_t5.snapshot.csv'
# >>>>> Zero count remove_item_data remove_item_data
# remove_item_element
# Trying csv/remove_item_element_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/remove_item_element_t30.snapshot.csv'
# Trying csv/remove_item_element_t5.snapshot.csv
# [Errno 2] No such file or directory: 'csv/remove_item_element_t5.snapshot.csv'
# >>>>> Zero count remove_item_element remove_item_element
# rename_exports
# Trying csv/rename_exports_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/rename_exports_t30.snapshot.csv'
# Trying csv/rename_exports_t5.snapshot.csv
# [Errno 2] No such file or directory: 'csv/rename_exports_t5.snapshot.csv'
# >>>>> Zero count rename_exports rename_exports
# snip_function
# Trying csv/snip_function_t30.snapshot.csv
# [Errno 2] No such file or directory: 'csv/snip_function_t30.snapshot.csv'
# Trying csv/snip_function_t5.snapshot.csv
# [Errno 2] No such file or directory: 'csv/snip_function_t5.snapshot.csv'
# >>>>> Zero count snip_function snip_function

# %%
display(alldf)
# Out:
#                                                     num_tags  num_functions  \
# id
# 00008799c04b4f111d28331ef77c387fb2bd6724c9ce88a...         0             19
# 000415b2639c960e039299fde2a52e7e9c692c212c1fa6c...         0             37
# 000e01741a75cf7a3d9afc0f4950c220c67188a7c1434bb...         0             72
# 00189ff4eeb814ffa662649ba6859c004036580fccc2b83...         0             37
# 0018e8f82de999af365dfc57d0bbe06d5d08eaf791d31f5...         0             25
# ...                                                      ...            ...
# ffc74ca2c5ca93aefa0a7e7e0f2b73fa04f82ef95f52de4...         0          13354
# ffd880b33124a740f739dda080d1969280ea4d6c1772f4d...         0             73
# ffe3c93afa93da108768ccbc6ae0fdf0a493f3177e3164b...         0              4
# ffef41ae6c4f9c9db558585637e941c5a0338e28e6e6643...         0             65
# fff1b66b5ad54eb13c66a795797d406b6e787b4b1eadef2...         0             24
#
#                                                     num_globals  num_tables  \
# id
# 00008799c04b4f111d28331ef77c387fb2bd6724c9ce88a...            3           1
# 000415b2639c960e039299fde2a52e7e9c692c212c1fa6c...            6           0
# 000e01741a75cf7a3d9afc0f4950c220c67188a7c1434bb...           27           1
# 00189ff4eeb814ffa662649ba6859c004036580fccc2b83...            0           1
# 0018e8f82de999af365dfc57d0bbe06d5d08eaf791d31f5...            0           1
# ...                                                         ...         ...
# ffc74ca2c5ca93aefa0a7e7e0f2b73fa04f82ef95f52de4...            9           0
# ffd880b33124a740f739dda080d1969280ea4d6c1772f4d...           27           1
# ffe3c93afa93da108768ccbc6ae0fdf0a493f3177e3164b...            1           1
# ffef41ae6c4f9c9db558585637e941c5a0338e28e6e6643...           19           0
# fff1b66b5ad54eb13c66a795797d406b6e787b4b1eadef2...            3           1
#
#                                                     num_elements  num_data  \
# id
# 00008799c04b4f111d28331ef77c387fb2bd6724c9ce88a...             1         0
# 000415b2639c960e039299fde2a52e7e9c692c212c1fa6c...             1         0
# 000e01741a75cf7a3d9afc0f4950c220c67188a7c1434bb...             1         0
# 00189ff4eeb814ffa662649ba6859c004036580fccc2b83...             1         0
# 0018e8f82de999af365dfc57d0bbe06d5d08eaf791d31f5...             1         0
# ...                                                          ...       ...
# ffc74ca2c5ca93aefa0a7e7e0f2b73fa04f82ef95f52de4...             1         0
# ffd880b33124a740f739dda080d1969280ea4d6c1772f4d...             1         0
# ffe3c93afa93da108768ccbc6ae0fdf0a493f3177e3164b...             0         0
# ffef41ae6c4f9c9db558585637e941c5a0338e28e6e6643...             1         0
# fff1b66b5ad54eb13c66a795797d406b6e787b4b1eadef2...             1         0
#
#                                                     num_types  num_memory  \
# id
# 00008799c04b4f111d28331ef77c387fb2bd6724c9ce88a...         10           1
# 000415b2639c960e039299fde2a52e7e9c692c212c1fa6c...         10           0
# 000e01741a75cf7a3d9afc0f4950c220c67188a7c1434bb...         16           1
# 00189ff4eeb814ffa662649ba6859c004036580fccc2b83...         19           1
# 0018e8f82de999af365dfc57d0bbe06d5d08eaf791d31f5...         11           1
# ...                                                       ...         ...
# ffc74ca2c5ca93aefa0a7e7e0f2b73fa04f82ef95f52de4...        190           0
# ffd880b33124a740f739dda080d1969280ea4d6c1772f4d...         17           1
# ffe3c93afa93da108768ccbc6ae0fdf0a493f3177e3164b...          6           1
# ffef41ae6c4f9c9db558585637e941c5a0338e28e6e6643...         16           0
# fff1b66b5ad54eb13c66a795797d406b6e787b4b1eadef2...         17           1
#
#                                                     num_instructions  \
# id
# 00008799c04b4f111d28331ef77c387fb2bd6724c9ce88a...              1751
# 000415b2639c960e039299fde2a52e7e9c692c212c1fa6c...             28339
# 000e01741a75cf7a3d9afc0f4950c220c67188a7c1434bb...             14859
# 00189ff4eeb814ffa662649ba6859c004036580fccc2b83...              5313
# 0018e8f82de999af365dfc57d0bbe06d5d08eaf791d31f5...              2454
# ...                                                              ...
# ffc74ca2c5ca93aefa0a7e7e0f2b73fa04f82ef95f52de4...            903659
# ffd880b33124a740f739dda080d1969280ea4d6c1772f4d...             14615
# ffe3c93afa93da108768ccbc6ae0fdf0a493f3177e3164b...               224
# ffef41ae6c4f9c9db558585637e941c5a0338e28e6e6643...             18276
# fff1b66b5ad54eb13c66a795797d406b6e787b4b1eadef2...              2512
#
#                                                    class_name  ...  \
# id                                                             ...
# 00008799c04b4f111d28331ef77c387fb2bd6724c9ce88a...       none  ...
# 000415b2639c960e039299fde2a52e7e9c692c212c1fa6c...       none  ...
# 000e01741a75cf7a3d9afc0f4950c220c67188a7c1434bb...       none  ...
# 00189ff4eeb814ffa662649ba6859c004036580fccc2b83...       none  ...
# 0018e8f82de999af365dfc57d0bbe06d5d08eaf791d31f5...       none  ...
# ...                                                       ...  ...
# ffc74ca2c5ca93aefa0a7e7e0f2b73fa04f82ef95f52de4...       none  ...
# ffd880b33124a740f739dda080d1969280ea4d6c1772f4d...       none  ...
# ffe3c93afa93da108768ccbc6ae0fdf0a493f3177e3164b...       none  ...
# ffef41ae6c4f9c9db558585637e941c5a0338e28e6e6643...       none  ...
# fff1b66b5ad54eb13c66a795797d406b6e787b4b1eadef2...       none  ...
#
#                                                     peep.i64.mul_1  \
# id
# 00008799c04b4f111d28331ef77c387fb2bd6724c9ce88a...            True
# 000415b2639c960e039299fde2a52e7e9c692c212c1fa6c...            True
# 000e01741a75cf7a3d9afc0f4950c220c67188a7c1434bb...            True
# 00189ff4eeb814ffa662649ba6859c004036580fccc2b83...            True
# 0018e8f82de999af365dfc57d0bbe06d5d08eaf791d31f5...            True
# ...                                                            ...
# ffc74ca2c5ca93aefa0a7e7e0f2b73fa04f82ef95f52de4...            True
# ffd880b33124a740f739dda080d1969280ea4d6c1772f4d...            True
# ffe3c93afa93da108768ccbc6ae0fdf0a493f3177e3164b...            True
# ffef41ae6c4f9c9db558585637e941c5a0338e28e6e6643...            True
# fff1b66b5ad54eb13c66a795797d406b6e787b4b1eadef2...            True
#
#                                                     peep.i32.mul_1  \
# id
# 00008799c04b4f111d28331ef77c387fb2bd6724c9ce88a...           False
# 000415b2639c960e039299fde2a52e7e9c692c212c1fa6c...           False
# 000e01741a75cf7a3d9afc0f4950c220c67188a7c1434bb...           False
# 00189ff4eeb814ffa662649ba6859c004036580fccc2b83...           False
# 0018e8f82de999af365dfc57d0bbe06d5d08eaf791d31f5...            True
# ...                                                            ...
# ffc74ca2c5ca93aefa0a7e7e0f2b73fa04f82ef95f52de4...           False
# ffd880b33124a740f739dda080d1969280ea4d6c1772f4d...           False
# ffe3c93afa93da108768ccbc6ae0fdf0a493f3177e3164b...           False
# ffef41ae6c4f9c9db558585637e941c5a0338e28e6e6643...            True
# fff1b66b5ad54eb13c66a795797d406b6e787b4b1eadef2...            True
#
#                                                     peep.i32.sub_zero  \
# id
# 00008799c04b4f111d28331ef77c387fb2bd6724c9ce88a...               True
# 000415b2639c960e039299fde2a52e7e9c692c212c1fa6c...               True
# 000e01741a75cf7a3d9afc0f4950c220c67188a7c1434bb...               True
# 00189ff4eeb814ffa662649ba6859c004036580fccc2b83...               True
# 0018e8f82de999af365dfc57d0bbe06d5d08eaf791d31f5...               True
# ...                                                               ...
# ffc74ca2c5ca93aefa0a7e7e0f2b73fa04f82ef95f52de4...               True
# ffd880b33124a740f739dda080d1969280ea4d6c1772f4d...               True
# ffe3c93afa93da108768ccbc6ae0fdf0a493f3177e3164b...               True
# ffef41ae6c4f9c9db558585637e941c5a0338e28e6e6643...               True
# fff1b66b5ad54eb13c66a795797d406b6e787b4b1eadef2...               True
#
#                                                     peep.select_same_branches  \
# id
# 00008799c04b4f111d28331ef77c387fb2bd6724c9ce88a...                      False
# 000415b2639c960e039299fde2a52e7e9c692c212c1fa6c...                      False
# 000e01741a75cf7a3d9afc0f4950c220c67188a7c1434bb...                      False
# 00189ff4eeb814ffa662649ba6859c004036580fccc2b83...                      False
# 0018e8f82de999af365dfc57d0bbe06d5d08eaf791d31f5...                      False
# ...                                                                       ...
# ffc74ca2c5ca93aefa0a7e7e0f2b73fa04f82ef95f52de4...                      False
# ffd880b33124a740f739dda080d1969280ea4d6c1772f4d...                      False
# ffe3c93afa93da108768ccbc6ae0fdf0a493f3177e3164b...                      False
# ffef41ae6c4f9c9db558585637e941c5a0338e28e6e6643...                      False
# fff1b66b5ad54eb13c66a795797d406b6e787b4b1eadef2...                      False
#
#                                                     peep.i64.operator_and_commutative  \
# id
# 00008799c04b4f111d28331ef77c387fb2bd6724c9ce88a...                               True
# 000415b2639c960e039299fde2a52e7e9c692c212c1fa6c...                               True
# 000e01741a75cf7a3d9afc0f4950c220c67188a7c1434bb...                               True
# 00189ff4eeb814ffa662649ba6859c004036580fccc2b83...                               True
# 0018e8f82de999af365dfc57d0bbe06d5d08eaf791d31f5...                               True
# ...                                                                               ...
# ffc74ca2c5ca93aefa0a7e7e0f2b73fa04f82ef95f52de4...                               True
# ffd880b33124a740f739dda080d1969280ea4d6c1772f4d...                               True
# ffe3c93afa93da108768ccbc6ae0fdf0a493f3177e3164b...                               True
# ffef41ae6c4f9c9db558585637e941c5a0338e28e6e6643...                               True
# fff1b66b5ad54eb13c66a795797d406b6e787b4b1eadef2...                               True
#
#                                                     peep.i32.operator_and_commutative  \
# id
# 00008799c04b4f111d28331ef77c387fb2bd6724c9ce88a...                               True
# 000415b2639c960e039299fde2a52e7e9c692c212c1fa6c...                               True
# 000e01741a75cf7a3d9afc0f4950c220c67188a7c1434bb...                               True
# 00189ff4eeb814ffa662649ba6859c004036580fccc2b83...                               True
# 0018e8f82de999af365dfc57d0bbe06d5d08eaf791d31f5...                               True
# ...                                                                               ...
# ffc74ca2c5ca93aefa0a7e7e0f2b73fa04f82ef95f52de4...                               True
# ffd880b33124a740f739dda080d1969280ea4d6c1772f4d...                               True
# ffe3c93afa93da108768ccbc6ae0fdf0a493f3177e3164b...                               True
# ffef41ae6c4f9c9db558585637e941c5a0338e28e6e6643...                               True
# fff1b66b5ad54eb13c66a795797d406b6e787b4b1eadef2...                               True
#
#                                                     peep.i64.operator_or_commutative  \
# id
# 00008799c04b4f111d28331ef77c387fb2bd6724c9ce88a...                              True
# 000415b2639c960e039299fde2a52e7e9c692c212c1fa6c...                              True
# 000e01741a75cf7a3d9afc0f4950c220c67188a7c1434bb...                              True
# 00189ff4eeb814ffa662649ba6859c004036580fccc2b83...                              True
# 0018e8f82de999af365dfc57d0bbe06d5d08eaf791d31f5...                              True
# ...                                                                              ...
# ffc74ca2c5ca93aefa0a7e7e0f2b73fa04f82ef95f52de4...                              True
# ffd880b33124a740f739dda080d1969280ea4d6c1772f4d...                              True
# ffe3c93afa93da108768ccbc6ae0fdf0a493f3177e3164b...                              True
# ffef41ae6c4f9c9db558585637e941c5a0338e28e6e6643...                              True
# fff1b66b5ad54eb13c66a795797d406b6e787b4b1eadef2...                              True
#
#                                                     peep.i32.operator_or_commutative  \
# id
# 00008799c04b4f111d28331ef77c387fb2bd6724c9ce88a...                              True
# 000415b2639c960e039299fde2a52e7e9c692c212c1fa6c...                              True
# 000e01741a75cf7a3d9afc0f4950c220c67188a7c1434bb...                              True
# 00189ff4eeb814ffa662649ba6859c004036580fccc2b83...                              True
# 0018e8f82de999af365dfc57d0bbe06d5d08eaf791d31f5...                              True
# ...                                                                              ...
# ffc74ca2c5ca93aefa0a7e7e0f2b73fa04f82ef95f52de4...                              True
# ffd880b33124a740f739dda080d1969280ea4d6c1772f4d...                              True
# ffe3c93afa93da108768ccbc6ae0fdf0a493f3177e3164b...                              True
# ffef41ae6c4f9c9db558585637e941c5a0338e28e6e6643...                              True
# fff1b66b5ad54eb13c66a795797d406b6e787b4b1eadef2...                              True
#
#                                                     peep.i32.operator_or_neg_one1  \
# id
# 00008799c04b4f111d28331ef77c387fb2bd6724c9ce88a...                          False
# 000415b2639c960e039299fde2a52e7e9c692c212c1fa6c...                          False
# 000e01741a75cf7a3d9afc0f4950c220c67188a7c1434bb...                          False
# 00189ff4eeb814ffa662649ba6859c004036580fccc2b83...                          False
# 0018e8f82de999af365dfc57d0bbe06d5d08eaf791d31f5...                          False
# ...                                                                           ...
# ffc74ca2c5ca93aefa0a7e7e0f2b73fa04f82ef95f52de4...                          False
# ffd880b33124a740f739dda080d1969280ea4d6c1772f4d...                          False
# ffe3c93afa93da108768ccbc6ae0fdf0a493f3177e3164b...                          False
# ffef41ae6c4f9c9db558585637e941c5a0338e28e6e6643...                          False
# fff1b66b5ad54eb13c66a795797d406b6e787b4b1eadef2...                          False
#
#                                                     peep.i32.operator_or_neg1
# id
# 00008799c04b4f111d28331ef77c387fb2bd6724c9ce88a...                      False
# 000415b2639c960e039299fde2a52e7e9c692c212c1fa6c...                      False
# 000e01741a75cf7a3d9afc0f4950c220c67188a7c1434bb...                      False
# 00189ff4eeb814ffa662649ba6859c004036580fccc2b83...                      False
# 0018e8f82de999af365dfc57d0bbe06d5d08eaf791d31f5...                      False
# ...                                                                       ...
# ffc74ca2c5ca93aefa0a7e7e0f2b73fa04f82ef95f52de4...                      False
# ffd880b33124a740f739dda080d1969280ea4d6c1772f4d...                      False
# ffe3c93afa93da108768ccbc6ae0fdf0a493f3177e3164b...                      False
# ffef41ae6c4f9c9db558585637e941c5a0338e28e6e6643...                      False
# fff1b66b5ad54eb13c66a795797d406b6e787b4b1eadef2...                      False
#
# [8461 rows x 145 columns]

# %%
import random



features = [('peep.i32.operator_or_neg1', 'i32.operator_or_neg1'), 
         ('peep.i32.operator_or_neg_one1', 'i32.operator_or_neg_one1'), 
         ('peep.i32.operator_or_commutative', 'i32.operator_or_commutative'), 
         ('peep.i64.operator_or_commutative', 'i64.operator_or_commutative'), 
         ('peep.i32.operator_and_commutative', 'i32.operator_and_commutative'), 
         ('peep.i64.operator_and_commutative', 'i64.operator_and_commutative'), 
         ('peep.select_same_branches', 'select_same_branches'), 
         ('peep.i32.sub_zero', 'i32.sub_zero'), 
         ('peep.i32.mul_1', 'i32.mul_1_t5.snapshot'), 
         ('peep.i64.mul_1', 'i64.mul_1'), 
         ('peep.f32.mul_1', 'f32.mul_1'), 
         ('peep.f64.mul_1', 'f64.mul_1'), 
         ('peep.i32.add_0', 'i32.add_0'), 
         ('peep.i64.add_0', 'i64.add_0'), 
         ('peep.f32.add_0', 'f32.add_0'), 
         ('peep.f64.add_0', 'f64.add_0'), 
         ('peep.i32.xor_0', 'i32.xor_0'), 
         ('peep.i64.xor_0', 'i64.xor_0'), 
         ('peep.i32.eq_0', 'i32.eq_0'),
         ('peep.i64.eq_0', 'i64.eq_0'), 
         ('peep.i32.shl_by_0', 'i32.shl_by_0'), 
         ('peep.i64.shl_by_0', 'i64.shl_by_0'), 
         ('peep.i32.shr_u_by_0', 'i32.shr_u_by_0'), 
         ('peep.i64.shr_u_by_0', 'i64.shr_u_by_0'), 
         ('peep.i32.shr_s_by_0', 'i32.shr_s_by_0'), 
         ('peep.i64.shr_s_by_0', 'i64.shr_s_by_0'), 
         ('peep.i64.operator_or_neg1', 'i64.operator_or_neg1'), 
         ('peep.i64.sub_zero', 'i64.sub_zero'), 
         ('peep.i32.add-commutes', 'i32.add-commutes'), 
         ('peep.i64.add-commutes', 'i64.add-commutes'), 
         ('peep.f32.add-commutes', 'f32.add-commutes'), 
         ('peep.f64.add-commutes', 'f64.add-commutes'), 
         ('peep.i32.mul-commutes', 'i32.mul-commutes'), 
         ('peep.i64.mul-commutes', 'i64.mul-commutes'), 
         ('peep.f32.mul-commutes', 'f32.mul-commutes'), 
         ('peep.f64.mul-commutes', 'f64.mul-commutes'), 
         ('peep.i32.and-commutes', 'i32.and-commutes'), 
         ('peep.i64.and-commutes', 'i64.and-commutes'), 
         ('peep.i32.or-commutes', 'i32.or-commutes'), 
         ('peep.i64.or-commutes', 'i64.or-commutes'), 
         ('peep.i32.xor-commutes', 'i32.xor-commutes'), 
         ('peep.i64.xor-commutes', 'i64.xor-commutes'), 
         ('peep.i32.eq-commutes', 'i32.eq-commutes'), 
         ('peep.i64.eq-commutes', 'i64.eq-commutes'), 
         ('peep.i32.mul-associates', 'i32.mul-associates'), 
         ('peep.i64.mul-associates', 'i64.mul-associates'), 
         ('peep.i32.add-associates', 'i32.add-associates'), 
         ('peep.i32.and-associates', 'i32.and-associates'), 
         ('peep.i32.or-associates', 'i32.or-associates'), 
         ('peep.i64.or-associates', 'i64.or-associates'), 
         ('peep.i32.xor-associates', 'i32.xor-associates'), 
         ('peep.i64.xor-associates', 'i64.xor-associates'), 
         ('peep.i32.eq-associates', 'i32.eq-associates'), 
         ('peep.i64.eq-associates', 'i64.eq-associates'), 
         ('peep.i32.mul-by-2', 'i32.mul-by-2'), 
         ('peep.i64.mul-by-2', 'i64.mul-by-2'), 
         ('peep.i32.mul-by-4', 'i32.mul-by-4'), 
         ('peep.i64.mul-by-4', 'i64.mul-by-4'), 
         ('peep.i32.mul-by-8', 'i32.mul-by-8'), 
         ('peep.i64.mul-by-8', 'i64.mul-by-8'), 
         ('peep.select-invert', 'select-invert'), 
         ('peep.i32.add-x-x', 'i32.add-x-x'), 
         ('peep.i64.add-x-x', 'i64.add-x-x'), 
         ('peep.i32.drop-x', 'i32.drop-x'), 
         ('peep.i64.drop-x', 'i64.drop-x'), 
         ('peep.f32.drop-x', 'f32.drop-x'), 
         ('peep.f64.drop-x', 'f64.drop-x'), 
         ('peep.container-nop-x', 'container-nop-x'), 
         ('peep.container-x-nop', 'container-x-nop'), 
         ('peep.container-drop-i32.rand-x', 'container-drop-i32.rand-x'), 
         ('peep.container-drop-i64.rand-x', 'container-drop-i64.rand-x'), 
         ('peep.container-x-drop-i32.rand', 'container-x-drop-i32.rand'), 
         ('peep.container-x-drop-i64.rand', 'container-x-drop-i64.rand'), 
         ('peep.i32.use_of_global', 'i32.use_of_global'), 
         ('peep.i64.use_of_global', 'i64.use_of_global'), 
         ('peep.f32.use_of_global', 'f32.use_of_global'), 
         ('peep.f64.use_of_global', 'f64.use_of_global'), 
         ('peep.i32.unfold', 'i32.unfold'), 
         ('peep.i64.unfold', 'i64.unfold'), 
         ('peep.replace-with-i32-1', 'replace-with-i32-1'), 
         ('peep.replace-with-i64-1', 'replace-with-i64-1'),
         ('peep.replace-with-f32-1', 'replace-with-f32-1_t30'), 
         ('peep.replace-with-f64-1', 'replace-with-f64-1_t30'), 
         ('peep.replace-with-v128-1', 'replace-with-v128-1_t30'), 
         ('peep.replace-with-i32.rand', 'replace-with-i32.rand_t30'), 
         ('peep.replace-with-i64.rand', 'replace-with-i64.rand'), 
         ('peep.replace-with-f32.rand', 'replace-with-f32.rand'), 
         ('peep.replace-with-f64.rand', 'replace-with-f64.rand'), 
         ('peep.replace-with-ref-null-func', 'replace-with-ref-null-func'), 
         ('peep.replace-with-ref-null-extern', 'replace-with-ref-null-extern'), 
         ('peep.remove-drop', 'remove-drop'), 
         ('peep.remove-nop', 'remove-nop'), 
         ('peep.remove-global.set.0', 'remove-global.set.0'), 
         ('peep.remove-global.set.1', 'remove-global.set.1'), 
         ('peep.remove-elem.drop.0', 'remove-elem.drop.0'), 
         ('peep.remove-elem.drop.1', 'remove-elem.drop.1'), 
         ('peep.remove-data.drop.0', 'remove-data.drop.0'), 
         ('peep.remove-data.drop.1', 'remove-data.drop.1'), 
         ('peep.i32.add-1', 'i32.add-1'), 
         ('peep.i64.add-1', 'i64.add-1'), 
         ('peep.i32.sub-1', 'i32.sub-1'), 
         ('peep.i64.sub-1', 'i64.sub-1'), 
         ('peep.i32.and-1', 'i32.and-1'), 
         ('peep.i64.and-1', 'i64.and-1'), 
         ('peep.i32.or-1', 'i32.or-1'), 
         ('peep.i64.or-1', 'i64.or-1'), 
         ('peep.i32.xor-1', 'i32.xor-1'), 
         ('peep.i64.xor-1', 'i64.xor-1'), 
         ('peep.i32.shl-1', 'i32.shl-1'), 
         ('peep.i64.shl-1', 'i64.shl-1'), 
         ('peep.i32.shr_u-1', 'i32.shr_u-1'), 
         ('peep.i64.shr_u-1', 'i64.shr_u-1'), 
         ('peep.i32.shr_s-1', 'i32.shr_s-1'), 
         ('peep.i64.shr_s-1', 'i64.shr_s-1'), 
         ('code_motion_ifs', 'code_motion_ifs'), 
         ('code_motion_loops', 'code_motion_loops'), 
         ('add_function', 'add_function'), 
         ('add_type', 'add_type'), 
         ('modify_custom_section', 'modify_custom_section_name'), 
         ('modify_custom_section_name', 'modify_custom_section_name'), 
         ('modify_custom_section_data', 'modify_custom_section_data'), 
         ('function_body_unreachable', 'function_body_unreachable'), 
         ('modify_data', 'modify_data'), 
         ('modify_init_exprs', 'modify_init_exprs'), 
         ('remove_exports', 'remove_exports'), 
         ('remove_item_function', 'remove_item_function'), 
         ('remove_item_table', 'remove_item_table'), 
         ('remove_item_memory', 'remove_item_memory'), 
         ('remove_item_global', 'remove_item_global'), 
         ('remove_item_tag', 'remove_item_tag'), 
         ('remove_item_type', 'remove_item_type'), 
         ('remove_item_data', 'remove_item_data'), 
         ('remove_item_element', 'remove_item_element'), 
         ('rename_exports', 'rename_exports'), 
         ('snip_function', 'snip_function')]


def all_combinations(features, r, cb):
    
    if len(features) == 0:
        cb(r)
    else:
        l = features[0]
        tail = [x for x in features[1:]]
        all_combinations(tail, r + [l], cb)
        all_combinations(tail, r, cb)
    

def get_uniform_x(count):
    
    r = []
    sets = []
    
    alla_filtered = [r for r in features]
    
    if count > 2**(len(alla_filtered)):
        # Filter ouur, there is not possible to get more than this number
        all_combinations(alla_filtered, [], lambda x: r.append([ y[1] for y in x ]))
        return r
        
    while len(r) < count:
        alla = [r[1] for r in features]
        selected = [] 
        
        for x in alla:
            n = random.random()
            if n <= 1/len(features):
                selected.append(x)
                
        selected = list(sorted(selected))
        if len(selected) > 0 and f"{selected}" not in sets:
            r.append(selected)
            sets.append(f"{selected}")
    
    return r

def get_uniform_x_filter_non_probable(frame, count):
    
    def is_probable(name):
        c = len(frame[frame[name] == True])
        return c > 0
    
    r = []
    sets = []
    alla_filtered = [r for r in features if is_probable(r[0])]
    
    print("Set size", len(alla_filtered))
    
    if count > 2**(len(alla_filtered)):
        # Filter ouur, there is not possible to get more than this number
        print("Setting the count to the max possible")
        all_combinations(alla_filtered, [], lambda x: r.append([ y[1] for y in x ]))
        return r
        
    
    while len(r) < count:
        alla = [r for r in alla_filtered]
        #print(alla)
        selected = [] 
        
        for x in alla:
            n = random.random()
            if n <= 1/len(features):
                selected.append(x)
                
        selected = list(sorted(selected))
        if len(selected) > 0 and f"{selected}" not in sets:
            r.append(selected)
            sets.append(f"{selected}")
    
    return r


def get_x_weight_by_applicability(frame, count, reverse = False):
    
    def weight(name):
        c1 = len(frame[frame[name] == True])
        c2 = len(frame)
        
        return (1 - c1/c2) if (reverse and c1 > 0) else c1/ c2
    
    r = []
    sets = []
    weights = {r[0]: weight(r[0]) for r in features }
    sumweights = sum(r for r in weights.values())
    print(weights)
    
    
    while len(r) < count:
        try:
            alla = [r for r in features]
            #print(alla)
            selected = [] 

            for x in alla:
                n = random.random()
                p_perfeature = weights[x[0]]
                p_weighted = p_perfeature/sumweights
                
                if n <= p_weighted:
                    selected.append(x)

            selected = list(sorted(selected))
            if len(selected) > 0 and f"{selected}" not in sets:
                r.append(selected)
                sets.append(f"{selected}")
        except KeyboardInterrupt:
            break
    return r

# %%
def print_to_compile(cfgs):
    
    for features in cfgs:
        
        print("--features", end=" ")
        print("'", end="")
        
        has_peep = False
        has_remo_item = False
        has_codemotion = False
        modify_custom_section = False
        
        for name, f in features:
            if "peep" in name:
                has_peep = True
            if "remove_item" in name:
                has_remo_item = True
            if "codemotion" in name:
                has_codemotion = True
            if "code_motion" in name:
                has_codemotion = True
            if "modify_custom_section" in name:
                modify_custom_section = True
            
            print(f"wasm-mutate/{f}", end=",")
        if has_peep:
            print(f"wasm-mutate/peep_hole,", end="")
        if has_remo_item:
            print(f"wasm-mutate/remove_item,", end="")
        if has_codemotion:
            print(f"wasm-mutate/code_motion,", end="")
        if modify_custom_section:
            print(f"wasm-mutate/modify_custom_section,", end="")
        print("\b'")

# %%
random.seed(10)
c2 = get_uniform_x_filter_non_probable(alldf, 300)


print_to_compile(c2)
# Out:
# Set size 88
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '

# %%
random.seed(10)

c2 = get_x_weight_by_applicability(alldf, 100, reverse=False)

print_to_compile(c2)
# Out:
# {'peep.i32.operator_or_neg1': 0.0020092187684670844, 'peep.i32.operator_or_neg_one1': 0.0, 'peep.i32.operator_or_commutative': 0.9888902021037702, 'peep.i64.operator_or_commutative': 0.882637986053658, 'peep.i32.operator_and_commutative': 0.9893629594610566, 'peep.i64.operator_and_commutative': 0.8819288500177284, 'peep.select_same_branches': 0.004018437536934169, 'peep.i32.sub_zero': 0.9891265807824134, 'peep.i32.mul_1': 0.22987826498049876, 'peep.i64.mul_1': 0.8801560099279045, 'peep.f32.mul_1': 0.2097860772958279, 'peep.f64.mul_1': 0.48847653941614466, 'peep.i32.add_0': 0.9881810660678407, 'peep.i64.add_0': 0.8801560099279045, 'peep.f32.add_0': 0.21439546152937006, 'peep.f64.add_0': 0.4897766221486822, 'peep.i32.xor_0': 0.989835716818343, 'peep.i64.xor_0': 0.88204703935705, 'peep.i32.eq_0': 0.9085214513650869, 'peep.i64.eq_0': 0.47110270653587044, 'peep.i32.shl_by_0': 0.9888902021037702, 'peep.i64.shl_by_0': 0.8807469566245125, 'peep.i32.shr_u_by_0': 0.9886538234251271, 'peep.i64.shr_u_by_0': 0.8806287672851909, 'peep.i32.shr_s_by_0': 0.9875901193712328, 'peep.i64.shr_s_by_0': 0.881456092660442, 'peep.i64.operator_or_neg1': 0.0, 'peep.i64.sub_zero': 0.8818106606784069, 'peep.i32.add-commutes': 0.9611157073631958, 'peep.i64.add-commutes': 0.69436236851436, 'peep.f32.add-commutes': 0.09644250088642005, 'peep.f64.add-commutes': 0.2708899657250916, 'peep.i32.mul-commutes': 0.8350076823070559, 'peep.i64.mul-commutes': 0.38446992081314263, 'peep.f32.mul-commutes': 0.1093251388724737, 'peep.f64.mul-commutes': 0.3351849663160383, 'peep.i32.and-commutes': 0.9027301737383288, 'peep.i64.and-commutes': 0.6716700153646141, 'peep.i32.or-commutes': 0.8508450537761494, 'peep.i64.or-commutes': 0.6539416144663751, 'peep.i32.xor-commutes': 0.5917740219832172, 'peep.i64.xor-commutes': 0.2720718591183075, 'peep.i32.eq-commutes': 0.8939841626285309, 'peep.i64.eq-commutes': 0.5117598392624986, 'peep.i32.mul-associates': 0.027419926722609622, 'peep.i64.mul-associates': 0.14631840208013236, 'peep.i32.add-associates': 0.843990072095497, 'peep.i32.and-associates': 0.11925304337548753, 'peep.i32.or-associates': 0.3819879446873892, 'peep.i64.or-associates': 0.08285072686443683, 'peep.i32.xor-associates': 0.04148445810187921, 'peep.i64.xor-associates': 0.04739392506795887, 'peep.i32.eq-associates': 0.0016546507505023047, 'peep.i64.eq-associates': 0.0, 'peep.i32.mul-by-2': 0.8014419099397234, 'peep.i64.mul-by-2': 0.1128708190521215, 'peep.i32.mul-by-4': 0.5466256943623685, 'peep.i64.mul-by-4': 0.053776149391324905, 'peep.i32.mul-by-8': 0.5874010164283182, 'peep.i64.mul-by-8': 0.05673088287436473, 'peep.select-invert': 0.6876255761730292, 'peep.i32.add-x-x': 0.007564117716581964, 'peep.i64.add-x-x': 0.018319347594846946, 'peep.i32.drop-x': 0.6071386360950243, 'peep.i64.drop-x': 0.005318520269471693, 'peep.f32.drop-x': 0.008273253752511523, 'peep.f64.drop-x': 0.006500413662687625, 'peep.container-nop-x': 0.9992908639640704, 'peep.container-x-nop': 0.9888902021037702, 'peep.container-drop-i32.rand-x': 0.11405271244533743, 'peep.container-drop-i64.rand-x': 0.11405271244533743, 'peep.container-x-drop-i32.rand': 0.9892447701217351, 'peep.container-x-drop-i64.rand': 0.9888902021037702, 'peep.i32.use_of_global': 0.9881810660678407, 'peep.i64.use_of_global': 0.8825197967143363, 'peep.f32.use_of_global': 0.21628649095851554, 'peep.f64.use_of_global': 0.49048575818461176, 'peep.i32.unfold': 0.9849899539061576, 'peep.i64.unfold': 0.8672733719418508, 'peep.replace-with-i32-1': 0.0, 'peep.replace-with-i64-1': 0.0, 'peep.replace-with-f32-1': 0.0, 'peep.replace-with-f64-1': 0.0, 'peep.replace-with-v128-1': 0.0, 'peep.replace-with-i32.rand': 0.0, 'peep.replace-with-i64.rand': 0.0, 'peep.replace-with-f32.rand': 0.0, 'peep.replace-with-f64.rand': 0.0, 'peep.replace-with-ref-null-func': 0.0, 'peep.replace-with-ref-null-extern': 0.0, 'peep.remove-drop': 0.0, 'peep.remove-nop': 0.0, 'peep.remove-global.set.0': 0.0, 'peep.remove-global.set.1': 0.0, 'peep.remove-elem.drop.0': 0 ...
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
# '
