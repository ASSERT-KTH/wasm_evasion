# %% [markdown]
# ## Feature selection experiment

# %%
import networkx as nx
import matplotlib.pyplot as plt
import itertools
import json
import pandas as pd
import re

resampple = r"sample (\d+)"
is_sampled = r"timeout (true|false)"


def load_mutable_csv(f, rename=""):
    a = pd.read_csv(f,index_col = 'id')
    
    if rename:
        a.rename(columns = {'mutable_count': rename}, inplace = True)
        
        # Set the sample ratio then
        a[rename] = a[rename] > 0
        try:
            a[f"{rename}_sample_ratio"] = a[a[rename] > 0]['class_name'].map(lambda x: 1.0/int(re.search(resampple, x).group(1)))
            
            a[f"{rename}_timeout"] = a[a[rename] > 0]['class_name'].map(lambda x: re.search(is_sampled, x).group(1) == "true")
            
            
        except Exception as e:
            pass
    
    #display(a)
    return a

# %%
ratios = [
    
]

files = (
    [ "codemotion_loops", "code_motion_loops.csv" ],
    [ "codemotion_ifs", "code_motion_ifs.csv" ],
    [ "modify_custom_section_data", "modify_custom_section_data.csv" ],
    [ "remove_exports", "remove_exports.csv" ],
    [ "remove_function", "remove_function.csv" ],
    [ "remove_table", "remove_item_table.csv" ],
    [ "remove_global", "remove_item_global.csv" ],
    [ "remove_memory", "remove_item_memory.csv" ],
    [ "remove_tag", "remove_item_tag.csv" ],
    [ "remove_data", "remove_item_data.csv" ],
    [ "remove_element", "remove_item_element.csv" ],
    [ "remove_item_function", "remove_item_function.csv" ],
    [ "snip_function", "snip_function.csv" ],
    [ "modify_data", "modify_data.csv" ],
    
    # Peep hole level
    [ "peep.i64.mul-by-8", "i64.mul-by-8.csv" ],
    [ "peep.select-invert", "select-invert.csv" ],
)
alldf = pd.DataFrame()

for n, f in files:
    print(n)
    df = load_mutable_csv(f, n)
    alldf = pd.concat([df, alldf], axis=1)

# Replace 0 by non mutable :|
alldf=alldf.fillna(0)
alldf = alldf.loc[:,~alldf.columns.duplicated()].copy()

A = 1
# Out:
# codemotion_loops
# codemotion_ifs
# modify_custom_section_data
# remove_exports
# remove_function
# remove_table
# remove_global
# remove_memory
# remove_tag
# remove_data
# remove_element
# remove_item_function
# snip_function
# modify_data
# peep.i64.mul-by-8
# peep.select-invert

# %%
display(alldf)
# Out:
#                                                     num_tags  num_functions  \
# id
# 00008799c04b4f111d28331ef77c387fb2bd6724c9ce88a...       0.0           19.0
# 000415b2639c960e039299fde2a52e7e9c692c212c1fa6c...       0.0           37.0
# 000e01741a75cf7a3d9afc0f4950c220c67188a7c1434bb...       0.0           72.0
# 00189ff4eeb814ffa662649ba6859c004036580fccc2b83...       0.0           37.0
# 0018e8f82de999af365dfc57d0bbe06d5d08eaf791d31f5...       0.0           25.0
# ...                                                      ...            ...
# a471fb0f8617fffacca39359fece67587bc9623e3308574...       0.0            0.0
# b788790a1ea2cb492d79861fff7207a4945a74c80dec928...       0.0            0.0
# d6fb2d9d69ff94496eb462410df30ff1b86e822afbe52a5...       0.0            0.0
# d7a95032e9d3c995bc118ab94b339832261113a91b3ad38...       0.0            0.0
# f0a6d3bd78f86b005e811934b01b83e8de0726fdb7eda4d...       0.0            0.0
#
#                                                     num_globals  num_tables  \
# id
# 00008799c04b4f111d28331ef77c387fb2bd6724c9ce88a...          3.0         1.0
# 000415b2639c960e039299fde2a52e7e9c692c212c1fa6c...          6.0         0.0
# 000e01741a75cf7a3d9afc0f4950c220c67188a7c1434bb...         27.0         1.0
# 00189ff4eeb814ffa662649ba6859c004036580fccc2b83...          0.0         1.0
# 0018e8f82de999af365dfc57d0bbe06d5d08eaf791d31f5...          0.0         1.0
# ...                                                         ...         ...
# a471fb0f8617fffacca39359fece67587bc9623e3308574...          0.0         0.0
# b788790a1ea2cb492d79861fff7207a4945a74c80dec928...          0.0         0.0
# d6fb2d9d69ff94496eb462410df30ff1b86e822afbe52a5...          0.0         0.0
# d7a95032e9d3c995bc118ab94b339832261113a91b3ad38...          0.0         0.0
# f0a6d3bd78f86b005e811934b01b83e8de0726fdb7eda4d...          0.0         0.0
#
#                                                     num_elements  num_data  \
# id
# 00008799c04b4f111d28331ef77c387fb2bd6724c9ce88a...           1.0       0.0
# 000415b2639c960e039299fde2a52e7e9c692c212c1fa6c...           1.0       0.0
# 000e01741a75cf7a3d9afc0f4950c220c67188a7c1434bb...           1.0       0.0
# 00189ff4eeb814ffa662649ba6859c004036580fccc2b83...           1.0       0.0
# 0018e8f82de999af365dfc57d0bbe06d5d08eaf791d31f5...           1.0       0.0
# ...                                                          ...       ...
# a471fb0f8617fffacca39359fece67587bc9623e3308574...           0.0       0.0
# b788790a1ea2cb492d79861fff7207a4945a74c80dec928...           0.0       0.0
# d6fb2d9d69ff94496eb462410df30ff1b86e822afbe52a5...           0.0       0.0
# d7a95032e9d3c995bc118ab94b339832261113a91b3ad38...           0.0       0.0
# f0a6d3bd78f86b005e811934b01b83e8de0726fdb7eda4d...           0.0       0.0
#
#                                                     num_types  num_memory  \
# id
# 00008799c04b4f111d28331ef77c387fb2bd6724c9ce88a...       10.0         1.0
# 000415b2639c960e039299fde2a52e7e9c692c212c1fa6c...       10.0         0.0
# 000e01741a75cf7a3d9afc0f4950c220c67188a7c1434bb...       16.0         1.0
# 00189ff4eeb814ffa662649ba6859c004036580fccc2b83...       19.0         1.0
# 0018e8f82de999af365dfc57d0bbe06d5d08eaf791d31f5...       11.0         1.0
# ...                                                       ...         ...
# a471fb0f8617fffacca39359fece67587bc9623e3308574...        0.0         0.0
# b788790a1ea2cb492d79861fff7207a4945a74c80dec928...        0.0         0.0
# d6fb2d9d69ff94496eb462410df30ff1b86e822afbe52a5...        0.0         0.0
# d7a95032e9d3c995bc118ab94b339832261113a91b3ad38...        0.0         0.0
# f0a6d3bd78f86b005e811934b01b83e8de0726fdb7eda4d...        0.0         0.0
#
#                                                     num_instructions  \
# id
# 00008799c04b4f111d28331ef77c387fb2bd6724c9ce88a...            1751.0
# 000415b2639c960e039299fde2a52e7e9c692c212c1fa6c...           28339.0
# 000e01741a75cf7a3d9afc0f4950c220c67188a7c1434bb...           14859.0
# 00189ff4eeb814ffa662649ba6859c004036580fccc2b83...            5313.0
# 0018e8f82de999af365dfc57d0bbe06d5d08eaf791d31f5...            2454.0
# ...                                                              ...
# a471fb0f8617fffacca39359fece67587bc9623e3308574...               0.0
# b788790a1ea2cb492d79861fff7207a4945a74c80dec928...               0.0
# d6fb2d9d69ff94496eb462410df30ff1b86e822afbe52a5...               0.0
# d7a95032e9d3c995bc118ab94b339832261113a91b3ad38...               0.0
# f0a6d3bd78f86b005e811934b01b83e8de0726fdb7eda4d...               0.0
#
#                                                    class_name  ...  \
# id                                                             ...
# 00008799c04b4f111d28331ef77c387fb2bd6724c9ce88a...       none  ...
# 000415b2639c960e039299fde2a52e7e9c692c212c1fa6c...       none  ...
# 000e01741a75cf7a3d9afc0f4950c220c67188a7c1434bb...       none  ...
# 00189ff4eeb814ffa662649ba6859c004036580fccc2b83...       none  ...
# 0018e8f82de999af365dfc57d0bbe06d5d08eaf791d31f5...       none  ...
# ...                                                       ...  ...
# a471fb0f8617fffacca39359fece67587bc9623e3308574...          0  ...
# b788790a1ea2cb492d79861fff7207a4945a74c80dec928...          0  ...
# d6fb2d9d69ff94496eb462410df30ff1b86e822afbe52a5...          0  ...
# d7a95032e9d3c995bc118ab94b339832261113a91b3ad38...          0  ...
# f0a6d3bd78f86b005e811934b01b83e8de0726fdb7eda4d...          0  ...
#
#                                                    remove_data  remove_tag  \
# id
# 00008799c04b4f111d28331ef77c387fb2bd6724c9ce88a...       False       False
# 000415b2639c960e039299fde2a52e7e9c692c212c1fa6c...       False       False
# 000e01741a75cf7a3d9afc0f4950c220c67188a7c1434bb...       False       False
# 00189ff4eeb814ffa662649ba6859c004036580fccc2b83...       False       False
# 0018e8f82de999af365dfc57d0bbe06d5d08eaf791d31f5...       False       False
# ...                                                        ...         ...
# a471fb0f8617fffacca39359fece67587bc9623e3308574...       False       False
# b788790a1ea2cb492d79861fff7207a4945a74c80dec928...       False       False
# d6fb2d9d69ff94496eb462410df30ff1b86e822afbe52a5...       False       False
# d7a95032e9d3c995bc118ab94b339832261113a91b3ad38...       False       False
# f0a6d3bd78f86b005e811934b01b83e8de0726fdb7eda4d...       False       False
#
#                                                    remove_memory  \
# id
# 00008799c04b4f111d28331ef77c387fb2bd6724c9ce88a...         False
# 000415b2639c960e039299fde2a52e7e9c692c212c1fa6c...         False
# 000e01741a75cf7a3d9afc0f4950c220c67188a7c1434bb...         False
# 00189ff4eeb814ffa662649ba6859c004036580fccc2b83...         False
# 0018e8f82de999af365dfc57d0bbe06d5d08eaf791d31f5...         False
# ...                                                          ...
# a471fb0f8617fffacca39359fece67587bc9623e3308574...         False
# b788790a1ea2cb492d79861fff7207a4945a74c80dec928...         False
# d6fb2d9d69ff94496eb462410df30ff1b86e822afbe52a5...         False
# d7a95032e9d3c995bc118ab94b339832261113a91b3ad38...         False
# f0a6d3bd78f86b005e811934b01b83e8de0726fdb7eda4d...         False
#
#                                                     remove_global  \
# id
# 00008799c04b4f111d28331ef77c387fb2bd6724c9ce88a...          False
# 000415b2639c960e039299fde2a52e7e9c692c212c1fa6c...           True
# 000e01741a75cf7a3d9afc0f4950c220c67188a7c1434bb...          False
# 00189ff4eeb814ffa662649ba6859c004036580fccc2b83...          False
# 0018e8f82de999af365dfc57d0bbe06d5d08eaf791d31f5...          False
# ...                                                           ...
# a471fb0f8617fffacca39359fece67587bc9623e3308574...          False
# b788790a1ea2cb492d79861fff7207a4945a74c80dec928...          False
# d6fb2d9d69ff94496eb462410df30ff1b86e822afbe52a5...          False
# d7a95032e9d3c995bc118ab94b339832261113a91b3ad38...          False
# f0a6d3bd78f86b005e811934b01b83e8de0726fdb7eda4d...          False
#
#                                                     remove_table  \
# id
# 00008799c04b4f111d28331ef77c387fb2bd6724c9ce88a...         False
# 000415b2639c960e039299fde2a52e7e9c692c212c1fa6c...         False
# 000e01741a75cf7a3d9afc0f4950c220c67188a7c1434bb...         False
# 00189ff4eeb814ffa662649ba6859c004036580fccc2b83...         False
# 0018e8f82de999af365dfc57d0bbe06d5d08eaf791d31f5...         False
# ...                                                          ...
# a471fb0f8617fffacca39359fece67587bc9623e3308574...         False
# b788790a1ea2cb492d79861fff7207a4945a74c80dec928...         False
# d6fb2d9d69ff94496eb462410df30ff1b86e822afbe52a5...         False
# d7a95032e9d3c995bc118ab94b339832261113a91b3ad38...         False
# f0a6d3bd78f86b005e811934b01b83e8de0726fdb7eda4d...         False
#
#                                                     remove_function  \
# id
# 00008799c04b4f111d28331ef77c387fb2bd6724c9ce88a...                0
# 000415b2639c960e039299fde2a52e7e9c692c212c1fa6c...                0
# 000e01741a75cf7a3d9afc0f4950c220c67188a7c1434bb...            False
# 00189ff4eeb814ffa662649ba6859c004036580fccc2b83...                0
# 0018e8f82de999af365dfc57d0bbe06d5d08eaf791d31f5...                0
# ...                                                             ...
# a471fb0f8617fffacca39359fece67587bc9623e3308574...                0
# b788790a1ea2cb492d79861fff7207a4945a74c80dec928...                0
# d6fb2d9d69ff94496eb462410df30ff1b86e822afbe52a5...                0
# d7a95032e9d3c995bc118ab94b339832261113a91b3ad38...                0
# f0a6d3bd78f86b005e811934b01b83e8de0726fdb7eda4d...                0
#
#                                                     remove_exports  \
# id
# 00008799c04b4f111d28331ef77c387fb2bd6724c9ce88a...           False
# 000415b2639c960e039299fde2a52e7e9c692c212c1fa6c...           False
# 000e01741a75cf7a3d9afc0f4950c220c67188a7c1434bb...           False
# 00189ff4eeb814ffa662649ba6859c004036580fccc2b83...           False
# 0018e8f82de999af365dfc57d0bbe06d5d08eaf791d31f5...           False
# ...                                                            ...
# a471fb0f8617fffacca39359fece67587bc9623e3308574...           False
# b788790a1ea2cb492d79861fff7207a4945a74c80dec928...           False
# d6fb2d9d69ff94496eb462410df30ff1b86e822afbe52a5...           False
# d7a95032e9d3c995bc118ab94b339832261113a91b3ad38...           False
# f0a6d3bd78f86b005e811934b01b83e8de0726fdb7eda4d...           False
#
#                                                     modify_custom_section_data  \
# id
# 00008799c04b4f111d28331ef77c387fb2bd6724c9ce88a...                       False
# 000415b2639c960e039299fde2a52e7e9c692c212c1fa6c...                       False
# 000e01741a75cf7a3d9afc0f4950c220c67188a7c1434bb...                        True
# 00189ff4eeb814ffa662649ba6859c004036580fccc2b83...                       False
# 0018e8f82de999af365dfc57d0bbe06d5d08eaf791d31f5...                       False
# ...                                                                        ...
# a471fb0f8617fffacca39359fece67587bc9623e3308574...                       False
# b788790a1ea2cb492d79861fff7207a4945a74c80dec928...                       False
# d6fb2d9d69ff94496eb462410df30ff1b86e822afbe52a5...                        True
# d7a95032e9d3c995bc118ab94b339832261113a91b3ad38...                       False
# f0a6d3bd78f86b005e811934b01b83e8de0726fdb7eda4d...                       False
#
#                                                     codemotion_ifs  \
# id
# 00008799c04b4f111d28331ef77c387fb2bd6724c9ce88a...           False
# 000415b2639c960e039299fde2a52e7e9c692c212c1fa6c...            True
# 000e01741a75cf7a3d9afc0f4950c220c67188a7c1434bb...           False
# 00189ff4eeb814ffa662649ba6859c004036580fccc2b83...           False
# 0018e8f82de999af365dfc57d0bbe06d5d08eaf791d31f5...           False
# ...                                                            ...
# a471fb0f8617fffacca39359fece67587bc9623e3308574...            True
# b788790a1ea2cb492d79861fff7207a4945a74c80dec928...            True
# d6fb2d9d69ff94496eb462410df30ff1b86e822afbe52a5...           False
# d7a95032e9d3c995bc118ab94b339832261113a91b3ad38...            True
# f0a6d3bd78f86b005e811934b01b83e8de0726fdb7eda4d...            True
#
#                                                     codemotion_loops
# id
# 00008799c04b4f111d28331ef77c387fb2bd6724c9ce88a...              True
# 000415b2639c960e039299fde2a52e7e9c692c212c1fa6c...              True
# 000e01741a75cf7a3d9afc0f4950c220c67188a7c1434bb...              True
# 00189ff4eeb814ffa662649ba6859c004036580fccc2b83...              True
# 0018e8f82de999af365dfc57d0bbe06d5d08eaf791d31f5...              True
# ...                                                              ...
# a471fb0f8617fffacca39359fece67587bc9623e3308574...              True
# b788790a1ea2cb492d79861fff7207a4945a74c80dec928...              True
# d6fb2d9d69ff94496eb462410df30ff1b86e822afbe52a5...              True
# d7a95032e9d3c995bc118ab94b339832261113a91b3ad38...              True
# f0a6d3bd78f86b005e811934b01b83e8de0726fdb7eda4d...              True
#
# [8461 rows x 27 columns]

# %%
import random

features = [
    # columns that represent features and the name of the binary feature
    [ "codemotion_loops", "code_motion_loops" ],
    [ "codemotion_ifs", "code_motion_ifs" ],
    [ "modify_custom_section_data", "modify_custom_section_data" ],
    [ "remove_exports", "remove_exports" ],
    [ "remove_function", "remove_function" ],
    [ "remove_table", "remove_item_table" ],
    [ "remove_global", "remove_item_global" ],
    [ "remove_memory", "remove_item_memory" ],
    [ "remove_tag", "remove_item_tag" ],
    [ "remove_data", "remove_item_data" ],
    [ "remove_element", "remove_item_element" ],
    [ "remove_item_function", "remove_item_function" ],
    [ "snip_function", "snip_function" ],
    [ "modify_data", "modify_data" ],
    
    # Peep hole level
    [ "peep.i64.mul-by-8", "i64.mul-by-8.csv" ],
    [ "peep.select-invert", "select-invert.csv" ],
]


def all_combinations(features, r, cb):
    
    if len(features) == 0:
        cb(r)
    else:
        l = features[0]
        tail = [x for x in features[1:]]
        all_combinations(tail, r + [l], cb)
        all_combinations(tail, r, cb)
    

def get_uniform_x(count):
    
    r = []
    sets = []
    
    alla_filtered = [r for r in features]
    
    if count > 2**(len(alla_filtered)):
        # Filter ouur, there is not possible to get more than this number
        all_combinations(alla_filtered, [], lambda x: r.append([ y[1] for y in x ]))
        return r
        
    while len(r) < count:
        alla = [r[1] for r in features]
        selected = [] 
        
        for x in alla:
            n = random.random()
            if n <= 1/len(features):
                selected.append(x)
                
        selected = list(sorted(selected))
        if len(selected) > 0 and f"{selected}" not in sets:
            r.append(selected)
            sets.append(f"{selected}")
    
    return r

def get_uniform_x_filter_non_probable(frame, count):
    
    def is_probable(name):
        c = len(frame[frame[name] == True])
        
        return c > 0
    
    r = []
    sets = []
    alla_filtered = [r for r in features if is_probable(r[0])]
    
    print("Set size", len(alla_filtered))
    
    if count > 2**(len(alla_filtered)):
        # Filter ouur, there is not possible to get more than this number
        print("Setting the count to the max possible")
        all_combinations(alla_filtered, [], lambda x: r.append([ y[1] for y in x ]))
        return r
        
    
    while len(r) < count:
        alla = [r[1] for r in alla_filtered]
        #print(alla)
        selected = [] 
        
        for x in alla:
            n = random.random()
            if n <= 1/len(features):
                selected.append(x)
                
        selected = list(sorted(selected))
        if len(selected) > 0 and f"{selected}" not in sets:
            r.append(selected)
            sets.append(f"{selected}")
    
    return r


def get_x_weight_by_applicability(frame, count, reverse = False):
    
    def weight(name):
        c1 = len(frame[frame[name] == True])
        c2 = len(frame)
        
        return (1 - c1/c2) if (reverse and c1 > 0) else c1/ c2
    
    r = []
    sets = []
    weights = {r[0]: weight(r[0]) for r in features }
    sumweights = sum(r for r in weights.values())
    print(weights)
    
    
    while len(r) < count:
        try:
            alla = [r for r in features]
            #print(alla)
            selected = [] 

            for x in alla:
                n = random.random()
                p_perfeature = weights[x[0]]
                p_weighted = p_perfeature/sumweights
                
                if n <= p_weighted:
                    selected.append(x[1])

            selected = list(sorted(selected))
            if len(selected) > 0 and f"{selected}" not in sets:
                r.append(selected)
                sets.append(f"{selected}")
        except KeyboardInterrupt:
            break
    return r

# %%
random.seed(10)
configs = get_uniform_x(100)

for i, c in enumerate(configs):
    print(f"C{i}", c)
# Out:
# C0 ['modify_data']
# C1 ['remove_item_function', 'snip_function']
# C2 ['remove_item_function']
# C3 ['remove_item_element']
# C4 ['remove_item_global', 'remove_item_table', 'remove_item_tag']
# C5 ['remove_item_global']
# C6 ['remove_item_memory']
# C7 ['remove_exports', 'remove_item_table', 'select-invert.csv']
# C8 ['i64.mul-by-8.csv', 'modify_data']
# C9 ['code_motion_ifs', 'remove_item_memory']
# C10 ['remove_item_tag']
# C11 ['modify_data', 'remove_item_element', 'remove_item_function', 'snip_function']
# C12 ['modify_custom_section_data', 'remove_item_tag', 'snip_function']
# C13 ['remove_function']
# C14 ['remove_item_element', 'remove_item_table']
# C15 ['modify_custom_section_data']
# C16 ['code_motion_ifs', 'modify_data', 'remove_item_element']
# C17 ['i64.mul-by-8.csv', 'modify_custom_section_data', 'remove_function', 'remove_item_global']
# C18 ['snip_function']
# C19 ['select-invert.csv']
# C20 ['i64.mul-by-8.csv', 'remove_item_data']
# C21 ['code_motion_ifs', 'remove_item_global']
# C22 ['modify_data', 'remove_item_tag']
# C23 ['i64.mul-by-8.csv', 'remove_item_table']
# C24 ['code_motion_ifs', 'remove_function', 'select-invert.csv']
# C25 ['remove_item_data']
# C26 ['modify_custom_section_data', 'remove_item_tag']
# C27 ['modify_custom_section_data', 'remove_item_data', 'remove_item_table']
# C28 ['remove_exports', 'remove_item_element']
# C29 ['i64.mul-by-8.csv', 'remove_item_function']
# C30 ['i64.mul-by-8.csv']
# C31 ['remove_item_element', 'snip_function']
# C32 ['code_motion_loops', 'i64.mul-by-8.csv']
# C33 ['modify_data', 'remove_item_element']
# C34 ['code_motion_loops', 'remove_item_data']
# C35 ['code_motion_loops', 'remove_item_table']
# C36 ['i64.mul-by-8.csv', 'remove_item_element']
# C37 ['code_motion_loops']
# C38 ['remove_item_data', 'remove_item_global']
# C39 ['code_motion_loops', 'modify_data']
# C40 ['code_motion_ifs', 'remove_item_table']
# C41 ['modify_data', 'remove_item_table', 'select-invert.csv']
# C42 ['remove_item_table']
# C43 ['modify_data', 'remove_function', 'select-invert.csv']
# C44 ['remove_item_global', 'select-invert.csv']
# C45 ['remove_exports']
# C46 ['code_motion_ifs']
# C47 ['code_motion_loops', 'i64.mul-by-8.csv', 'modify_data', 'remove_item_global']
# C48 ['code_motion_loops', 'snip_function']
# C49 ['code_motion_ifs', 'remove_item_data']
# C50 ['code_motion_ifs', 'remove_item_data', 'remove_item_function']
# C51 ['remove_function', 'snip_function']
# C52 ['i64.mul-by-8.csv', 'remove_item_tag']
# C53 ['remove_function', 'remove_item_global']
# C54 ['modify_custom_section_data', 'select-invert.csv']
# C55 ['remove_function', 'remove_item_table', 'snip_function']
# C56 ['remove_item_function', 'remove_item_global']
# C57 ['remove_function', 'select-invert.csv']
# C58 ['code_motion_ifs', 'snip_function']
# C59 ['modify_data', 'snip_function']
# C60 ['remove_item_table', 'snip_function']
# C61 ['code_motion_loops', 'remove_item_tag']
# C62 ['remove_item_table', 'remove_item_tag', 'snip_function']
# C63 ['remove_item_memory', 'remove_item_table']
# C64 ['remove_exports', 'remove_item_tag', 'snip_function']
# C65 ['modify_data', 'remove_function', 'remove_item_data']
# C66 ['remove_item_function', 'select-invert.csv']
# C67 ['code_motion_loops', 'remove_function', 'remove_item_global']
# C68 ['modify_data', 'remove_item_function']
# C69 ['select-invert.csv', 'snip_function']
# C70 ['remove_item_memory', 'snip_function']
# C71 ['modify_data', 'remove_exports']
# C72 ['code_motion_loops', 'modify_data', 'remove_item_table']
# C73 ['code_motion_loops', 'i64.mul-by-8.csv', 'remove_item_data']
# C74 ['modify_custom_section_data', 'remove_item_global']
# C75 ['remove_item_global', 'remove_item_memory']
# C76 ['code_motion_ifs', 'modify_data', 'remove_item_table']
# C77 ['remove_function', 'remove_item_element']
# C78 ['i64.mul-by-8.csv', 'remove_item_global']
# C79 ['code_motion_loops', 'select-invert.csv']
# C80 ['modify_custom_section_data', 'remove_item_function', 'snip_function']
# C81 ['modify_data', 'remove_function']
# C82 ['i64.mul-by-8.csv', 'modify_custom_section_data']
# C83 ['code_motion_loops', 'i64.mul-by-8.csv', 'modify_data', 'remove_item_memory']
# C84 ['i64.mul-by-8.csv', 'remove_item_memory']
# C85 ['remove_function', 'remove_item_memory']
# C86 ['remove_item_tag', 'select-invert.csv']
# C87 ['code_motion_loops', 'modify_custom_section_data']
# C88 ['modify_data', 'remove_item_data']
# C89 ['remove_exports', 'remove_item_global', 'remove_item_memory']
# C90 ['remove_function', 'remove_item_global', 'remove_item_tag', 'select-invert.csv']
# C91 ['remove_item_data', 'select-invert.csv']
# C92 ['code_motion_ifs', 'code_motion_loops']
# C93 ['code_motion_loops', 'modify_data', 'remove_item_global']
# C94 ['remove_exports', 'remove_item_tag']
# C95 ['modify_custom_section_data', 'snip_function']
# C96 ['code_motion_loops', 'remove_function']
# C97 ['code_motion_loops', 'remove_item_element', 'remove_item_global']
# C98 ['code_motion_loops', 'remove_item_global']
# C99 ['code_motion_ifs', 'remove_item_memory', 'remove_item_tag']

# %%
random.seed(10)
c2 = get_uniform_x_filter_non_probable(alldf, 300)

for i, c2 in enumerate(c2):
    print(f"C{i}", c2)
# Out:
# Set size 8
# Setting the count to the max possible
# C0 ['code_motion_loops', 'code_motion_ifs', 'modify_custom_section_data', 'remove_function', 'remove_item_table', 'remove_item_global', 'remove_item_memory', 'i64.mul-by-8']
# C1 ['code_motion_loops', 'code_motion_ifs', 'modify_custom_section_data', 'remove_function', 'remove_item_table', 'remove_item_global', 'remove_item_memory']
# C2 ['code_motion_loops', 'code_motion_ifs', 'modify_custom_section_data', 'remove_function', 'remove_item_table', 'remove_item_global', 'i64.mul-by-8']
# C3 ['code_motion_loops', 'code_motion_ifs', 'modify_custom_section_data', 'remove_function', 'remove_item_table', 'remove_item_global']
# C4 ['code_motion_loops', 'code_motion_ifs', 'modify_custom_section_data', 'remove_function', 'remove_item_table', 'remove_item_memory', 'i64.mul-by-8']
# C5 ['code_motion_loops', 'code_motion_ifs', 'modify_custom_section_data', 'remove_function', 'remove_item_table', 'remove_item_memory']
# C6 ['code_motion_loops', 'code_motion_ifs', 'modify_custom_section_data', 'remove_function', 'remove_item_table', 'i64.mul-by-8']
# C7 ['code_motion_loops', 'code_motion_ifs', 'modify_custom_section_data', 'remove_function', 'remove_item_table']
# C8 ['code_motion_loops', 'code_motion_ifs', 'modify_custom_section_data', 'remove_function', 'remove_item_global', 'remove_item_memory', 'i64.mul-by-8']
# C9 ['code_motion_loops', 'code_motion_ifs', 'modify_custom_section_data', 'remove_function', 'remove_item_global', 'remove_item_memory']
# C10 ['code_motion_loops', 'code_motion_ifs', 'modify_custom_section_data', 'remove_function', 'remove_item_global', 'i64.mul-by-8']
# C11 ['code_motion_loops', 'code_motion_ifs', 'modify_custom_section_data', 'remove_function', 'remove_item_global']
# C12 ['code_motion_loops', 'code_motion_ifs', 'modify_custom_section_data', 'remove_function', 'remove_item_memory', 'i64.mul-by-8']
# C13 ['code_motion_loops', 'code_motion_ifs', 'modify_custom_section_data', 'remove_function', 'remove_item_memory']
# C14 ['code_motion_loops', 'code_motion_ifs', 'modify_custom_section_data', 'remove_function', 'i64.mul-by-8']
# C15 ['code_motion_loops', 'code_motion_ifs', 'modify_custom_section_data', 'remove_function']
# C16 ['code_motion_loops', 'code_motion_ifs', 'modify_custom_section_data', 'remove_item_table', 'remove_item_global', 'remove_item_memory', 'i64.mul-by-8']
# C17 ['code_motion_loops', 'code_motion_ifs', 'modify_custom_section_data', 'remove_item_table', 'remove_item_global', 'remove_item_memory']
# C18 ['code_motion_loops', 'code_motion_ifs', 'modify_custom_section_data', 'remove_item_table', 'remove_item_global', 'i64.mul-by-8']
# C19 ['code_motion_loops', 'code_motion_ifs', 'modify_custom_section_data', 'remove_item_table', 'remove_item_global']
# C20 ['code_motion_loops', 'code_motion_ifs', 'modify_custom_section_data', 'remove_item_table', 'remove_item_memory', 'i64.mul-by-8']
# C21 ['code_motion_loops', 'code_motion_ifs', 'modify_custom_section_data', 'remove_item_table', 'remove_item_memory']
# C22 ['code_motion_loops', 'code_motion_ifs', 'modify_custom_section_data', 'remove_item_table', 'i64.mul-by-8']
# C23 ['code_motion_loops', 'code_motion_ifs', 'modify_custom_section_data', 'remove_item_table']
# C24 ['code_motion_loops', 'code_motion_ifs', 'modify_custom_section_data', 'remove_item_global', 'remove_item_memory', 'i64.mul-by-8']
# C25 ['code_motion_loops', 'code_motion_ifs', 'modify_custom_section_data', 'remove_item_global', 'remove_item_memory']
# C26 ['code_motion_loops', 'code_motion_ifs', 'modify_custom_section_data', 'remove_item_global', 'i64.mul-by-8']
# C27 ['code_motion_loops', 'code_motion_ifs', 'modify_custom_section_data', 'remove_item_global']
# C28 ['code_motion_loops', 'code_motion_ifs', 'modify_custom_section_data', 'remove_item_memory', 'i64.mul-by-8']
# C29 ['code_motion_loops', 'code_motion_ifs', 'modify_custom_section_data', 'remove_item_memory']
# C30 ['code_motion_loops', 'code_motion_ifs', 'modify_custom_section_data', 'i64.mul-by-8']
# C31 ['code_motion_loops', 'code_motion_ifs', 'modify_custom_section_data']
# C32 ['code_motion_loops', 'code_motion_ifs', 'remove_function', 'remove_item_table', 'remove_item_global', 'remove_item_memory', 'i64.mul-by-8']
# C33 ['code_motion_loops', 'code_motion_ifs', 'remove_function', 'remove_item_table', 'remove_item_global', 'remove_item_memory']
# C34 ['code_motion_loops', 'code_motion_ifs', 'remove_function', 'remove_item_table', 'remove_item_global', 'i64.mul-by-8']
# C35 ['code_motion_loops', 'code_motion_ifs', 'remove_function', 'remove_item_table', 'remove_item_global']
# C36 ['code_motion_loops', 'code_motion_ifs', 'remove_function', 'remove_item_table', 'remove_item_memory', 'i64.mul-by-8']
# C37 ['code_motion_loops', 'code_motion_ifs', 'remove_function', 'remove_item_table', 'remove_item_memory']
# C38 ['code_motion_loops', 'code_motion_ifs', 'remove_function', 'remove_item_table', 'i64.mul-by-8']
# C39 ['code_motion_loops', 'code_motion_ifs', 'remove_function', 'remove_item_table']
# C40 ['code_motion_loops', 'code_motion_ifs', 'remove_function', 'remove_item_global', 'remove_item_memory', 'i64.mul-by-8']
# C41 ['code_motion_loops', 'code_motion_ifs', 'remove_function', 'remove_item_global', 'remove_item_memory']
# C42 ['code_motion_loops', 'code_motion_ifs', 'remove_function', 'remove_item_global', 'i64.mul-by-8']
# C43 ['code_motion_loops', 'code_motion_ifs', 'remove_function', 'remove_item_global']
# C44 ['code_motion_loops', 'code_motion_ifs', 'remove_function', 'remove_item_memory', 'i64.mul-by-8']
# C45 ['code_motion_loops', 'code_motion_ifs', 'remove_function', 'remove_item_memory']
# C46 ['code_motion_loops', 'code_motion_ifs', 'remove_function', 'i64.mul-by-8']
# C47 ['code_motion_loops', 'code_motion_ifs', 'remove_function']
# C48 ['code_motion_loops', 'code_motion_ifs', 'remove_item_table', 'remove_item_global', 'remove_item_memory', 'i64.mul-by-8']
# C49 ['code_motion_loops', 'code_motion_ifs', 'remove_item_table', 'remove_item_global', 'remove_item_memory']
# C50 ['code_motion_loops', 'code_motion_ifs', 'remove_item_table', 'remove_item_global', 'i64.mul-by-8']
# C51 ['code_motion_loops', 'code_motion_ifs', 'remove_item_table', 'remove_item_global']
# C52 ['code_motion_loops', 'code_motion_ifs', 'remove_item_table', 'remove_item_memory', 'i64.mul-by-8']
# C53 ['code_motion_loops', 'code_motion_ifs', 'remove_item_table', 'remove_item_memory']
# C54 ['code_motion_loops', 'code_motion_ifs', 'remove_item_table', 'i64.mul-by-8']
# C55 ['code_motion_loops', 'code_motion_ifs', 'remove_item_table']
# C56 ['code_motion_loops', 'code_motion_ifs', 'remove_item_global', 'remove_item_memory', 'i64.mul-by-8']
# C57 ['code_motion_loops', 'code_motion_ifs', 'remove_item_global', 'remove_item_memory']
# C58 ['code_motion_loops', 'code_motion_ifs', 'remove_item_global', 'i64.mul-by-8']
# C59 ['code_motion_loops', 'code_motion_ifs', 'remove_item_global']
# C60 ['code_motion_loops', 'code_motion_ifs', 'remove_item_memory', 'i64.mul-by-8']
# C61 ['code_motion_loops', 'code_motion_ifs', 'remove_item_memory']
# C62 ['code_motion_loops', 'code_motion_ifs', 'i64.mul-by-8']
# C63 ['code_motion_loops', 'code_motion_ifs']
# C64 ['code_motion_loops', 'modify_custom_section_data', 'remove_function', 'remove_item_table', 'remove_item_global', 'remove_item_memory', 'i64.mul-by-8']
# C65 ['code_motion_loops', 'modify_custom_section_data', 'remove_function', 'remove_item_table', 'remove_item_global', 'remove_item_memory']
# C66 ['code_motion_loops', 'modify_custom_section_data', 'remove_function', 'remove_item_table', 'remove_item_global', 'i64.mul-by-8']
# C67 ['code_motion_loops', 'modify_custom_section_data', 'remove_function', 'remove_item_table', 'remove_item_global']
# C68 ['code_motion_loops', 'modify_custom_section_data', 'remove_function', 'remove_item_table', 'remove_item_memory', 'i64.mul-by-8']
# C69 ['code_motion_loops', 'modify_custom_section_data', 'remove_function', 'remove_item_table', 'remove_item_memory']
# C70 ['code_motion_loops', 'modify_custom_section_data', 'remove_function', 'remove_item_table', 'i64.mul-by-8']
# C71 ['code_motion_loops', 'modify_custom_section_data', 'remove_function', 'remove_item_table']
# C72 ['code_motion_loops', 'modify_custom_section_data', 'remove_function', 'remove_item_global', 'remove_item_memory', 'i64.mul-by-8']
# C73 ['code_motion_loops', 'modify_custom_section_data', 'remove_function', 'remove_item_global', 'remove_item_memory']
# C74 ['code_motion_loops', 'modify_custom_section_data', 'remove_function', 'remove_item_global', 'i64.mul-by-8']
# C75 ['code_motion_loops', 'modify_custom_section_data', 'remove_function', 'remove_item_global']
# C76 ['code_motion_loops', 'modify_custom_section_data', 'remove_function', 'remove_item_memory', 'i64.mul-by-8']
# C77 ['code_motion_loops', 'modify_custom_section_data', 'remove_function', 'remove_item_memory']
# C78 ['code_motion_loops', 'modify_custom_section_data', 'remove_function', 'i64.mul-by-8']
# C79 ['code_motion_loops', 'modify_custom_section_data', 'remove_function']
# C80 ['code_motion_loops', 'modify_custom_section_data', 'remove_item_table', 'remove_item_global', 'remove_item_memory', 'i64.mul-by-8']
# C81 ['code_motion_loops', 'modify_custom_section_data', 'remove_item_table', 'remove_item_global', 'remove_item_memory']
# C82 ['code_motion_loops', 'modify_custom_section_data', 'remove_item_table', 'remove_item_global', 'i64.mul-by-8']
# C83 ['code_motion_loops', 'modify_custom_section_data', 'remove_item_table', 'remove_item_global']
# C84 ['code_motion_loops', 'modify_custom_section_data', 'remove_item_table', 'remove_item_memory', 'i64.mul-by-8']
# C85 ['code_motion_loops', 'modify_custom_section_data', 'remove_item_table', 'remove_item_memory']
# C86 ['code_motion_loops', 'modify_custom_section_data', 'remove_item_table', 'i64.mul-by-8']
# C87 ['code_motion_loops', 'modify_custom_section_data', 'remove_item_table']
# C88 ['code_motion_loops', 'modify_custom_section_data', 'remove_item_global', 'remove_item_memory', 'i64.mul-by-8']
# C89 ['code_motion_loops', 'modify_custom_section_data', 'remove_item_global', 'remove_item_memory']
# C90 ['code_motion_loops', 'modify_custom_section_data', 'remove_item_global', 'i64.mul-by-8']
# C91 ['code_motion_loops', 'modify_custom_section_data', 'remove_item_global']
# C92 ['code_motion_loops', 'modify_custom_section_data', 'remove_item_memory', 'i64.mul-by-8']
# C93 ['code_motion_loops', 'modify_custom_section_data', 'remove_item_memory']
# C94 ['code_motion_loops', 'modify_custom_section_data', 'i64.mul-by-8']
# C95 ['code_motion_loops', 'modify_custom_section_data']
# C96 ['code_motion_loops', 'remove_function', 'remove_item_table', 'remove_item_global', 'remove_item_memory', 'i64.mul-by-8']
# C97 ['code_motion_loops', 'remove_function', 'remove_item_table', 'remove_item_global', 'remove_item_memory']
# C98 ['code_motion_loops', 'remove_function', 'remove_item_table', 'remove_item_global', 'i64.mul-by-8']
# C99 ['code_motion_loops', 'remove_function', 'remove_item_table', 'remove_item_global']
# C100 ['code_motion_loops', 'remove_function', 'remove_item_table', 'remove_item_memory', 'i64.mul-by-8']
# C101 ['code_motion_loops', 'remove_function', 'remove_item_table', 'remove_item_memory']
# C102 ['code_motion_loops', 'remove_function', 'remove_item_table', 'i64.mul-by-8']
# C103 ['code_motion_loops', 'remove_function', 'remove_item_table']
# C104 ['code_motion_loops', 'remove_function', 'remove_item_global', 'remove_item_memory', 'i64.mul-by-8']
# C105 ['code_motion_loops', 'remove_function', 'remove_item_global', 'remove_item_memory']
# C106 ['code_motion_loops', 'remove_function', 'remove_item_global', 'i64.mul-by-8']
# C107 ['code_motion_loops', 'remove_function', 'remove_item_global']
# C108 ['code_motion_loops', 'remove_function', 'remove_item_memory', 'i64.mul-by-8']
# C109 ['code_motion_loops', 'remove_function', 'remove_item_memory']
# C110 ['code_motion_loops', 'remove_function', 'i64.mul-by-8']
# C111 ['code_motion_loops', 'remove_function']
# C112 ['code_motion_loops', 'remove_item_table', 'remove_item_global', 'remove_item_memory', 'i64.mul-by-8']
# C113 ['code_motion_loops', 'remove_item_table', 'remove_item_global', 'remove_item_memory']
# C114 ['code_motion_loops', 'remove_item_table', 'remove_item_global', 'i64.mul-by-8']
# C115 ['code_motion_loops', 'remove_item_table', 'remove_item_global']
# C116 ['code_motion_loops', 'remove_item_table', 'remove_item_memory', 'i64.mul-by-8']
# C117 ['code_motion_loops', 'remove_item_table', 'remove_item_memory']
# C118 ['code_motion_loops', 'remove_item_table', 'i64.mul-by-8']
# C119 ['code_motion_loops', 'remove_item_table']
# C120 ['code_motion_loops', 'remove_item_global', 'remove_item_memory', 'i64.mul-by-8']
# C121 ['code_motion_loops', 'remove_item_global', 'remove_item_memory']
# C122 ['code_motion_loops', 'remove_item_global', 'i64.mul-by-8']
# C123 ['code_motion_loops', 'remove_item_global']
# C124 ['code_motion_loops', 'remove_item_memory', 'i64.mul-by-8']
# C125 ['code_motion_loops', 'remove_item_memory']
# C126 ['code_motion_loops', 'i64.mul-by-8']
# C127 ['code_motion_loops']
# C128 ['code_motion_ifs', 'modify_custom_section_data', 'remove_function', 'remove_item_table', 'remove_item_global', 'remove_item_memory', 'i64.mul-by-8']
# C129 ['code_motion_ifs', 'modify_custom_section_data', 'remove_function', 'remove_item_table', 'remove_item_global', 'remove_item_memory']
# C130 ['code_motion_ifs', 'modify_custom_section_data', 'remove_function', 'remove_item_table', 'remove_item_global', 'i64.mul-by-8']
# C131 ['code_motion_ifs', 'modify_custom_section_data', 'remove_function', 'remove_item_table', 'remove_item_global']
# C132 ['code_motion_ifs', 'modify_custom_section_data', 'remove_function', 'remove_item_table', 'remove_item_memory', 'i64.mul-by-8']
# C133 ['code_motion_ifs', 'modify_custom_section_data', 'remove_function', 'remove_item_table', 'remove_item_memory']
# C134 ['code_motion_ifs', 'modify_custom_section_data', 'remove_function', 'remove_item_table', 'i64.mul-by-8']
# C135 ['code_motion_ifs', 'modify_custom_section_data', 'remove_function', 'remove_item_table']
# C136 ['code_motion_ifs', 'modify_custom_section_data', 'remove_function', 'remove_item_global', 'remove_item_memory', 'i64.mul-by-8']
# C137 ['code_motion_ifs', 'modify_custom_section_data', 'remove_function', 'remove_item_global', 'remove_item_memory']
# C138 ['code_motion_ifs', 'modify_custom_section_data', 'remove_function', 'remove_item_global', 'i64.mul-by-8']
# C139 ['code_motion_ifs', 'modify_custom_section_data', 'remove_function', 'remove_item_global']
# C140 ['code_motion_ifs', 'modify_custom_section_data', 'remove_function', 'remove_item_memory', 'i64.mul-by-8']
# C141 ['code_motion_ifs', 'modify_custom_section_data', 'remove_function', 'remove_item_memory']
# C142 ['code_motion_ifs', 'modify_custom_section_data', 'remove_function', 'i64.mul-by-8']
# C143 ['code_motion_ifs', 'modify_custom_section_data', 'remove_function']
# C144 ['code_motion_ifs', 'modify_custom_section_data', 'remove_item_table', 'remove_item_global', 'remove_item_memory', 'i64.mul-by-8']
# C145 ['code_motion_ifs', 'modify_custom_section_data', 'remove_item_table', 'remove_item_global', 'remove_item_memory']
# C146 ['code_motion_ifs', 'modify_custom_section_data', 'remove_item_table', 'remove_item_global', 'i64.mul-by-8']
# C147 ['code_motion_ifs', 'modify_custom_section_data', 'remove_item_table', 'remove_item_global']
# C148 ['code_motion_ifs', 'modify_custom_section_data', 'remove_item_table', 'remove_item_memory', 'i64.mul-by-8']
# C149 ['code_motion_ifs', 'modify_custom_section_data', 'remove_item_table', 'remove_item_memory']
# C150 ['code_motion_ifs', 'modify_custom_section_data', 'remove_item_table', 'i64.mul-by-8']
# C151 ['code_motion_ifs', 'modify_custom_section_data', 'remove_item_table']
# C152 ['code_motion_ifs', 'modify_custom_section_data', 'remove_item_global', 'remove_item_memory', 'i64.mul-by-8']
# C153 ['code_motion_ifs', 'modify_custom_section_data', 'remove_item_global', 'remove_item_memory']
# C154 ['code_motion_ifs', 'modify_custom_section_data', 'remove_item_global', 'i64.mul-by-8']
# C155 ['code_motion_ifs', 'modify_custom_section_data', 'remove_item_global']
# C156 ['code_motion_ifs', 'modify_custom_section_data', 'remove_item_memory', 'i64.mul-by-8']
# C157 ['code_motion_ifs', 'modify_custom_section_data', 'remove_item_memory']
# C158 ['code_motion_ifs', 'modify_custom_section_data', 'i64.mul-by-8']
# C159 ['code_motion_ifs', 'modify_custom_section_data']
# C160 ['code_motion_ifs', 'remove_function', 'remove_item_table', 'remove_item_global', 'remove_item_memory', 'i64.mul-by-8']
# C161 ['code_motion_ifs', 'remove_function', 'remove_item_table', 'remove_item_global', 'remove_item_memory']
# C162 ['code_motion_ifs', 'remove_function', 'remove_item_table', 'remove_item_global', 'i64.mul-by-8']
# C163 ['code_motion_ifs', 'remove_function', 'remove_item_table', 'remove_item_global']
# C164 ['code_motion_ifs', 'remove_function', 'remove_item_table', 'remove_item_memory', 'i64.mul-by-8']
# C165 ['code_motion_ifs', 'remove_function', 'remove_item_table', 'remove_item_memory']
# C166 ['code_motion_ifs', 'remove_function', 'remove_item_table', 'i64.mul-by-8']
# C167 ['code_motion_ifs', 'remove_function', 'remove_item_table']
# C168 ['code_motion_ifs', 'remove_function', 'remove_item_global', 'remove_item_memory', 'i64.mul-by-8']
# C169 ['code_motion_ifs', 'remove_function', 'remove_item_global', 'remove_item_memory']
# C170 ['code_motion_ifs', 'remove_function', 'remove_item_global', 'i64.mul-by-8']
# C171 ['code_motion_ifs', 'remove_function', 'remove_item_global']
# C172 ['code_motion_ifs', 'remove_function', 'remove_item_memory', 'i64.mul-by-8']
# C173 ['code_motion_ifs', 'remove_function', 'remove_item_memory']
# C174 ['code_motion_ifs', 'remove_function', 'i64.mul-by-8']
# C175 ['code_motion_ifs', 'remove_function']
# C176 ['code_motion_ifs', 'remove_item_table', 'remove_item_global', 'remove_item_memory', 'i64.mul-by-8']
# C177 ['code_motion_ifs', 'remove_item_table', 'remove_item_global', 'remove_item_memory']
# C178 ['code_motion_ifs', 'remove_item_table', 'remove_item_global', 'i64.mul-by-8']
# C179 ['code_motion_ifs', 'remove_item_table', 'remove_item_global']
# C180 ['code_motion_ifs', 'remove_item_table', 'remove_item_memory', 'i64.mul-by-8']
# C181 ['code_motion_ifs', 'remove_item_table', 'remove_item_memory']
# C182 ['code_motion_ifs', 'remove_item_table', 'i64.mul-by-8']
# C183 ['code_motion_ifs', 'remove_item_table']
# C184 ['code_motion_ifs', 'remove_item_global', 'remove_item_memory', 'i64.mul-by-8']
# C185 ['code_motion_ifs', 'remove_item_global', 'remove_item_memory']
# C186 ['code_motion_ifs', 'remove_item_global', 'i64.mul-by-8']
# C187 ['code_motion_ifs', 'remove_item_global']
# C188 ['code_motion_ifs', 'remove_item_memory', 'i64.mul-by-8']
# C189 ['code_motion_ifs', 'remove_item_memory']
# C190 ['code_motion_ifs', 'i64.mul-by-8']
# C191 ['code_motion_ifs']
# C192 ['modify_custom_section_data', 'remove_function', 'remove_item_table', 'remove_item_global', 'remove_item_memory', 'i64.mul-by-8']
# C193 ['modify_custom_section_data', 'remove_function', 'remove_item_table', 'remove_item_global', 'remove_item_memory']
# C194 ['modify_custom_section_data', 'remove_function', 'remove_item_table', 'remove_item_global', 'i64.mul-by-8']
# C195 ['modify_custom_section_data', 'remove_function', 'remove_item_table', 'remove_item_global']
# C196 ['modify_custom_section_data', 'remove_function', 'remove_item_table', 'remove_item_memory', 'i64.mul-by-8']
# C197 ['modify_custom_section_data', 'remove_function', 'remove_item_table', 'remove_item_memory']
# C198 ['modify_custom_section_data', 'remove_function', 'remove_item_table', 'i64.mul-by-8']
# C199 ['modify_custom_section_data', 'remove_function', 'remove_item_table']
# C200 ['modify_custom_section_data', 'remove_function', 'remove_item_global', 'remove_item_memory', 'i64.mul-by-8']
# C201 ['modify_custom_section_data', 'remove_function', 'remove_item_global', 'remove_item_memory']
# C202 ['modify_custom_section_data', 'remove_function', 'remove_item_global', 'i64.mul-by-8']
# C203 ['modify_custom_section_data', 'remove_function', 'remove_item_global']
# C204 ['modify_custom_section_data', 'remove_function', 'remove_item_memory', 'i64.mul-by-8']
# C205 ['modify_custom_section_data', 'remove_function', 'remove_item_memory']
# C206 ['modify_custom_section_data', 'remove_function', 'i64.mul-by-8']
# C207 ['modify_custom_section_data', 'remove_function']
# C208 ['modify_custom_section_data', 'remove_item_table', 'remove_item_global', 'remove_item_memory', 'i64.mul-by-8']
# C209 ['modify_custom_section_data', 'remove_item_table', 'remove_item_global', 'remove_item_memory']
# C210 ['modify_custom_section_data', 'remove_item_table', 'remove_item_global', 'i64.mul-by-8']
# C211 ['modify_custom_section_data', 'remove_item_table', 'remove_item_global']
# C212 ['modify_custom_section_data', 'remove_item_table', 'remove_item_memory', 'i64.mul-by-8']
# C213 ['modify_custom_section_data', 'remove_item_table', 'remove_item_memory']
# C214 ['modify_custom_section_data', 'remove_item_table', 'i64.mul-by-8']
# C215 ['modify_custom_section_data', 'remove_item_table']
# C216 ['modify_custom_section_data', 'remove_item_global', 'remove_item_memory', 'i64.mul-by-8']
# C217 ['modify_custom_section_data', 'remove_item_global', 'remove_item_memory']
# C218 ['modify_custom_section_data', 'remove_item_global', 'i64.mul-by-8']
# C219 ['modify_custom_section_data', 'remove_item_global']
# C220 ['modify_custom_section_data', 'remove_item_memory', 'i64.mul-by-8']
# C221 ['modify_custom_section_data', 'remove_item_memory']
# C222 ['modify_custom_section_data', 'i64.mul-by-8']
# C223 ['modify_custom_section_data']
# C224 ['remove_function', 'remove_item_table', 'remove_item_global', 'remove_item_memory', 'i64.mul-by-8']
# C225 ['remove_function', 'remove_item_table', 'remove_item_global', 'remove_item_memory']
# C226 ['remove_function', 'remove_item_table', 'remove_item_global', 'i64.mul-by-8']
# C227 ['remove_function', 'remove_item_table', 'remove_item_global']
# C228 ['remove_function', 'remove_item_table', 'remove_item_memory', 'i64.mul-by-8']
# C229 ['remove_function', 'remove_item_table', 'remove_item_memory']
# C230 ['remove_function', 'remove_item_table', 'i64.mul-by-8']
# C231 ['remove_function', 'remove_item_table']
# C232 ['remove_function', 'remove_item_global', 'remove_item_memory', 'i64.mul-by-8']
# C233 ['remove_function', 'remove_item_global', 'remove_item_memory']
# C234 ['remove_function', 'remove_item_global', 'i64.mul-by-8']
# C235 ['remove_function', 'remove_item_global']
# C236 ['remove_function', 'remove_item_memory', 'i64.mul-by-8']
# C237 ['remove_function', 'remove_item_memory']
# C238 ['remove_function', 'i64.mul-by-8']
# C239 ['remove_function']
# C240 ['remove_item_table', 'remove_item_global', 'remove_item_memory', 'i64.mul-by-8']
# C241 ['remove_item_table', 'remove_item_global', 'remove_item_memory']
# C242 ['remove_item_table', 'remove_item_global', 'i64.mul-by-8']
# C243 ['remove_item_table', 'remove_item_global']
# C244 ['remove_item_table', 'remove_item_memory', 'i64.mul-by-8']
# C245 ['remove_item_table', 'remove_item_memory']
# C246 ['remove_item_table', 'i64.mul-by-8']
# C247 ['remove_item_table']
# C248 ['remove_item_global', 'remove_item_memory', 'i64.mul-by-8']
# C249 ['remove_item_global', 'remove_item_memory']
# C250 ['remove_item_global', 'i64.mul-by-8']
# C251 ['remove_item_global']
# C252 ['remove_item_memory', 'i64.mul-by-8']
# C253 ['remove_item_memory']
# C254 ['i64.mul-by-8']
# C255 []

# %%
random.seed(10)

c2 = get_x_weight_by_applicability(alldf, 100, reverse=False)
for i, c2 in enumerate(c2):
    print(f"C{i}", c2)
# Out:
# {'codemotion_loops': 0.948587637395107, 'codemotion_ifs': 0.36532324784304454, 'modify_custom_section_data': 0.31875664815033683, 'remove_exports': 0.0, 'remove_function': 0.010518851199621794, 'remove_table': 0.05141236260489304, 'remove_global': 0.13828152700626403, 'remove_memory': 0.003663869518969389, 'remove_tag': 0.0, 'remove_data': 0.0, 'remove_element': 0.0, 'remove_item_function': 0.0, 'snip_function': 0.0, 'modify_data': 0.0, 'peep.i64.mul-by-8': 0.05673088287436473, 'peep.select-invert': 0.6876255761730292}
# C0 ['code_motion_loops']
# C1 ['code_motion_ifs', 'code_motion_loops']
# C2 ['remove_item_global']
# C3 ['code_motion_loops', 'modify_custom_section_data', 'select-invert.csv']
# C4 ['select-invert.csv']
# C5 ['code_motion_ifs']
# C6 ['code_motion_loops', 'modify_custom_section_data']
# C7 ['code_motion_loops', 'remove_item_table']
# C8 ['modify_custom_section_data']
# C9 ['code_motion_loops', 'modify_custom_section_data', 'remove_item_global']
# C10 ['i64.mul-by-8.csv', 'remove_item_table']
# C11 ['code_motion_ifs', 'code_motion_loops', 'select-invert.csv']
# C12 ['code_motion_loops', 'select-invert.csv']
# C13 ['code_motion_ifs', 'select-invert.csv']
# C14 ['code_motion_loops', 'i64.mul-by-8.csv', 'select-invert.csv']
# C15 ['code_motion_loops', 'i64.mul-by-8.csv']
# C16 ['code_motion_ifs', 'modify_custom_section_data']
# C17 ['i64.mul-by-8.csv']
# C18 ['remove_item_table', 'select-invert.csv']
# C19 ['modify_custom_section_data', 'select-invert.csv']
# C20 ['remove_function', 'select-invert.csv']
# C21 ['remove_item_global', 'select-invert.csv']
# C22 ['code_motion_loops', 'i64.mul-by-8.csv', 'remove_item_global']
# C23 ['code_motion_ifs', 'code_motion_loops', 'remove_item_global']
# C24 ['remove_item_table']
# C25 ['code_motion_ifs', 'code_motion_loops', 'modify_custom_section_data', 'select-invert.csv']
# C26 ['remove_function']
# C27 ['code_motion_loops', 'remove_item_global']
# C28 ['code_motion_ifs', 'modify_custom_section_data', 'select-invert.csv']
# C29 ['modify_custom_section_data', 'remove_item_global']
# C30 ['code_motion_loops', 'remove_item_global', 'select-invert.csv']
# C31 ['code_motion_loops', 'remove_function']
# C32 ['code_motion_ifs', 'remove_item_global']
# C33 ['code_motion_loops', 'remove_item_memory']
# C34 ['i64.mul-by-8.csv', 'modify_custom_section_data']
# C35 ['i64.mul-by-8.csv', 'select-invert.csv']
# C36 ['code_motion_ifs', 'code_motion_loops', 'modify_custom_section_data']
# C37 ['code_motion_ifs', 'remove_function', 'select-invert.csv']
# C38 ['code_motion_ifs', 'code_motion_loops', 'remove_item_table']
# C39 ['modify_custom_section_data', 'remove_item_table']
# C40 ['code_motion_loops', 'remove_item_table', 'select-invert.csv']
# C41 ['remove_item_global', 'remove_item_table']
# C42 ['code_motion_loops', 'i64.mul-by-8.csv', 'modify_custom_section_data', 'select-invert.csv']
# C43 ['code_motion_loops', 'modify_custom_section_data', 'remove_item_table', 'select-invert.csv']
# C44 ['i64.mul-by-8.csv', 'modify_custom_section_data', 'remove_item_global']
# C45 ['code_motion_ifs', 'code_motion_loops', 'i64.mul-by-8.csv']
# C46 ['modify_custom_section_data', 'remove_item_table', 'select-invert.csv']
# C47 ['code_motion_ifs', 'remove_item_table']
# C48 ['remove_item_global', 'remove_item_table', 'select-invert.csv']
# C49 ['i64.mul-by-8.csv', 'remove_item_global', 'select-invert.csv']
# C50 ['code_motion_ifs', 'code_motion_loops', 'i64.mul-by-8.csv', 'remove_item_global', 'select-invert.csv']
# C51 ['code_motion_loops', 'i64.mul-by-8.csv', 'modify_custom_section_data']
# C52 ['code_motion_loops', 'modify_custom_section_data', 'remove_item_global', 'select-invert.csv']
# C53 ['i64.mul-by-8.csv', 'modify_custom_section_data', 'remove_item_table']
# C54 ['code_motion_ifs', 'code_motion_loops', 'remove_item_global', 'select-invert.csv']
# C55 ['code_motion_loops', 'remove_item_global', 'remove_item_table']
# C56 ['code_motion_ifs', 'code_motion_loops', 'i64.mul-by-8.csv', 'select-invert.csv']
# C57 ['code_motion_loops', 'modify_custom_section_data', 'remove_item_table']
# C58 ['code_motion_ifs', 'i64.mul-by-8.csv', 'modify_custom_section_data']
# C59 ['code_motion_ifs', 'modify_custom_section_data', 'remove_item_table']
# C60 ['code_motion_ifs', 'remove_item_global', 'select-invert.csv']
# C61 ['i64.mul-by-8.csv', 'remove_item_global', 'remove_item_table']
# C62 ['code_motion_loops', 'i64.mul-by-8.csv', 'remove_item_global', 'select-invert.csv']
# C63 ['code_motion_ifs', 'code_motion_loops', 'remove_item_global', 'remove_item_table', 'select-invert.csv']
# C64 ['code_motion_ifs', 'i64.mul-by-8.csv']
# C65 ['remove_item_memory']
# C66 ['code_motion_loops', 'modify_custom_section_data', 'remove_function']
# C67 ['code_motion_loops', 'i64.mul-by-8.csv', 'remove_item_table']
# C68 ['code_motion_ifs', 'i64.mul-by-8.csv', 'remove_item_global']
# C69 ['i64.mul-by-8.csv', 'modify_custom_section_data', 'select-invert.csv']
# C70 ['code_motion_ifs', 'i64.mul-by-8.csv', 'select-invert.csv']
# C71 ['modify_custom_section_data', 'remove_item_global', 'select-invert.csv']
# C72 ['code_motion_ifs', 'modify_custom_section_data', 'remove_item_global']
# C73 ['code_motion_ifs', 'remove_item_table', 'select-invert.csv']
# C74 ['code_motion_ifs', 'code_motion_loops', 'modify_custom_section_data', 'remove_item_table']
# C75 ['code_motion_ifs', 'code_motion_loops', 'modify_custom_section_data', 'remove_item_table', 'select-invert.csv']
# C76 ['code_motion_loops', 'remove_item_global', 'remove_item_table', 'select-invert.csv']
# C77 ['code_motion_loops', 'remove_item_memory', 'select-invert.csv']
# C78 ['code_motion_ifs', 'remove_function']
# C79 ['code_motion_ifs', 'code_motion_loops', 'remove_function']
# C80 ['code_motion_loops', 'remove_function', 'remove_item_table', 'select-invert.csv']
# C81 ['code_motion_ifs', 'code_motion_loops', 'modify_custom_section_data', 'remove_item_global', 'select-invert.csv']
# C82 ['i64.mul-by-8.csv', 'remove_item_global']
# C83 ['code_motion_ifs', 'code_motion_loops', 'remove_item_table', 'select-invert.csv']
# C84 ['code_motion_ifs', 'code_motion_loops', 'modify_custom_section_data', 'remove_item_global', 'remove_item_table']
# C85 ['code_motion_ifs', 'modify_custom_section_data', 'remove_item_table', 'select-invert.csv']
# C86 ['code_motion_ifs', 'code_motion_loops', 'modify_custom_section_data', 'remove_item_global']
# C87 ['code_motion_ifs', 'code_motion_loops', 'remove_function', 'select-invert.csv']
# C88 ['modify_custom_section_data', 'remove_function']
# C89 ['code_motion_ifs', 'remove_item_memory', 'select-invert.csv']
# C90 ['code_motion_ifs', 'modify_custom_section_data', 'remove_item_global', 'select-invert.csv']
# C91 ['i64.mul-by-8.csv', 'remove_item_memory']
# C92 ['code_motion_loops', 'modify_custom_section_data', 'remove_function', 'select-invert.csv']
# C93 ['code_motion_loops', 'modify_custom_section_data', 'remove_item_global', 'remove_item_table']
# C94 ['modify_custom_section_data', 'remove_item_memory']
# C95 ['code_motion_ifs', 'code_motion_loops', 'i64.mul-by-8.csv', 'remove_item_global']
# C96 ['code_motion_loops', 'remove_item_memory', 'remove_item_table', 'select-invert.csv']
# C97 ['remove_item_memory', 'select-invert.csv']
# C98 ['code_motion_loops', 'remove_function', 'remove_item_table']
# C99 ['code_motion_loops', 'remove_function', 'select-invert.csv']
