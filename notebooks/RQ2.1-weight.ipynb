# %%
import pandas as pd


# For type checking
from pandas.api.types import is_string_dtype
from pandas.api.types import is_numeric_dtype
from pandas.api.types import is_object_dtype

# %%
vt_benchmark = pd.read_csv("vt.csv")

# %%
display(vt_benchmark)
# Out:
#       Unnamed: 0                                                 id  \
# 0              0  bd11f315be4000436e932a2f10e3d398c43a0e66cef927...
# 1              0  055279cf9aafe1b7eb3b413fe02fa874e40a0aeb227e76...
# 2              0  cc6b248b292b08b15d013993cea07bdc7221ead2a44f73...
# 3              0  415067b43b6ddf70f64124c10df7e5d899f36b24371581...
# 4              0  c8b390fc67508432ff3621f60908ebfd948c85baca2e7b...
# ...          ...                                                ...
# 8456           0  259e8bdf27cb5024db03b036dac6aedd5e4cc32e5e483b...
# 8457           0  2dd65578c68612c77463dfac02713831d8c795ea9c914a...
# 8458           0  c51e58b56ab64965bd679138ea0d44d241fd2261355c28...
# 8459           0  21d09972c350c142ba84ecfbb4b282eb29ba34eec697b7...
# 8460           0  5ce958f63811e2073917690139ef6e7b01399dc3f1c0af...
#
#       non_benign  engines Acronis (Static ML)    Ad-Aware   AhnLab-V3  \
# 0              0       59          undetected  undetected  undetected
# 1              0       59          undetected  undetected  undetected
# 2              0       59          undetected  undetected  undetected
# 3              0       59          undetected  undetected  undetected
# 4              0       58          undetected  undetected  undetected
# ...          ...      ...                 ...         ...         ...
# 8456           0       59          undetected  undetected  undetected
# 8457           0       59          undetected  undetected  undetected
# 8458           0       59          undetected  undetected  undetected
# 8459           0       58          undetected  undetected  undetected
# 8460           0       59          undetected  undetected  undetected
#
#            ALYac   Antiy-AVL     Arcabit  ...                      Cylance  \
# 0     undetected  undetected  undetected  ...  unable_to_process_file_type
# 1     undetected  undetected  undetected  ...  unable_to_process_file_type
# 2     undetected  undetected  undetected  ...  unable_to_process_file_type
# 3     undetected  undetected  undetected  ...  unable_to_process_file_type
# 4     undetected  undetected  undetected  ...  unable_to_process_file_type
# ...          ...         ...         ...  ...                          ...
# 8456  undetected  undetected  undetected  ...  unable_to_process_file_type
# 8457  undetected  undetected  undetected  ...  unable_to_process_file_type
# 8458  undetected  undetected  undetected  ...  unable_to_process_file_type
# 8459  undetected  undetected  undetected  ...  unable_to_process_file_type
# 8460  undetected  undetected  undetected  ...  unable_to_process_file_type
#
#                           Elastic           Palo Alto Networks  \
# 0     unable_to_process_file_type  unable_to_process_file_type
# 1     unable_to_process_file_type  unable_to_process_file_type
# 2     unable_to_process_file_type  unable_to_process_file_type
# 3     unable_to_process_file_type  unable_to_process_file_type
# 4     unable_to_process_file_type  unable_to_process_file_type
# ...                           ...                          ...
# 8456  unable_to_process_file_type  unable_to_process_file_type
# 8457  unable_to_process_file_type  unable_to_process_file_type
# 8458  unable_to_process_file_type  unable_to_process_file_type
# 8459  unable_to_process_file_type  unable_to_process_file_type
# 8460  unable_to_process_file_type  unable_to_process_file_type
#
#                    SecureAge APEX      SentinelOne (Static ML)  \
# 0     unable_to_process_file_type  unable_to_process_file_type
# 1     unable_to_process_file_type  unable_to_process_file_type
# 2     unable_to_process_file_type  unable_to_process_file_type
# 3     unable_to_process_file_type  unable_to_process_file_type
# 4     unable_to_process_file_type  unable_to_process_file_type
# ...                           ...                          ...
# 8456  unable_to_process_file_type  unable_to_process_file_type
# 8457  unable_to_process_file_type  unable_to_process_file_type
# 8458  unable_to_process_file_type  unable_to_process_file_type
# 8459  unable_to_process_file_type  unable_to_process_file_type
# 8460  unable_to_process_file_type  unable_to_process_file_type
#
#           Symantec Mobile Insight                      TEHTRIS  \
# 0     unable_to_process_file_type  unable_to_process_file_type
# 1     unable_to_process_file_type  unable_to_process_file_type
# 2     unable_to_process_file_type  unable_to_process_file_type
# 3     unable_to_process_file_type  unable_to_process_file_type
# 4     unable_to_process_file_type  unable_to_process_file_type
# ...                           ...                          ...
# 8456  unable_to_process_file_type  unable_to_process_file_type
# 8457  unable_to_process_file_type  unable_to_process_file_type
# 8458  unable_to_process_file_type  unable_to_process_file_type
# 8459  unable_to_process_file_type  unable_to_process_file_type
# 8460  unable_to_process_file_type  unable_to_process_file_type
#
#                          Trapmine                    Trustlook  \
# 0     unable_to_process_file_type  unable_to_process_file_type
# 1     unable_to_process_file_type  unable_to_process_file_type
# 2     unable_to_process_file_type  unable_to_process_file_type
# 3     unable_to_process_file_type  unable_to_process_file_type
# 4     unable_to_process_file_type  unable_to_process_file_type
# ...                           ...                          ...
# 8456  unable_to_process_file_type  unable_to_process_file_type
# 8457  unable_to_process_file_type  unable_to_process_file_type
# 8458  unable_to_process_file_type  unable_to_process_file_type
# 8459  unable_to_process_file_type  unable_to_process_file_type
# 8460  unable_to_process_file_type  unable_to_process_file_type
#
#                           Webroot
# 0     unable_to_process_file_type
# 1     unable_to_process_file_type
# 2     unable_to_process_file_type
# 3     unable_to_process_file_type
# 4     unable_to_process_file_type
# ...                           ...
# 8456  unable_to_process_file_type
# 8457  unable_to_process_file_type
# 8458  unable_to_process_file_type
# 8459  unable_to_process_file_type
# 8460  unable_to_process_file_type
#
# [8461 rows x 78 columns]

# %%
mal = vt_benchmark[vt_benchmark['non_benign'] > 0]

terms = [f for f in list(mal.values.flatten()) if f != 'undetected' and 
         f != 'unable_to_process_file_type' 
         and not f.__str__().endswith(".wasm")
         and f != 'no_response'
         and f != 'timeout'
        ]

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [30, 20]

terms = { t: len([f for f in terms if f == t]) for t in terms }
print(terms)

plt.bar(x=list(range(len(terms.keys()))), height=list(terms.values()))
plt.xticks(list(range(len(terms.keys()))),list(terms.keys()), rotation=45, ha='right')
# Out:
# {0: 33, 19: 1, 60: 5, 'application.bitcoinminer.ahr': 18, 'misc.riskware.js.coinminer': 4, 'other:malware-gen_[trj]': 5, 'application.bitcoinminer.ahr_(b)': 3, 'generic.application.coinminer.az': 9, 'detected': 27, 'pua.wasm.coinminer': 24, 'trojan.js.minewasm.y': 1, 'trojan.js.minewasm.4!c': 1, 'malware_(ai_score=76)': 2, 'wasm/cryptonight': 20, 'miner.wasmwebcoin': 8, 'js.trojan.minewasm.eddm': 1, 20: 1, 'application.bitcoinminer.ahs': 8, 'malware@#1qvve9pb3qu0r': 1, 'application.bitcoinminer.ahs_(b)': 1, 'not-a-virus:risktool.wasm.miner.d': 13, 'riskware.ukp.bitcoinminer.1!c': 1, 'wasm/coinminer.b': 10, 4: 6, 59: 20, 'wasm/coinminer.v_potentially_unwanted': 1, 'generic.application.agent.bgraqi': 1, 2: 13, 'coinminer_cryptonight.sm-wasm': 8, 9: 1, 56: 1, 'pua/coinminer.tbkts': 1, 'applicunwnt@#2qfidwr7udso8': 1, nan: 0, 53: 1, 'virustotal': 2, 58: 6, 3: 2, 'not-a-virus:heur:risktool.wasm.cryptonight.heur': 3, 6: 3, 'pua.bitcoinminer': 3, 'riskware.wasm.miner.1!c': 9, 'malware@#1y4bbun0pz3gz': 1, 31: 1, 'application.bitcoinminer.ub': 5, 'wasm/cryptojs': 3, 'trojan/generic.assuf.285a8': 1, 'pua/coinminer.tnvhl': 1, 'malicious_(score:_99)': 2, 'tool.btcmine.1100': 2, 'application.bitcoinminer.ub_(b)': 1, 'wasm/coinminer.b_potentially_unwanted': 3, 'riskware/bitcoinminer93ea': 1, 'malware_(ai_score=100)': 2, 'trj/coinminer.a': 1, 'malware.generic-script.save.6e95479e': 3, 'bitcoinminer_(pua)': 3, 'wasm.s.coinminer.68796': 1, 'malware@#2ikhkvxpx6gyc': 1, 1: 1, 18: 2, 'malware_(ai_score=78)': 1, 'win32.risk.miner.amcd': 1, 30: 1, 'trojan.coinminer.i': 5, 'pua/cryptominer.gen': 1, 'wasm/wasm/coinminer.a': 1, 'trojan.coinminer.i_(b)': 1, 'riskware/coinminer': 2, 'trojan:win32/coinminer': 1, 'hktl_coinmine': 2, 'wasm/abrisk.sfzi-8': 1, 'malware_(ai_score=71)': 1, 'win32.risk.miner.hssz': 1, 26: 1, 'application.bitcoinminer.aam': 5, 'application.bitcoinminer.aam_(b)': 1, 'malware_(ai_score=91)': 1, 'wasm.s.coinminer.68803': 1}
# ([<matplotlib.axis.XTick at 0x7fa860f1ffd0>,
#   <matplotlib.axis.XTick at 0x7fa860f1ffa0>,
#   <matplotlib.axis.XTick at 0x7fa860f1f7f0>,
#   <matplotlib.axis.XTick at 0x7fa8a0ffadc0>,
#   <matplotlib.axis.XTick at 0x7fa8a1011550>,
#   <matplotlib.axis.XTick at 0x7fa8a1011ca0>,
#   <matplotlib.axis.XTick at 0x7fa8a1016430>,
#   <matplotlib.axis.XTick at 0x7fa8a1011d90>,
#   <matplotlib.axis.XTick at 0x7fa8a0f563d0>,
#   <matplotlib.axis.XTick at 0x7fa8a1016dc0>,
#   <matplotlib.axis.XTick at 0x7fa8a101b550>,
#   <matplotlib.axis.XTick at 0x7fa8a101bca0>,
#   <matplotlib.axis.XTick at 0x7fa8a1023430>,
#   <matplotlib.axis.XTick at 0x7fa8a1023b80>,
#   <matplotlib.axis.XTick at 0x7fa8a1023700>,
#   <matplotlib.axis.XTick at 0x7fa8a101b610>,
#   <matplotlib.axis.XTick at 0x7fa8a102b1c0>,
#   <matplotlib.axis.XTick at 0x7fa8a102b820>,
#   <matplotlib.axis.XTick at 0x7fa8a1025040>,
#   <matplotlib.axis.XTick at 0x7fa8a1025760>,
#   <matplotlib.axis.XTick at 0x7fa8a1037040>,
#   <matplotlib.axis.XTick at 0x7fa8a1025850>,
#   <matplotlib.axis.XTick at 0x7fa8a1011910>,
#   <matplotlib.axis.XTick at 0x7fa8a1037370>,
#   <matplotlib.axis.XTick at 0x7fa8a1037a30>,
#   <matplotlib.axis.XTick at 0x7fa8a103c1c0>,
#   <matplotlib.axis.XTick at 0x7fa8a103c910>,
#   <matplotlib.axis.XTick at 0x7fa8a103cbb0>,
#   <matplotlib.axis.XTick at 0x7fa8a1037cd0>,
#   <matplotlib.axis.XTick at 0x7fa8a1025070>,
#   <matplotlib.axis.XTick at 0x7fa8a10445e0>,
#   <matplotlib.axis.XTick at 0x7fa8a1044d30>,
#   <matplotlib.axis.XTick at 0x7fa8a104d4c0>,
#   <matplotlib.axis.XTick at 0x7fa8a104dc10>,
#   <matplotlib.axis.XTick at 0x7fa8a104d880>,
#   <matplotlib.axis.XTick at 0x7fa8a1044610>,
#   <matplotlib.axis.XTick at 0x7fa8a1052220>,
#   <matplotlib.axis.XTick at 0x7fa8a10528b0>,
#   <matplotlib.axis.XTick at 0x7fa8a105c040>,
#   <matplotlib.axis.XTick at 0x7fa8a105c790>,
#   <matplotlib.axis.XTick at 0x7fa8a105f070>,
#   <matplotlib.axis.XTick at 0x7fa8a105c7f0>,
#   <matplotlib.axis.XTick at 0x7fa8a101b2b0>,
#   <matplotlib.axis.XTick at 0x7fa8a105f310>,
#   <matplotlib.axis.XTick at 0x7fa8a105fa60>,
#   <matplotlib.axis.XTick at 0x7fa8a10681f0>,
#   <matplotlib.axis.XTick at 0x7fa8a1068940>,
#   <matplotlib.axis.XTick at 0x7fa8a1068be0>,
#   <matplotlib.axis.XTick at 0x7fa8a105fd30>,
#   <matplotlib.axis.XTick at 0x7fa8a105c7c0>,
#   <matplotlib.axis.XTick at 0x7fa8a106b550>,
#   <matplotlib.axis.XTick at 0x7fa8a106bca0>,
#   <matplotlib.axis.XTick at 0x7fa870807430>,
#   <matplotlib.axis.XTick at 0x7fa870807b80>,
#   <matplotlib.axis.XTick at 0x7fa8708077f0>,
#   <matplotlib.axis.XTick at 0x7fa8a106b580>,
#   <matplotlib.axis.XTick at 0x7fa87080d190>,
#   <matplotlib.axis.XTick at 0x7fa87080d820>,
#   <matplotlib.axis.XTick at 0x7fa870810040>,
#   <matplotlib.axis.XTick at 0x7fa870810700>,
#   <matplotlib.axis.XTick at 0x7fa870810e50>,
#   <matplotlib.axis.XTick at 0x7fa870810760>,
#   <matplotlib.axis.XTick at 0x7fa8a1044340>,
#   <matplotlib.axis.XTick at 0x7fa870814280>,
#   <matplotlib.axis.XTick at 0x7fa8708149d0>,
#   <matplotlib.axis.XTick at 0x7fa870823160>,
#   <matplotlib.axis.XTick at 0x7fa8708238b0>,
#   <matplotlib.axis.XTick at 0x7fa870823b20>,
#   <matplotlib.axis.XTick at 0x7fa870814c70>,
#   <matplotlib.axis.XTick at 0x7fa870810730>,
#   <matplotlib.axis.XTick at 0x7fa8708244c0>,
#   <matplotlib.axis.XTick at 0x7fa870824c10>,
#   <matplotlib.axis.XTick at 0x7fa8708313a0>,
#   <matplotlib.axis.XTick at 0x7fa870831af0>,
#   <matplotlib.axis.XTick at 0x7fa870831760>,
#   <matplotlib.axis.XTick at 0x7fa8708244f0>,
#   <matplotlib.axis.XTick at 0x7fa870836100>,
#   <matplotlib.axis.XTick at 0x7fa8708367c0>,
#   <matplotlib.axis.XTick at 0x7fa87083e070>],
#  [Text(0, 0, '0'),
#   Text(1, 0, '19'),
#   Text(2, 0, '60'),
#   Text(3, 0, 'application.bitcoinminer.ahr'),
#   Text(4, 0, 'misc.riskware.js.coinminer'),
#   Text(5, 0, 'other:malware-gen_[trj]'),
#   Text(6, 0, 'application.bitcoinminer.ahr_(b)'),
#   Text(7, 0, 'generic.application.coinminer.az'),
#   Text(8, 0, 'detected'),
#   Text(9, 0, 'pua.wasm.coinminer'),
#   Text(10, 0, 'trojan.js.minewasm.y'),
#   Text(11, 0, 'trojan.js.minewasm.4!c'),
#   Text(12, 0, 'malware_(ai_score=76)'),
#   Text(13, 0, 'wasm/cryptonight'),
#   Text(14, 0, 'miner.wasmwebcoin'),
#   Text(15, 0, 'js.trojan.minewasm.eddm'),
#   Text(16, 0, '20'),
#   Text(17, 0, 'application.bitcoinminer.ahs'),
#   Text(18, 0, 'malware@#1qvve9pb3qu0r'),
#   Text(19, 0, 'application.bitcoinminer.ahs_(b)'),
#   Text(20, 0, 'not-a-virus:risktool.wasm.miner.d'),
#   Text(21, 0, 'riskware.ukp.bitcoinminer.1!c'),
#   Text(22, 0, 'wasm/coinminer.b'),
#   Text(23, 0, '4'),
#   Text(24, 0, '59'),
#   Text(25, 0, 'wasm/coinminer.v_potentially_unwanted'),
#   Text(26, 0, 'generic.application.agent.bgraqi'),
#   Text(27, 0, '2'),
#   Text(28, 0, 'coinminer_cryptonight.sm-wasm'),
#   Text(29, 0, '9'),
#   Text(30, 0, '56'),
#   Text(31, 0, 'pua/coinminer.tbkts'),
#   Text(32, 0, 'applicunwnt@#2qfidwr7udso8'),
#   Text(33, 0, 'nan'),
#   Text(34, 0, '53'),
#   Text(35, 0, 'virustotal'),
#   Text(36, 0, '58'),
#   Text(37, 0, '3'),
#   Text(38, 0, 'not-a-virus:heur:risktool.wasm.cryptonight.heur'),
#   Text(39, 0, '6'),
#   Text(40, 0, 'pua.bitcoinminer'),
#   Text(41, 0, 'riskware.wasm.miner.1!c'),
#   Text(42, 0, 'malware@#1y4bbun0pz3gz'),
#   Text(43, 0, '31'),
#   Text(44, 0, 'application.bitcoinminer.ub'),
#   Text(45, 0, 'wasm/cryptojs'),
#   Text(46, 0, 'trojan/generic.assuf.285a8'),
#   Text(47, 0, 'pua/coinminer.tnvhl'),
#   Text(48, 0, 'malicious_(score:_99)'),
#   Text(49, 0, 'tool.btcmine.1100'),
#   Text(50, 0, 'application.bitcoinminer.ub_(b)'),
#   Text(51, 0, 'wasm/coinminer.b_potentially_unwanted'),
#   Text(52, 0, 'riskware/bitcoinminer93ea'),
#   Text(53, 0, 'malware_(ai_score=100)'),
#   Text(54, 0, 'trj/coinminer.a'),
#   Text(55, 0, 'malware.generic-script.save.6e95479e'),
#   Text(56, 0, 'bitcoinminer_(pua)'),
#   Text(57, 0, 'wasm.s.coinminer.68796'),
#   Text(58, 0, 'malware@#2ikhkvxpx6gyc'),
#   Text(59, 0, '1'),
#   Text(60, 0, '18'),
#   Text(61, 0, 'malware_(ai_score=78)'),
#   Text(62, 0, 'win32.risk.miner.amcd'),
#   Text(63, 0, '30'),
#   Text(64, 0, 'trojan.coinminer.i'),
#   Text(65, 0, 'pua/cryptominer.gen'),
#   Text(66, 0, 'wasm/wasm/coinminer.a'),
#   Text(67, 0, 'trojan.coinminer.i_(b)'),
#   Text(68, 0, 'riskware/coinminer'),
#   Text(69, 0, 'trojan:win32/coinminer'),
#   Text(70, 0, 'hktl_coinmine'),
#   Text(71, 0, 'wasm/abrisk.sfzi-8'),
#   Text(72, 0, 'malware_(ai_score=71)'),
#   Text(73, 0, 'win32.risk.miner.hssz'),
#   Text(74, 0, '26'),
#   Text(75, 0, 'application.bitcoinminer.aam'),
#   Text(76, 0, 'application.bitcoinminer.aam_(b)'),
#   Text(77, 0, 'malware_(ai_score=91)'),
#   Text(78, 0, 'wasm.s.coinminer.68803')])

# %%
mal = vt_benchmark[vt_benchmark['non_benign'] > 0]

display(mal)
mal.to_csv("mal.csv")
# Out:
#       Unnamed: 0                                                 id  \
# 993            0  0d99646229ea6010fa510333161653955eadb11acdb51c...
# 1522           0  dc11d82d85b5745ff2c69e901b9b6b42da9e1c102ae45e...
# 1656           0  942be4f7a78a50453f8949a0a20e1ae66a5b84a67db712...
# 1885           0  5bc5334382f650c8a7cc38d651b86db06eb755b64662ea...
# 2012           0  fb15929fb454d62f2dbabb306d9b73b3b1fe4526e6b4a7...
# 2183           0  f0b244090f9e4a9f599a68f42d7a89e003026202324cf8...
# 2806           0  d2141ff28b1c81a90177319d3f4ddc17ab5c493d165be7...
# 2816           0  a27b45ef89b961b8c8ff78b6ab580ce0d866647c3ae03c...
# 3114           0  6b8c789921d0ca5531295477c7703d2f5ec619a8bbb51d...
# 3201           0  c1be4071ccc59e468803cb9b9eae25ec3aaff24f1d37ee...
# 3378           0  089dd3123f4322e38e3130b3c051b00f66b52070a56342...
# 3497           0  4cbdbbb1bc6880ecff2f1bc6cb66444b319cc57cf47e8a...
# 3690           0  aafff58765c917b0900726ecca11c715c38c3c25b1be9e...
# 3774           0  046dc081076d9cea6831967619b862cc80fa8c23813464...
# 4188           0  59955b4c538d0b45961e19b70c4ab7a101968561a35318...
# 4285           0  65debcbe8c6e64a04c9c3b75794b77644526a514d89a09...
# 4532           0  47d299593572faf8941351f3ef8e46bc18eb684f679d87...
# 4715           0  000415b2639c960e039299fde2a52e7e9c692c212c1fa6...
# 4778           0  24aae13ae29d012fdf36cacc6871640f6883f07a0d42ee...
# 5117           0  643116ff7be6f5a1e538ceeca66f7815e3e1f0c95033fe...
# 5209           0  89a3645c1680125a0a2bcf30c33456f30a8235efbfb3c7...
# 5460           0  7c36f462eacff709b8821154424abb0386373d7d763c45...
# 5605           0  a74a7cb854cd33442d8ef481d341b4a0632b88d8def1d2...
# 5983           0  e09c32c505dc641e678cc4c7095315454d8d7f1094d0e3...
# 6032           0  119c53ebaf6077a5f445262ad91d91dfa137dac4127f73...
# 6331           0  fbdd1efaa585e95d802322c976e39430e6abb21de467be...
# 6883           0  9d30e7f065cd00a47d8e10e27acc443a33977176484ca1...
# 6942           0  dceaf65bf86d2de5bc460eef3b3c858ccdc82f47846975...
# 7203           0  006b2fb61de05aa4fec89f479ce45b6295c6080d6ec4bd...
# 7289           0  a32a6f4bbd1918accf9ce8206bbf8e1346eb93c283d44e...
# 7301           0  68ca7c0e99a5df6d36e52008df1b20c108d1821f28a40c...
# 7696           0  15b86a25f45761119d9819ad9eaedce5239a23d66f12b3...
# 7977           0  8ebf4e44c47b6b61d313bd2580bd788a1daa029541fe21...
#
#       non_benign  engines          Acronis (Static ML)  \
# 993           19       60                   undetected
# 1522          20       60                   undetected
# 1656           4       59                   undetected
# 1885           2       59                   undetected
# 2012           4       59                   undetected
# 2183           2       59                   undetected
# 2806           9       56                   undetected
# 2816           2       53                   undetected
# 3114           2       58                   undetected
# 3201           2       58                   undetected
# 3378           2       59                   undetected
# 3497           3       59                   undetected
# 3690           6       58                   undetected
# 3774           6       59                   undetected
# 4188           2       59                   undetected
# 4285           2       59                   undetected
# 4532          31       60                   undetected
# 4715           3       58  unable_to_process_file_type
# 4778           4       59                   undetected
# 5117           6       59                   undetected
# 5209           2       58  unable_to_process_file_type
# 5460           4       59                   undetected
# 5605           2       59                   undetected
# 5983           1       58  unable_to_process_file_type
# 6032           2       59                   undetected
# 6331          18       59                   undetected
# 6883          30       60                   undetected
# 6942           2       59                   undetected
# 7203           4       59                   undetected
# 7289          18       59                   undetected
# 7301           2       59                   undetected
# 7696           4       59                   undetected
# 7977          26       60                   undetected
#
#                           Ad-Aware      AhnLab-V3  \
# 993   application.bitcoinminer.ahr     undetected
# 1522  application.bitcoinminer.ahs     undetected
# 1656                    undetected     undetected
# 1885                    undetected     undetected
# 2012                    undetected     undetected
# 2183                    undetected     undetected
# 2806                    undetected     undetected
# 2816                    undetected     undetected
# 3114                    undetected     undetected
# 3201                    undetected     undetected
# 3378                    undetected     undetected
# 3497                    undetected     undetected
# 3690                    undetected     undetected
# 3774                    undetected     undetected
# 4188                    undetected     undetected
# 4285                    undetected     undetected
# 4532   application.bitcoinminer.ub  wasm/cryptojs
# 4715                    undetected     undetected
# 4778                    undetected     undetected
# 5117                    undetected     undetected
# 5209                    undetected     undetected
# 5460                    undetected     undetected
# 5605                    undetected     undetected
# 5983                    undetected     undetected
# 6032                    undetected     undetected
# 6331  application.bitcoinminer.ahr     undetected
# 6883            trojan.coinminer.i  wasm/cryptojs
# 6942                    undetected     undetected
# 7203                    undetected     undetected
# 7289  application.bitcoinminer.ahr     undetected
# 7301                    undetected     undetected
# 7696                    undetected     undetected
# 7977  application.bitcoinminer.aam  wasm/cryptojs
#
#                              ALYac                   Antiy-AVL  \
# 993     misc.riskware.js.coinminer                  undetected
# 1522  application.bitcoinminer.ahs                  undetected
# 1656                    undetected                  undetected
# 1885                    undetected                  undetected
# 2012                    undetected                  undetected
# 2183                    undetected                  undetected
# 2806                    undetected                  undetected
# 2816                    undetected                  undetected
# 3114                    undetected                  undetected
# 3201                    undetected                  undetected
# 3378                    undetected                  undetected
# 3497                    undetected                  undetected
# 3690                    undetected                  undetected
# 3774                    undetected                  undetected
# 4188                    undetected                  undetected
# 4285                    undetected                  undetected
# 4532    misc.riskware.js.coinminer  trojan/generic.assuf.285a8
# 4715                    undetected                  undetected
# 4778                    undetected                  undetected
# 5117                    undetected                  undetected
# 5209                    undetected                  undetected
# 5460                    undetected                  undetected
# 5605                    undetected                  undetected
# 5983                    undetected                  undetected
# 6032                    undetected                  undetected
# 6331  application.bitcoinminer.ahr                  undetected
# 6883    misc.riskware.js.coinminer                  undetected
# 6942                    undetected                  undetected
# 7203                    undetected                  undetected
# 7289  application.bitcoinminer.ahr                  undetected
# 7301                    undetected                  undetected
# 7696                    undetected                  undetected
# 7977    misc.riskware.js.coinminer                  undetected
#
#                            Arcabit  ...                      Cylance  \
# 993                     undetected  ...  unable_to_process_file_type
# 1522  application.bitcoinminer.ahs  ...  unable_to_process_file_type
# 1656                    undetected  ...  unable_to_process_file_type
# 1885                    undetected  ...  unable_to_process_file_type
# 2012                    undetected  ...  unable_to_process_file_type
# 2183                    undetected  ...  unable_to_process_file_type
# 2806                    undetected  ...  unable_to_process_file_type
# 2816                    undetected  ...  unable_to_process_file_type
# 3114                    undetected  ...  unable_to_process_file_type
# 3201                    undetected  ...  unable_to_process_file_type
# 3378                    undetected  ...  unable_to_process_file_type
# 3497                    undetected  ...  unable_to_process_file_type
# 3690                    undetected  ...  unable_to_process_file_type
# 3774                    undetected  ...  unable_to_process_file_type
# 4188                    undetected  ...  unable_to_process_file_type
# 4285                    undetected  ...  unable_to_process_file_type
# 4532                    undetected  ...  unable_to_process_file_type
# 4715                    undetected  ...  unable_to_process_file_type
# 4778                    undetected  ...  unable_to_process_file_type
# 5117                    undetected  ...  unable_to_process_file_type
# 5209                    undetected  ...  unable_to_process_file_type
# 5460                    undetected  ...  unable_to_process_file_type
# 5605                    undetected  ...  unable_to_process_file_type
# 5983                    undetected  ...  unable_to_process_file_type
# 6032                    undetected  ...  unable_to_process_file_type
# 6331  application.bitcoinminer.ahr  ...  unable_to_process_file_type
# 6883                    undetected  ...  unable_to_process_file_type
# 6942                    undetected  ...  unable_to_process_file_type
# 7203                    undetected  ...  unable_to_process_file_type
# 7289                    undetected  ...  unable_to_process_file_type
# 7301                    undetected  ...  unable_to_process_file_type
# 7696                    undetected  ...  unable_to_process_file_type
# 7977                    undetected  ...  unable_to_process_file_type
#
#                           Elastic           Palo Alto Networks  \
# 993   unable_to_process_file_type  unable_to_process_file_type
# 1522  unable_to_process_file_type  unable_to_process_file_type
# 1656  unable_to_process_file_type  unable_to_process_file_type
# 1885  unable_to_process_file_type  unable_to_process_file_type
# 2012  unable_to_process_file_type  unable_to_process_file_type
# 2183  unable_to_process_file_type  unable_to_process_file_type
# 2806  unable_to_process_file_type  unable_to_process_file_type
# 2816  unable_to_process_file_type  unable_to_process_file_type
# 3114  unable_to_process_file_type  unable_to_process_file_type
# 3201  unable_to_process_file_type  unable_to_process_file_type
# 3378                   virustotal  unable_to_process_file_type
# 3497  unable_to_process_file_type  unable_to_process_file_type
# 3690  unable_to_process_file_type  unable_to_process_file_type
# 3774  unable_to_process_file_type  unable_to_process_file_type
# 4188  unable_to_process_file_type  unable_to_process_file_type
# 4285  unable_to_process_file_type  unable_to_process_file_type
# 4532  unable_to_process_file_type  unable_to_process_file_type
# 4715  unable_to_process_file_type  unable_to_process_file_type
# 4778  unable_to_process_file_type  unable_to_process_file_type
# 5117  unable_to_process_file_type  unable_to_process_file_type
# 5209  unable_to_process_file_type  unable_to_process_file_type
# 5460  unable_to_process_file_type  unable_to_process_file_type
# 5605  unable_to_process_file_type  unable_to_process_file_type
# 5983  unable_to_process_file_type  unable_to_process_file_type
# 6032  unable_to_process_file_type  unable_to_process_file_type
# 6331  unable_to_process_file_type  unable_to_process_file_type
# 6883  unable_to_process_file_type  unable_to_process_file_type
# 6942  unable_to_process_file_type  unable_to_process_file_type
# 7203  unable_to_process_file_type  unable_to_process_file_type
# 7289  unable_to_process_file_type  unable_to_process_file_type
# 7301  unable_to_process_file_type  unable_to_process_file_type
# 7696  unable_to_process_file_type  unable_to_process_file_type
# 7977  unable_to_process_file_type  unable_to_process_file_type
#
#                    SecureAge APEX      SentinelOne (Static ML)  \
# 993   unable_to_process_file_type  unable_to_process_file_type
# 1522  unable_to_process_file_type  unable_to_process_file_type
# 1656  unable_to_process_file_type  unable_to_process_file_type
# 1885  unable_to_process_file_type  unable_to_process_file_type
# 2012  unable_to_process_file_type  unable_to_process_file_type
# 2183  unable_to_process_file_type  unable_to_process_file_type
# 2806  unable_to_process_file_type  unable_to_process_file_type
# 2816  unable_to_process_file_type  unable_to_process_file_type
# 3114  unable_to_process_file_type  unable_to_process_file_type
# 3201  unable_to_process_file_type  unable_to_process_file_type
# 3378  unable_to_process_file_type  unable_to_process_file_type
# 3497  unable_to_process_file_type  unable_to_process_file_type
# 3690  unable_to_process_file_type  unable_to_process_file_type
# 3774  unable_to_process_file_type  unable_to_process_file_type
# 4188  unable_to_process_file_type  unable_to_process_file_type
# 4285  unable_to_process_file_type  unable_to_process_file_type
# 4532  unable_to_process_file_type  unable_to_process_file_type
# 4715  unable_to_process_file_type  unable_to_process_file_type
# 4778  unable_to_process_file_type  unable_to_process_file_type
# 5117  unable_to_process_file_type  unable_to_process_file_type
# 5209  unable_to_process_file_type  unable_to_process_file_type
# 5460  unable_to_process_file_type  unable_to_process_file_type
# 5605  unable_to_process_file_type  unable_to_process_file_type
# 5983  unable_to_process_file_type  unable_to_process_file_type
# 6032  unable_to_process_file_type  unable_to_process_file_type
# 6331  unable_to_process_file_type  unable_to_process_file_type
# 6883  unable_to_process_file_type  unable_to_process_file_type
# 6942  unable_to_process_file_type  unable_to_process_file_type
# 7203  unable_to_process_file_type  unable_to_process_file_type
# 7289  unable_to_process_file_type  unable_to_process_file_type
# 7301  unable_to_process_file_type  unable_to_process_file_type
# 7696  unable_to_process_file_type  unable_to_process_file_type
# 7977  unable_to_process_file_type  unable_to_process_file_type
#
#           Symantec Mobile Insight                      TEHTRIS  \
# 993   unable_to_process_file_type  unable_to_process_file_type
# 1522  unable_to_process_file_type  unable_to_process_file_type
# 1656  unable_to_process_file_type  unable_to_process_file_type
# 1885  unable_to_process_file_type  unable_to_process_file_type
# 2012  unable_to_process_file_type  unable_to_process_file_type
# 2183  unable_to_process_file_type  unable_to_process_file_type
# 2806  unable_to_process_file_type  unable_to_process_file_type
# 2816  unable_to_process_file_type  unable_to_process_file_type
# 3114  unable_to_process_file_type  unable_to_process_file_type
# 3201  unable_to_process_file_type  unable_to_process_file_type
# 3378  unable_to_process_file_type  unable_to_process_file_type
# 3497  unable_to_process_file_type  unable_to_process_file_type
# 3690  unable_to_process_file_type  unable_to_process_file_type
# 3774  unable_to_process_file_type  unable_to_process_file_type
# 4188  unable_to_process_file_type  unable_to_process_file_type
# 4285  unable_to_process_file_type  unable_to_process_file_type
# 4532  unable_to_process_file_type  unable_to_process_file_type
# 4715  unable_to_process_file_type                          NaN
# 4778  unable_to_process_file_type  unable_to_process_file_type
# 5117  unable_to_process_file_type  unable_to_process_file_type
# 5209  unable_to_process_file_type                          NaN
# 5460  unable_to_process_file_type  unable_to_process_file_type
# 5605  unable_to_process_file_type  unable_to_process_file_type
# 5983  unable_to_process_file_type                          NaN
# 6032  unable_to_process_file_type  unable_to_process_file_type
# 6331  unable_to_process_file_type  unable_to_process_file_type
# 6883  unable_to_process_file_type  unable_to_process_file_type
# 6942  unable_to_process_file_type  unable_to_process_file_type
# 7203  unable_to_process_file_type  unable_to_process_file_type
# 7289  unable_to_process_file_type  unable_to_process_file_type
# 7301  unable_to_process_file_type  unable_to_process_file_type
# 7696  unable_to_process_file_type  unable_to_process_file_type
# 7977  unable_to_process_file_type  unable_to_process_file_type
#
#                          Trapmine                    Trustlook  \
# 993   unable_to_process_file_type  unable_to_process_file_type
# 1522  unable_to_process_file_type  unable_to_process_file_type
# 1656  unable_to_process_file_type  unable_to_process_file_type
# 1885  unable_to_process_file_type  unable_to_process_file_type
# 2012  unable_to_process_file_type  unable_to_process_file_type
# 2183  unable_to_process_file_type  unable_to_process_file_type
# 2806  unable_to_process_file_type  unable_to_process_file_type
# 2816  unable_to_process_file_type  unable_to_process_file_type
# 3114  unable_to_process_file_type  unable_to_process_file_type
# 3201  unable_to_process_file_type  unable_to_process_file_type
# 3378  unable_to_process_file_type  unable_to_process_file_type
# 3497  unable_to_process_file_type  unable_to_process_file_type
# 3690  unable_to_process_file_type  unable_to_process_file_type
# 3774  unable_to_process_file_type  unable_to_process_file_type
# 4188  unable_to_process_file_type  unable_to_process_file_type
# 4285  unable_to_process_file_type  unable_to_process_file_type
# 4532  unable_to_process_file_type  unable_to_process_file_type
# 4715                          NaN  unable_to_process_file_type
# 4778  unable_to_process_file_type  unable_to_process_file_type
# 5117  unable_to_process_file_type  unable_to_process_file_type
# 5209                          NaN  unable_to_process_file_type
# 5460  unable_to_process_file_type  unable_to_process_file_type
# 5605  unable_to_process_file_type  unable_to_process_file_type
# 5983                          NaN  unable_to_process_file_type
# 6032  unable_to_process_file_type  unable_to_process_file_type
# 6331  unable_to_process_file_type  unable_to_process_file_type
# 6883  unable_to_process_file_type  unable_to_process_file_type
# 6942  unable_to_process_file_type  unable_to_process_file_type
# 7203  unable_to_process_file_type  unable_to_process_file_type
# 7289  unable_to_process_file_type  unable_to_process_file_type
# 7301  unable_to_process_file_type  unable_to_process_file_type
# 7696  unable_to_process_file_type  unable_to_process_file_type
# 7977  unable_to_process_file_type  unable_to_process_file_type
#
#                           Webroot
# 993   unable_to_process_file_type
# 1522  unable_to_process_file_type
# 1656  unable_to_process_file_type
# 1885  unable_to_process_file_type
# 2012  unable_to_process_file_type
# 2183  unable_to_process_file_type
# 2806  unable_to_process_file_type
# 2816  unable_to_process_file_type
# 3114  unable_to_process_file_type
# 3201  unable_to_process_file_type
# 3378  unable_to_process_file_type
# 3497  unable_to_process_file_type
# 3690  unable_to_process_file_type
# 3774  unable_to_process_file_type
# 4188  unable_to_process_file_type
# 4285  unable_to_process_file_type
# 4532  unable_to_process_file_type
# 4715  unable_to_process_file_type
# 4778  unable_to_process_file_type
# 5117  unable_to_process_file_type
# 5209  unable_to_process_file_type
# 5460  unable_to_process_file_type
# 5605  unable_to_process_file_type
# 5983  unable_to_process_file_type
# 6032  unable_to_process_file_type
# 6331  unable_to_process_file_type
# 6883  unable_to_process_file_type
# 6942  unable_to_process_file_type
# 7203  unable_to_process_file_type
# 7289  unable_to_process_file_type
# 7301  unable_to_process_file_type
# 7696  unable_to_process_file_type
# 7977  unable_to_process_file_type
#
# [33 rows x 78 columns]

# %%
mal.to_csv("mal.csv")

# %%
# Get the files for the argo workflow
import os
C = 0
try:
    os.mkdir("mal")
except Exception as e:
    print(e)
    
import shutil

files = []
for row in mal.iloc:
    id = row['id']
    if os.path.exists(f"../RQ1/filtered-binaries-metadata_2/filtered/{id}"):
        shutil.copyfile(f"../RQ1/filtered-binaries-metadata_2/filtered/{id}", f"mal/{id}")
        files.append(id)
        print(f"- {{ file: \"{id}\" }}")
        C += 1
print(C)
# Out:
# [Errno 17] File exists: 'mal'
# 0

# %%
# Get work progress
import pandas as pd
import os
import re
from datetime import datetime

engines_re = r"(\d+)\n/ (\d+)"
# 2022-08-21 11:03:25 UTC
time_re = r"Size\n(\d\d\d\d)-(\d\d)-(\d\d) (\d\d):(\d\d):(\d\d) UTC"
# ai Score=74
MAX_ai_score = r"ai Score=(\d+)"


oracles = [
    # Add all oracles here
    'Acronis (Static ML)',
    'Ad-Aware',
    'AhnLab-V3',
    'ALYac',
    'Antiy-AVL',
    'Arcabit',
    'Avast',
    'Avira (no cloud)',
    'Baidu',
    'BitDefender',
    'BitDefenderTheta',
    'Bkav Pro',
    'ClamAV',
    'Comodo',
    'Cynet',
    'Cyren',
    'DrWeb',
    'EmsisoftAcronis (Static ML)',
    'Ad-Aware',
    'AhnLab-V3',
    'ALYac',
    'Antiy-AVL',
    'Arcabit',
    'Avast',
    'Avira (no cloud)',
    'Baidu',
    'BitDefender',
    'BitDefenderTheta',
    'Bkav Pro',
    'ClamAV',
    'Comodo',
    'Cynet',
    'Cyren',
    'DrWeb',
    'Emsisoft',
    'eScan',
    'ESET-NOD32',
    'F-Secure',
    'Fortinet',
    'GData',
    'Google',
    'Gridinsoft (no cloud)',
    'Ikarus',
    'Jiangmin',
    'K7AntiVirus',
    'K7GW',
    'Kaspersky',
    'Kingsoft',
    'Lionic',
    'Malwarebytes',
    'MAX',
    'McAfee',
    'McAfee-GW-Edition',
    'Microsoft',
    'NANO-Antivirus',
    'Panda',
    'QuickHeal',
    'Rising',
    'Sangfor Engine Zero',
    'Sophos',
    'SUPERAntiSpyware',
    'Symantec',
    'TACHYON',
    'Tencent',
    'Trellix (FireEye)',
    'TrendMicro',
    'TrendMicro-HouseCall',
    'VBA32',
    'VIPRE',
    'VirIT',
    'ViRobot',
    'Yandex',
    'Zillya',
    'ZoneAlarm by Check Point',
    'Zoner',
    'MaxSecure',
    'Alibaba',
    'Avast-Mobile',
    'BitDefenderFalx',
    'CrowdStrike Falcon',
    'Cybereason',
    'Cylance',
    'Elastic',
    'Palo Alto Networks',
    'SecureAge APEX',
    'SentinelOne (Static ML)',
    'Symantec Mobile Insight',
    'TEHTRIS',
    'Trapmine',
    'Trustlook',
    'Webroot',
    'eScan',
    'ESET-NOD32',
    'F-Secure',
    'Fortinet',
    'GData',
    'Google',
    'Gridinsoft (no cloud)',
    'Ikarus',
    'Jiangmin',
    'K7AntiVirus',
    'K7GW',
    'Kaspersky',
    'Kingsoft',
    'Lionic',
    'Malwarebytes',
    'MAX',
    'McAfee',
    'McAfee-GW-Edition',
    'Microsoft',
    'NANO-Antivirus',
    'Panda',
    'QuickHeal',
    'Rising',
    'Sangfor Engine Zero',
    'Sophos',
    'SUPERAntiSpyware',
    'Symantec',
    'TACHYON',
    'Tencent',
    'Trellix (FireEye)',
    'TrendMicro',
    'TrendMicro-HouseCall',
    'VBA32',
    'VIPRE',
    'VirIT',
    'ViRobot',
    'Yandex',
    'Zillya',
    'ZoneAlarm by Check Point',
    'Zoner',
    'MaxSecure',
    'Alibaba',
    'Avast-Mobile',
    'BitDefenderFalx',
    'CrowdStrike Falcon',
    'Cybereason',
    'Cylance',
    'Elastic',
    'Palo Alto Networks',
    'SecureAge APEX',
    'SentinelOne (Static ML)',
    'Symantec Mobile Insight',
    'TEHTRIS',
    'Trapmine',
    'Trustlook',
    'Webroot'
]

import time
import subprocess
import re
from datetime import datetime

r = re.compile(r"\[.*?\]")
meta_cache = {
    
}

import os

#if os.path.exists("meta.json"):
#    import json
#    meta_cache = json.loads(open("meta.json", "r").read())

def get_from_file(f, pref = "../files_reward/"):
    # The first line is the date
    d = open(f, "r").read().split("\n")[0]
    d = d.replace("DATE: ", "")
    d = datetime.strptime(d, "%Y-%m-%d %H:%M:%S.%f")
    return d, f

def parse_result(resultfile, details={}, mutation_log_in = lambda x: x):
    # Check if the result file is in the mutationlogs file
    
    
    #print(resultfile)
    #chunks = resultfile.split("/")
    #hash_ = chunks[-1]
    #print(chunks[1], chunks[2], hash_)
    
    #raise Exception(1)
    lines = open(resultfile, "r").read()

    start = False
    oracle = None
    result = None
    results = []
    find = re.findall(engines_re, lines)
    detected = 0
    all_find = 0
    ai_score = 0
    if find:
        detected = int(find[0][0])
        all_find = int(find[0][1])

    # find date
    #date = re.findall(time_re, lines)
    #if date:
    #    print(date, lines)
    #    date = date[0]
    #    date = datetime(int(date[0]), int(date[1]), int(date[2]), int(date[3]), int(date[4]), int(date[5]))
    #else:
    #    print(resultfile)
    date, orig_date = get_from_file(resultfile)

    aiscore_re = re.findall(MAX_ai_score, lines)
    if aiscore_re:
        #print(aiscore_re)
        ai_score = int(aiscore_re[0])
    lines = open(resultfile, "r").readlines()
    for i, l in enumerate(lines):
        if not l:
            continue
        l = l.strip()

        if l in oracles:
            # check next line
            result = lines[i + 1]
            result = result.replace("\n", "")
            if result and result not in oracles:
                results.append((l,result))
            else:
                # then it is unknown
                results.append((l,"no_response"))

        
    # check for this hsh in the details collected so far
    hsh = os.path.basename(resultfile).replace(".logs.txt", "")
    hsh = hsh.replace(".wasm", "")
    
    first_submission_date = None
    last_submission_date = None
    last_analysis_date = None
    
    if hsh in details:
        f = details[hsh]
        # parse
        # First Submission
        # 2022-09-08 08:29:31 UTC
        # Last Submission
        # 2022-09-08 08:29:31 UTC
        # Last Analysis
        # 2022-09-08 08:29:31 UTC
        content = open(f"{f}", "r").read()
        content = content.split("\n")
        content = [line for line in content if line]

        for i, l in enumerate(content):
            if "First Submission" in l:
                first_submission_date = content[i + 1]
            if "Last Submission" in l:
                last_submission_date = content[i + 1]
            if "Last Analysis" in l:
                last_analysis_date = content[i + 1]
       
    #print(len(results), results)
    print(date)
    frame = pd.DataFrame(
        # slugify the value
        {
            'id': [os.path.basename(resultfile).replace(".logs.txt", "")],
            'non_benign': [detected],
            'engines': [all_find],
            'aiscore':  [ai_score],
            'date': [date],
            'date_str': [orig_date],
            'first_submission_date': [first_submission_date],
            'last_submission_date': [last_submission_date],
            'last_analysis_date': [last_analysis_date],
            **{ k: [v.lower().replace(" ", "_")] for k, v in results }
        }
    )
    # return as pandas ?
    return frame, date

def load_progress(folder, details={}):
    files = os.listdir(folder)
    files = [f for f in files if f.endswith(".logs.txt")]
    
    # Load each one and parse it
    alldf = pd.DataFrame()
    for f in files:
        f, _ = parse_result(f"{folder}/{f}", details)
        alldf = pd.concat([alldf, f], axis=0)
        
    return alldf

folders = [
    f'../tmp_bck2/{f}' for f in files if os.path.exists(f"../tmp_bck2/{f}")
]
    
print(folders)
#progress1 = load_progress(folders[0])

#display(progress1)
# Out:
# []

# %%
seeds = [
    '1_', '2_', '3_', '4_', '5_', '6_', '7_', '8_', '9_', '10_'
]


# read details folder
details = {}
for path, dirs, f2 in os.walk("../oracles/vt_custom_chrome/out"):
    for f in f2:
        if f.endswith("details.txt"):
            details[f.replace(".details.txt", "")] = f"{path}/{f}"

print(len(details))
            
print(files)
progress  = []
container_folder = "../files_reward/"
count = 0
for folder in files:
    progresses = []
    newf = folder
    for seed in seeds:
        nfolder = f"{container_folder}{seed}{folder}"
        print(nfolder)
        if os.path.exists(nfolder):
            # todo, make somekind of cache here
            progresses.append(
                load_progress(nfolder, details)
            )
            count += len(os.listdir(nfolder))
    progress.append((newf, progresses))

print(count)
# Out:
# 9959
# []
# 0

# %%
import matplotlib.pyplot as plt
#plt.rcParams['figure.figsize'] = [20, 240]
import math
import numpy as np


def plot_progress(alldf, legends, ax, title="", xaxis="", yaxis="", plot_detectors=True, 
                  mode='normal', pluk_size=50, initial={}, shift=0, multiple_per_ax=0):
    
    
    
    if mode == 'normal':
        markers = ['-o', '--.', '-+', '--x', '--v', '-3', '--s', '-d', '-*']
        
        colors = ['C0', 'C1', 'C2', 'C3', 'C4', 'C5']
        for i, (df, leg) in enumerate(zip(alldf, legends)):
            df['date'] = pd.to_datetime(df['date'])
            df = df.sort_values(['date'])
            # df = df[df['engines'] >= 58]
            # display(df)
            # If date is Nat, set the creation of the file as it
            #x = [] #range(len(df['date'].values))
            # x = df['date'].values
            # display(df)
            y = df['non_benign'].values
            
            finaly = []
            
            pluk = []
            pluks = []
            
            for p in y:
                pluk.append(p)
                
                if len(pluk) == pluk_size:
                    pluks.append(pluk)
                    pluk = []
            
            if len(pluk) > 0:
                pluks.append(pluk)
                
            print(title, i, pluks, df['engines'].values)
            
            errors = []
            
            
            for p in pluks:
                errors.append([min(p), max(p)])
                
            finaly = [  min(p) for p in pluks]
            
            if title in initial:
                finaly = [initial[title]] + finaly
                
            # TODO, replace by the number of oracle calls instead of  number of iterations
            x = [o*pluk_size for o in  range(len(finaly))]
            print(finaly)
            # package 11 by 11
            
            zeros = df[df['non_benign'] == 0]
            
            if multiple_per_ax > 0:
                
                x = [o*pluk_size + i*multiple_per_ax for o in  range(len(finaly))]
                ax.plot(
                    x,
                    finaly,
                    f'{markers[(i + shift)%len(markers)]}',
                    color=colors[(i + shift)%len(colors)],
                    #label=title,
                    alpha=0.3,
                    label=leg
                )
                # ax.set_xticks(np.arange(0, multiple_per_ax*len(alldf), 1.0))
                ax.set_xticklabels([f"{p -i*multiple_per_ax}" for p in x ])
            else:
                ax.plot(
                    x,
                    finaly,
                    f'{markers[(i + shift)%len(markers)]}',
                    color=colors[(i + shift)%len(colors)],
                    #label=title,
                    alpha=0.3,
                    label=leg
                )

            
            #
            #ax.set_xticks(np.arange(0, 500, 1.0)) # 500 is the max daily permitted by VT
            ax.set_yticks(np.arange(0, max(finaly)+1, 1.0))
            if plot_detectors:
                for i, row in enumerate(df.iloc):
                    columns = df.columns
                    detected = []
                    for c, cname in zip(row, columns):
                        if cname not in ['id', 'date', 'aiscore', 'non_benign', 'engines']:
                            if c not in ['undetected', 'timeout', 'unable_to_process_file_type', 'virustotal']:
                                # add the text to the plot
                                detected.append((cname, c))
                    if len(detected) <= 3:
                        #for d in detected:
                        #    print(d)
                        ax.text(i, row['non_benign'], "\n".join([d[0] for d in detected]), rotation=45, ha='right')


        ax.set_title(f"{title}", fontsize=16)
        ax.set_ylim(0)
        ax.set_xlim(0)
        ax.set_xlabel("Iteration number", fontsize=16)
        ax.set_ylabel("Number of detectors", fontsize=16)
        ax.tick_params(axis='x', labelsize=14)
        ax.tick_params(axis='y', labelsize=14)
        ax.legend()
        
    if mode == 'area':
        sort = []
        for d in alldf:
            sort.append(d.sort_values('date'))
            
        non_count = []
        for d in sort:
            non_count.append(d['non_benign'].values)
            
        mins = []
        maxs = []
        
        for i in range(0, 1000):
            # get the max of all curves
            mx = -10
            mn = 70
            for n in non_count:
                if i < len(n):
                    if mx < n[i]:
                        mx = n[i]
                    if mn > n[i]:
                        mn = n[i]
                        
            if mx != -10:
                maxs.append(mx)
            if mn != 70:
                mins.append(mn)
            
            
        if len(maxs) > len(mins):
            mins += maxs[len(mins) - 1:]
        if len(mins) > len(maxs):
            maxs += mins[len(maxs) - 1:]
            
        ax.fill_between(range(len(mins)), maxs, mins,interpolate=True)
        ax.plot(range(len(mins)), mins, color='C0')
        ax.plot(range(len(maxs)), maxs, color='C0')
        ax.set_ylim(0)
        ax.set_xlim(0)
            # check if the curve has points here
    
    
#plot_progress(progress1)

# %%
# filter folders to fbdd1efa
#folders1 = [ f for f in folders if f.startswith("fbdd1efa") ]
fig, axs = plt.subplots(nrows=len(folders))    
plt.rcParams['figure.figsize'] = [20, 410]

i = 0
initials = {
    #"0d996462": 19
}
for (f, alldfs), ax in zip(progress, axs):
    #if "0d99" in f:
    plot_progress(alldfs, [f"seed {s}" for s in seeds], ax, title=f.replace(".wasm", "")[:8], 
                  plot_detectors=False, mode='normal',  pluk_size=1, initial = initials, multiple_per_ax=0)
    print()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [11], in <cell line: 3>()
#       1 # filter folders to fbdd1efa
#       2 #folders1 = [ f for f in folders if f.startswith("fbdd1efa") ]
# ----> 3 fig, axs = plt.subplots(nrows=len(folders))
#       4 plt.rcParams['figure.figsize'] = [20, 410]
#       6 i = 0
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:1435, in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1302 """
#    1303 Create a figure and a set of subplots.
#    1304
#    (...)
#    1432
#    1433 """
#    1434 fig = figure(**fig_kw)
# -> 1435 axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1436                    squeeze=squeeze, subplot_kw=subplot_kw,
#    1437                    gridspec_kw=gridspec_kw)
#    1438 return fig, axs
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/figure.py:896, in FigureBase.subplots(self, nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw)
#     894 if gridspec_kw is None:
#     895     gridspec_kw = {}
# --> 896 gs = self.add_gridspec(nrows, ncols, figure=self, **gridspec_kw)
#     897 axs = gs.subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
#     898                   subplot_kw=subplot_kw)
#     899 return axs
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/figure.py:1395, in FigureBase.add_gridspec(self, nrows, ncols, **kwargs)
#    1356 """
#    1357 Return a `.GridSpec` that has this figure as a parent.  This allows
#    1358 complex layout of Axes in the figure.
#    (...)
#    1391
#    1392 """
#    1394 _ = kwargs.pop('figure', None)  # pop in case user has added this...
# -> 1395 gs = GridSpec(nrows=nrows, ncols=ncols, figure=self, **kwargs)
#    1396 self._gridspecs.append(gs)
#    1397 return gs
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/gridspec.py:385, in GridSpec.__init__(self, nrows, ncols, figure, left, bottom, right, top, wspace, hspace, width_ratios, height_ratios)
#     382 self.hspace = hspace
#     383 self.figure = figure
# --> 385 super().__init__(nrows, ncols,
#     386                  width_ratios=width_ratios,
#     387                  height_ratios=height_ratios)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/gridspec.py:49, in GridSpecBase.__init__(self, nrows, ncols, height_ratios, width_ratios)
#      34 """
#      35 Parameters
#      36 ----------
#    (...)
#      46     If not given, all rows will have the same height.
#      47 """
#      48 if not isinstance(nrows, Integral) or nrows <= 0:
# ---> 49     raise ValueError(
#      50         f"Number of rows must be a positive integer, not {nrows!r}")
#      51 if not isinstance(ncols, Integral) or ncols <= 0:
#      52     raise ValueError(
#      53         f"Number of columns must be a positive integer, not {ncols!r}")
#
# ValueError: Number of rows must be a positive integer, not 0

# %%
import numpy as np

def get_random_search_info(f, alldf, ground):
    # return min, max, medium,  number of success runs (with zero detection at the end), number of runs
    
    finished = {
        'wasm': [],
        'seed': [],
        'finished_len': [],
        'type': [],
        'initial_detectors': []
    }
    
    ground_row = ground[ground['id'] == f]
    
    increased_detection = 0
    total_count_of_rows = 0
    breaking_oracle = 0
    pass_ = 0
    non_pass = 0
    
    for i, d in enumerate(alldf):
        d = d.sort_values("date")
        #d = d[d['engines'] >= 58]
        #display(d)
        total_count_of_rows += len(d)
        breaking_oracle += len(d[d['non_benign'] == 0])
        vals = d.iloc[-1]['non_benign']
        #print(vals)
        if vals == 0:
            finished['wasm'].append(f)
            finished['seed'].append(i)
            finished['finished_len'].append(len(d))
            finished['type'].append('pass')
            pass_ += 1
        else:
            finished['wasm'].append(f)
            finished['seed'].append(i)
            finished['finished_len'].append(len(d))
            finished['type'].append("non_pass")
            
            non_pass += 1
            
        # Get this from the ground dataset
        # display(ground_row)
        finished['initial_detectors'].append(ground_row.iloc[0]['non_benign'])
        # Check if at some point we have more detected than initial
        for row in d.iloc:
            if row['non_benign'] > ground_row.iloc[0]['non_benign']:
                #print(f, i, row['id'])
                # locate these ones
                increased_detection += 1
                # TODO, save all the binaries as a database, this could help us for time evaluation
                # TODO print the detection engines, it can be just random noise
        
        
    
    
    info = pd.DataFrame(finished)
    
    if len(info[info['type'] == 'pass']) > 0:
        print(f, "Breaking with", len(info[info['type'] == 'pass']), "seeds")
    
        sumup = pd.DataFrame({
            'hash': [info.iloc[0]['wasm']],
            'initial_detectors': [ground_row.iloc[0]['non_benign']],
            'max': [max(info[info['type'] == 'pass']['finished_len'].values)],
            'min': [min(info[info['type'] == 'pass']['finished_len'].values)],
            'avg': [np.median(info[info['type'] == 'pass']['finished_len'].values)],
            'mean': [np.mean(info[info['type'] == 'pass']['finished_len'].values)],
            'increased_detection': [increased_detection],
            'generated_files': [total_count_of_rows],
            'breaking_oracle': [breaking_oracle],
            'pass': [pass_],
            'non_pass': [non_pass],
            'ratio': [len(info[info['type'] == 'pass'])/(len(alldf))],
        })
    else:
        print(f, "Non breaking")
        sumup = pd.DataFrame({
            'hash': [info.iloc[0]['wasm']],
            'initial_detectors': [ground_row.iloc[0]['non_benign']],
            'increased_detection': [increased_detection],
            'generated_files': [total_count_of_rows],
            'breaking_oracle': [breaking_oracle],
            'pass': [pass_],
            'non_pass': [non_pass],
            'ratio': [0],
        })
        
    return info, sumup
        
all_ = pd.DataFrame()
for f, alldfs in progress:
    print(f)
    
    try:
        info, suma = get_random_search_info(f, alldfs, vt_benchmark)
        all_ = pd.concat([all_, suma], axis=0)
    except:
        pass

#all_ = all_.reset_index()
all_.reset_index(drop=True, inplace=True)


all_["hash"] = all_["hash"].map(lambda x: x[:8])
display(all_)
all_.to_csv("RQ2.csv")

# %%
all_ = pd.read_csv("RQ2.csv")
all_ = all_.sort_values(["initial_detectors"], ascending=False)
all_ = all_.drop(["min", "max", "generated_files", "increased_detection", "breaking_oracle", "avg"], axis=1)




print(all_.to_latex())

print(sum(all_['pass']))
print(sum(all_['non_pass']))
# Out:
# \begin{tabular}{lrlrrrrr}
# \toprule
# {} &  Unnamed: 0 &      hash &  initial\_detectors &  pass &  non\_pass &  ratio &   mean \\
# \midrule
# 16 &          16 &  47d29959 &                 31 &     0 &         1 &    0.0 &    NaN \\
# 1  &           1 &  dc11d82d &                 20 &     0 &         1 &    0.0 &    NaN \\
# 0  &           0 &  0d996462 &                 19 &     0 &         1 &    0.0 &    NaN \\
# 6  &           6 &  d2141ff2 &                  9 &     0 &         1 &    0.0 &    NaN \\
# 19 &          19 &  643116ff &                  6 &     0 &         1 &    0.0 &    NaN \\
# 13 &          13 &  046dc081 &                  6 &     0 &         1 &    0.0 &    NaN \\
# 12 &          12 &  aafff587 &                  6 &     0 &         1 &    0.0 &    NaN \\
# 21 &          21 &  7c36f462 &                  4 &     0 &         1 &    0.0 &    NaN \\
# 4  &           4 &  fb15929f &                  4 &     0 &         1 &    0.0 &    NaN \\
# 2  &           2 &  942be4f7 &                  4 &     1 &         0 &    1.0 &  177.0 \\
# 18 &          18 &  24aae13a &                  4 &     0 &         1 &    0.0 &    NaN \\
# 17 &          17 &  000415b2 &                  3 &     0 &         1 &    0.0 &    NaN \\
# 11 &          11 &  4cbdbbb1 &                  3 &     1 &         0 &    1.0 &  189.0 \\
# 7  &           7 &  a27b45ef &                  2 &     1 &         0 &    1.0 &  126.0 \\
# 22 &          22 &  a74a7cb8 &                  2 &     1 &         0 &    1.0 &  126.0 \\
# 20 &          20 &  89a3645c &                  2 &     0 &         1 &    0.0 &    NaN \\
# 3  &           3 &  5bc53343 &                  2 &     1 &         0 &    1.0 &  130.0 \\
# 8  &           8 &  6b8c7899 &                  2 &     0 &         1 &    0.0 &    NaN \\
# 15 &          15 &  65debcbe &                  2 &     0 &         1 &    0.0 &    NaN \\
# 14 &          14 &  59955b4c &                  2 &     1 &         0 &    1.0 &  126.0 \\
# 5  &           5 &  f0b24409 &                  2 &     1 &         0 &    1.0 &  126.0 \\
# 10 &          10 &  089dd312 &                  2 &     1 &         0 &    1.0 &   35.0 \\
# 9  &           9 &  c1be4071 &                  2 &     1 &         0 &    1.0 &  126.0 \\
# 24 &          24 &  119c53eb &                  2 &     0 &         1 &    0.0 &    NaN \\
# 23 &          23 &  e09c32c5 &                  1 &     0 &         1 &    0.0 &    NaN \\
# \bottomrule
# \end{tabular}
#
# 9
# 16
# /var/folders/gq/b9tbk2vx1qg57m7c4rkrdzv40000gn/T/ipykernel_13852/2147183714.py:8: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(all_.to_latex())

# %%
plt.rcParams['figure.figsize'] = [10, 10]

all_["multivariant"] = all_['hash'].map(lambda x: any([f in x for f in ["0d996462", "d2141ff2", "046dc081", "a32a6f4b", "fbdd1efa"]]))
display(all_)
multivariant = all_[all_['multivariant'] == True]

# separate multivariants
r =  plt.scatter(
    [ v for v in multivariant['initial_detectors'].values],
    multivariant['ratio'].values
)


single = all_[all_['multivariant'] == False]

# separate multivariants
r =  plt.scatter(
    [ v for v in single['initial_detectors'].values],
    single['ratio'].values
)


# The number of initial detectors is not determinant in the number of needed steps
# maybe a rewarded strategy is not needed
# Out:
#     Unnamed: 0      hash  initial_detectors  pass  non_pass  ratio   mean  \
# 16          16  47d29959                 31     0         1    0.0    NaN
# 1            1  dc11d82d                 20     0         1    0.0    NaN
# 0            0  0d996462                 19     0         1    0.0    NaN
# 6            6  d2141ff2                  9     0         1    0.0    NaN
# 19          19  643116ff                  6     0         1    0.0    NaN
# 13          13  046dc081                  6     0         1    0.0    NaN
# 12          12  aafff587                  6     0         1    0.0    NaN
# 21          21  7c36f462                  4     0         1    0.0    NaN
# 4            4  fb15929f                  4     0         1    0.0    NaN
# 2            2  942be4f7                  4     1         0    1.0  177.0
# 18          18  24aae13a                  4     0         1    0.0    NaN
# 17          17  000415b2                  3     0         1    0.0    NaN
# 11          11  4cbdbbb1                  3     1         0    1.0  189.0
# 7            7  a27b45ef                  2     1         0    1.0  126.0
# 22          22  a74a7cb8                  2     1         0    1.0  126.0
# 20          20  89a3645c                  2     0         1    0.0    NaN
# 3            3  5bc53343                  2     1         0    1.0  130.0
# 8            8  6b8c7899                  2     0         1    0.0    NaN
# 15          15  65debcbe                  2     0         1    0.0    NaN
# 14          14  59955b4c                  2     1         0    1.0  126.0
# 5            5  f0b24409                  2     1         0    1.0  126.0
# 10          10  089dd312                  2     1         0    1.0   35.0
# 9            9  c1be4071                  2     1         0    1.0  126.0
# 24          24  119c53eb                  2     0         1    0.0    NaN
# 23          23  e09c32c5                  1     0         1    0.0    NaN
#
#     multivariant
# 16         False
# 1          False
# 0           True
# 6           True
# 19         False
# 13          True
# 12         False
# 21         False
# 4          False
# 2          False
# 18         False
# 17         False
# 11         False
# 7          False
# 22         False
# 20         False
# 3          False
# 8          False
# 15         False
# 14         False
# 5          False
# 10         False
# 9          False
# 24         False
# 23         False

# %%
# Group all by similarity
same = pd.read_csv("cluster0.5.folder.1.csv")
display(same)

# Do a graph clustering
# Out:
#                                                      id  cluster  url
# 0     000415b2639c960e039299fde2a52e7e9c692c212c1fa6...        0  NaN
# 1     006b2fb61de05aa4fec89f479ce45b6295c6080d6ec4bd...        1  NaN
# 2     000415b2639c960e039299fde2a52e7e9c692c212c1fa6...        2  NaN
# 3     046dc081076d9cea6831967619b862cc80fa8c23813464...        3  NaN
# 4     000415b2639c960e039299fde2a52e7e9c692c212c1fa6...        4  NaN
# ...                                                 ...      ...  ...
# 1555  koko_046dc081076d9cea6831967619b862cc80fa8c238...     1507  NaN
# 1556  koko_dc11d82d85b5745ff2c69e901b9b6b42da9e1c102...     1508  NaN
# 1557  koko_7d3842e649ba37f94545fd6e194cc4f7298d4970e...     1509  NaN
# 1558  koko_dc11d82d85b5745ff2c69e901b9b6b42da9e1c102...     1510  NaN
# 1559  koko_a9c5637d37fd606c1567243a71b2866dd536e1e82...     1511  NaN
#
# [1560 rows x 3 columns]

# %%
import networkx as nx
import matplotlib.pyplot as plt

clusters = {}
nodes = []
info = []
labels = {}

for row in same.iloc:
    cluster = row['cluster']
    
    if cluster not in clusters:
        clusters[cluster] = []
        
for row in same.iloc:
    cluster = row['cluster']
    id = f"{row['id']}"
    if id not in nodes:
        nodes.append(id)
        info.append(row['url'])
        idx = len(nodes) - 1
        labels[idx] = id
    else:
        idx = nodes.index(id)
    clusters[cluster].append(idx)
    
print(clusters, nodes)
G = nx.Graph()
for c in clusters:
    nodes2 = clusters[c]
    for n in nodes2:
        for n2 in nodes2:
            if n != n2:
                
                G.add_edge(n, n2)
                
print(G)
# Out:
# {0: [0], 1: [1], 2: [0], 3: [2], 4: [0], 5: [3], 6: [0], 7: [4], 8: [0], 9: [5], 10: [0, 6], 11: [0], 12: [7], 13: [0], 14: [8], 15: [0], 16: [9], 17: [0], 18: [10], 19: [0], 20: [11], 21: [0], 22: [12], 23: [0], 24: [13], 25: [0], 26: [14], 27: [0], 28: [15], 29: [0], 30: [16], 31: [0], 32: [17], 33: [0], 34: [18], 35: [0], 36: [19], 37: [0], 38: [20], 39: [0], 40: [21], 41: [1], 42: [2], 43: [1], 44: [4], 45: [1], 46: [6], 47: [1], 48: [8], 49: [1], 50: [9], 51: [1], 52: [10], 53: [1], 54: [11], 55: [1], 56: [12], 57: [1], 58: [13], 59: [1], 60: [15], 61: [1], 62: [16], 63: [1], 64: [18], 65: [1], 66: [19], 67: [1], 68: [20], 69: [1], 70: [21], 71: [2], 72: [9], 73: [2], 74: [10], 75: [2], 76: [13], 77: [2], 78: [15], 79: [2], 80: [21], 81: [22], 82: [0], 83: [22], 84: [1], 85: [22], 86: [2], 87: [22], 88: [3], 89: [22], 90: [4], 91: [22], 92: [5], 93: [22], 94: [6], 95: [22], 96: [7], 97: [22], 98: [8], 99: [22], 100: [9], 101: [22], 102: [23], 103: [22], 104: [10], 105: [22], 106: [11], 107: [22], 108: [12], 109: [22], 110: [13], 111: [22], 112: [14], 113: [22], 114: [15], 115: [22], 116: [24], 117: [22], 118: [16], 119: [22], 120: [25], 121: [22], 122: [17], 123: [22], 124: [18], 125: [22], 126: [19], 127: [22], 128: [20], 129: [22], 130: [21], 131: [22], 132: [26], 133: [3], 134: [1], 135: [3, 2], 136: [3], 137: [4], 138: [3], 139: [6], 140: [3], 141: [8], 142: [3], 143: [9], 144: [3], 145: [10], 146: [3], 147: [11], 148: [3], 149: [12], 150: [3], 151: [13], 152: [3], 153: [14], 154: [3], 155: [15], 156: [3], 157: [16], 158: [3], 159: [18], 160: [3, 19], 161: [3], 162: [20], 163: [3], 164: [21], 165: [4], 166: [2], 167: [4], 168: [9], 169: [4], 170: [10], 171: [4], 172: [13], 173: [4], 174: [15], 175: [4], 176: [21], 177: [5], 178: [1], 179: [5], 180: [2], 181: [5], 182: [3], 183: [5], 184: [4], 185: [5], 186: [6], 187: [5], 188: [7], 189: [5], 190: [8], 191: [5], 192: [9], 193: [5], 194: [10], 195: [5], 196: [11], 197: [5], 198: [12], 199: [5], 200: [13], 201: [5], 202: [14], 203: [5], 204: [15], 205: [5], 206: [16], 207: [5], 208: [17], 209: [5], 210: [18], 211: [5], 212: [19], 213: [5], 214: [20], 215: [5], 216: [21], 217: [6], 218: [2], 219: [6], 220: [4], 221: [6], 222: [8], 223: [6], 224: [9], 225: [6], 226: [10], 227: [6], 228: [11], 229: [6], 230: [13], 231: [6], 232: [15], 233: [6], 234: [16], 235: [6], 236: [18], 237: [6], 238: [19], 239: [6], 240: [20], 241: [6], 242: [21], 243: [7], 244: [1], 245: [7], 246: [2], 247: [7], 248: [3], 249: [7], 250: [4], 251: [7], 252: [6], 253: [7], 254: [8], 255: [7], 256: [9], 257: [7], 258: [10], 259: [7], 260: [11], 261: [7], 262: [12], 263: [7], 264: [13], 265: [7], 266: [14], 267: [7], 268: [15], 269: [7], 270: [16], 271: [7], 272: [17], 273: [7], 274: [18], 275: [7], 276: [19], 277: [7], 278: [20], 279: [7], 280: [21], 281: [8], 282: [2], 283: [8], 284: [4], 285: [8], 286: [9], 287: [8], 288: [10], 289: [8], 290: [13], 291: [8], 292: [15], 293: [8], 294: [19], 295: [8], 296: [20], 297: [8], 298: [21], 299: [27], 300: [0], 301: [27], 302: [1], 303: [27], 304: [2], 305: [27], 306: [22], 307: [27], 308: [3], 309: [27], 310: [4], 311: [27], 312: [5], 313: [27], 314: [6], 315: [27], 316: [7], 317: [27], 318: [8], 319: [27, 9], 320: [27], 321: [23], 322: [27, 10], 323: [27, 11], 324: [27], 325: [12], 326: [27], 327: [13], 328: [27], 329: [28], 330: [27], 331: [29], 332: [27, 30], 333: [27], 334: [14], 335: [27, 15], 336: [27], 337: [24], 338: [27], 339: [31], 340: [27], 341: [16], 342: [27], 343: [25], 344: [27, 17], 345: [27], 346: [18], 347: [27], 348: [19], 349: [27], 350: [32], 351: [27], 352: [20], 353: [27], 354: [33], 355: [27], 356: [21], 357: [27], 358: [26], 359: [9, 10], 360: [9], 361: [13], 362: [9, 15], 363: [9], 364: [21], 365: [23], 366: [0], 367: [23], 368: [1], 369: [23], 370: [2], 371: [23], 372: [3], 373: [23], 374: [4], 375: [23], 376: [5], 377: [23], 378: [6], 379: [23], 380: [7], 381: [23], 382: [8], 383: [23], 384: [9], 385: [23], 386: [10], 387: [23], 3 ...
# Graph with 22 nodes and 48 edges

# %%
# Get pods and beta from stdout

import subprocess
import re

def get_pods(workname):
    r = subprocess.check_output([
        "argo",
        "get",
        workname
    ])
    
    r = r.decode()
    r = r.split("\n")
    # Filter out failed works
    
    r = [ l for l in r if all( x not in l for x in ['◷', '✖'] ) ]
    r = "\n".join(r)
    
    r = r.split("STEP")[1]
    
    files = r.split("select-file")
    
    result = []
    for f in files[1:]:
        print(f)
    
        re1 = re.compile(r"\(\d+:file:(.*?)\)")
        wasm = re1.findall(f)[0]

        re2 = re.compile(r"select-oracle\(\d+:beta:(\d+\.\d+),oracle:(\w+),peek:(\d+),seed:(\d+)\)")
        re3 = re.compile(f"({workname}-(.*?)) \d")
        betas = re2.findall(f)
        betas = [[x[0], x[2]] for x in betas]
        pods = re3.findall(f)
        pods = [p[0].strip() for p in pods]
        print(pods)
        #peeks = ["1"]*len(pod)
        #assert len(pods) == len(betas)
        print(wasm, betas, pods)
    
        k = [
            wasm,
            [[x, *y] for x,y in (zip(pods, betas))]
        ]
        result.append(k)
    return result
    
get_pods("reward-mutate-33-968kh")
# Out:
# (0:file:9d30e7f065cd00a47d8e10e27acc443a33977176484ca11077f08fc20b1a672c.wasm)  reward-mutate
#    │ └─┬─● select-oracle(0:beta:0.01,oracle:reward_5,peek:1,seed:4)                               select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-840345692   27m
#    │   ├─● select-oracle(1:beta:1.1,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-4280802684  27m
#    │   └─● select-oracle(2:beta:0.3,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │     └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-2460285818  27m
#    ├─●
# ['reward-mutate-33-968kh-840345692', 'reward-mutate-33-968kh-4280802684', 'reward-mutate-33-968kh-2460285818']
# 9d30e7f065cd00a47d8e10e27acc443a33977176484ca11077f08fc20b1a672c.wasm [['0.01', '1'], ['1.1', '1'], ['0.3', '1']] ['reward-mutate-33-968kh-840345692', 'reward-mutate-33-968kh-4280802684', 'reward-mutate-33-968kh-2460285818']
# (1:file:dceaf65bf86d2de5bc460eef3b3c858ccdc82f478469752555e95c749324e7e2.wasm)  reward-mutate
#    │ └─┬─● select-oracle(0:beta:0.01,oracle:reward_5,peek:1,seed:4)                               select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-136836731   27m
#    │   ├─● select-oracle(1:beta:1.1,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-3532019049  27m
#    │   └─● select-oracle(2:beta:0.3,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │     └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-516647919   27m
#    ├─●
# ['reward-mutate-33-968kh-136836731', 'reward-mutate-33-968kh-3532019049', 'reward-mutate-33-968kh-516647919']
# dceaf65bf86d2de5bc460eef3b3c858ccdc82f478469752555e95c749324e7e2.wasm [['0.01', '1'], ['1.1', '1'], ['0.3', '1']] ['reward-mutate-33-968kh-136836731', 'reward-mutate-33-968kh-3532019049', 'reward-mutate-33-968kh-516647919']
# (2:file:006b2fb61de05aa4fec89f479ce45b6295c6080d6ec4bd919059c39fa2b93b31.wasm)  reward-mutate
#    │ └─┬─● select-oracle(0:beta:0.01,oracle:reward_5,peek:1,seed:4)                               select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-2401812702  27m
#    │   ├─● select-oracle(1:beta:1.1,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-1908891922  27m
#    │   └─● select-oracle(2:beta:0.3,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │     └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-2917977520  27m
#    ├─●
# ['reward-mutate-33-968kh-2401812702', 'reward-mutate-33-968kh-1908891922', 'reward-mutate-33-968kh-2917977520']
# 006b2fb61de05aa4fec89f479ce45b6295c6080d6ec4bd919059c39fa2b93b31.wasm [['0.01', '1'], ['1.1', '1'], ['0.3', '1']] ['reward-mutate-33-968kh-2401812702', 'reward-mutate-33-968kh-1908891922', 'reward-mutate-33-968kh-2917977520']
# (3:file:942be4f7a78a50453f8949a0a20e1ae66a5b84a67db712fab66d3a9541087519.wasm)  reward-mutate
#    │ └─┬─● select-oracle(0:beta:0.01,oracle:reward_5,peek:1,seed:4)                               select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-4100076971  27m
#    │   ├─● select-oracle(1:beta:1.1,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-3418303961  27m
#    │   └─● select-oracle(2:beta:0.3,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │     └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-421157215   27m
#    ├─●
# ['reward-mutate-33-968kh-4100076971', 'reward-mutate-33-968kh-3418303961', 'reward-mutate-33-968kh-421157215']
# 942be4f7a78a50453f8949a0a20e1ae66a5b84a67db712fab66d3a9541087519.wasm [['0.01', '1'], ['1.1', '1'], ['0.3', '1']] ['reward-mutate-33-968kh-4100076971', 'reward-mutate-33-968kh-3418303961', 'reward-mutate-33-968kh-421157215']
# (4:file:5bc5334382f650c8a7cc38d651b86db06eb755b64662eaef42c6040cf879f0ce.wasm)  reward-mutate
#    │ └─┬─● select-oracle(0:beta:0.01,oracle:reward_5,peek:1,seed:4)                               select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-260104925   27m
#    │   ├─● select-oracle(1:beta:1.1,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-2598918591  27m
#    │   └─● select-oracle(2:beta:0.3,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │     └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-884393005   27m
#    ├─●
# ['reward-mutate-33-968kh-260104925', 'reward-mutate-33-968kh-2598918591', 'reward-mutate-33-968kh-884393005']
# 5bc5334382f650c8a7cc38d651b86db06eb755b64662eaef42c6040cf879f0ce.wasm [['0.01', '1'], ['1.1', '1'], ['0.3', '1']] ['reward-mutate-33-968kh-260104925', 'reward-mutate-33-968kh-2598918591', 'reward-mutate-33-968kh-884393005']
# (5:file:fb15929fb454d62f2dbabb306d9b73b3b1fe4526e6b4a76a7a23519273c6c519.wasm)  reward-mutate
#    │ └─┬─● select-oracle(0:beta:0.01,oracle:reward_5,peek:1,seed:4)                               select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-4059756803  27m
#    │   ├─● select-oracle(1:beta:1.1,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-3150224673  27m
#    │   └─● select-oracle(2:beta:0.3,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │     └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-3743323463  27m
#    ├─●
# ['reward-mutate-33-968kh-4059756803', 'reward-mutate-33-968kh-3150224673', 'reward-mutate-33-968kh-3743323463']
# fb15929fb454d62f2dbabb306d9b73b3b1fe4526e6b4a76a7a23519273c6c519.wasm [['0.01', '1'], ['1.1', '1'], ['0.3', '1']] ['reward-mutate-33-968kh-4059756803', 'reward-mutate-33-968kh-3150224673', 'reward-mutate-33-968kh-3743323463']
# (6:file:f0b244090f9e4a9f599a68f42d7a89e003026202324cf86c6cd4a46ad8c98da8.wasm)  reward-mutate
#    │ └─┬─● select-oracle(0:beta:0.01,oracle:reward_5,peek:1,seed:4)                               select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-2780701272  27m
#    │   ├─● select-oracle(1:beta:1.1,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-2801644976  27m
#    │   └─● select-oracle(2:beta:0.3,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │     └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-2246938222  27m
#    ├─●
# ['reward-mutate-33-968kh-2780701272', 'reward-mutate-33-968kh-2801644976', 'reward-mutate-33-968kh-2246938222']
# f0b244090f9e4a9f599a68f42d7a89e003026202324cf86c6cd4a46ad8c98da8.wasm [['0.01', '1'], ['1.1', '1'], ['0.3', '1']] ['reward-mutate-33-968kh-2780701272', 'reward-mutate-33-968kh-2801644976', 'reward-mutate-33-968kh-2246938222']
# (7:file:d2141ff28b1c81a90177319d3f4ddc17ab5c493d165be73a4af7256474a4ed58.wasm)  reward-mutate
#    │ └─┬─● select-oracle(0:beta:0.01,oracle:reward_5,peek:1,seed:4)                               select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-1600289999  27m
#    │   ├─● select-oracle(1:beta:1.1,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-859359669   27m
#    │   └─● select-oracle(2:beta:0.3,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │     └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-1504021467  27m
#    └─●
# ['reward-mutate-33-968kh-1600289999', 'reward-mutate-33-968kh-859359669', 'reward-mutate-33-968kh-1504021467']
# d2141ff28b1c81a90177319d3f4ddc17ab5c493d165be73a4af7256474a4ed58.wasm [['0.01', '1'], ['1.1', '1'], ['0.3', '1']] ['reward-mutate-33-968kh-1600289999', 'reward-mutate-33-968kh-859359669', 'reward-mutate-33-968kh-1504021467']
# (8:file:a27b45ef89b961b8c8ff78b6ab580ce0d866647c3ae03c4ab0f37ba15c433f8f.wasm)  reward-mutate
#      └───● select-oracle(0:beta:0.01,oracle:reward_5,peek:1,seed:4)                               select-oracle-template
#          └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-3892150460  27m
#
# This workflow does not have security context set. You can run your workflow pods more securely by setting it.
# Learn more at https://argoproj.github.io/argo-workflows/workflow-pod-security-context/
#
# ['reward-mutate-33-968kh-3892150460']
# a27b45ef89b961b8c8ff78b6ab580ce0d866647c3ae03c4ab0f37ba15c433f8f.wasm [['0.01', '1']] ['reward-mutate-33-968kh-3892150460']
# [['9d30e7f065cd00a47d8e10e27acc443a33977176484ca11077f08fc20b1a672c.wasm',
#   [['reward-mutate-33-968kh-840345692', '0.01', '1'],
#    ['reward-mutate-33-968kh-4280802684', '1.1', '1'],
#    ['reward-mutate-33-968kh-2460285818', '0.3', '1']]],
#  ['dceaf65bf86d2de5bc460eef3b3c858ccdc82f478469752555e95c749324e7e2.wasm',
#   [['reward-mutate-33-968kh-136836731', '0.01', '1'],
#    ['reward-mutate-33-968kh-3532019049', '1.1', '1'],
#    ['reward-mutate-33-968kh-516647919', '0.3', '1']]],
#  ['006b2fb61de05aa4fec89f479ce45b6295c6080d6ec4bd919059c39fa2b93b31.wasm',
#   [['reward-mutate-33-968kh-2401812702', '0.01', '1'],
#    ['reward-mutate-33-968kh-1908891922', '1.1', '1'],
#    ['reward-mutate-33-968kh-2917977520', '0.3', '1']]],
#  ['942be4f7a78a50453f8949a0a20e1ae66a5b84a67db712fab66d3a9541087519.wasm',
#   [['reward-mutate-33-968kh-4100076971', '0.01', '1'],
#    ['reward-mutate-33-968kh-3418303961', '1.1', '1'],
#    ['reward-mutate-33-968kh-421157215', '0.3', '1']]],
#  ['5bc5334382f650c8a7cc38d651b86db06eb755b64662eaef42c6040cf879f0ce.wasm',
#   [['reward-mutate-33-968kh-260104925', '0.01', '1'],
#    ['reward-mutate-33-968kh-2598918591', '1.1', '1'],
#    ['reward-mutate-33-968kh-884393005', '0.3', '1']]],
#  ['fb15929fb454d62f2dbabb306d9b73b3b1fe4526e6b4a76a7a23519273c6c519.wasm',
#   [['reward-mutate-33-968kh-4059756803', '0.01', '1'],
#    ['reward-mutate-33-968kh-3150224673', '1.1', '1'],
#    ['reward-mutate-33-968kh-3743323463', '0.3', '1']]],
#  ['f0b244090f9e4a9f599a68f42d7a89e003026202324cf86c6cd4a46ad8c98da8.wasm',
#   [['reward-mutate-33-968kh-2780701272', '0.01', '1'],
#    ['reward-mutate-33-968kh-2801644976', '1.1', '1'],
#    ['reward-mutate-33-968kh-2246938222', '0.3', '1']]],
#  ['d2141ff28b1c81a90177319d3f4ddc17ab5c493d165be73a4af7256474a4ed58.wasm',
#   [['reward-mutate-33-968kh-1600289999', '0.01', '1'],
#    ['reward-mutate-33-968kh-859359669', '1.1', '1'],
#    ['reward-mutate-33-968kh-1504021467', '0.3', '1']]],
#  ['a27b45ef89b961b8c8ff78b6ab580ce0d866647c3ae03c4ab0f37ba15c433f8f.wasm',
#   [['reward-mutate-33-968kh-3892150460', '0.01', '1']]]]

# %%
# Read progress from pod
plt.rcParams['figure.figsize'] = [15, 13]

import time

while True:
    
    import subprocess
    pods = get_pods("reward-mutate-33-968kh")

    WHITELIST = ['undetected', 'timeout', 'unable_to_process_file_type', 'no_response']

    VENDORS_WEIGHT = {'ZoneAlarm by Check Point': 13, 'Kaspersky': 13, 'Ikarus': 8, 'Google': 8, 'Emsisoft': 6, 'eScan': 6, 'VIPRE': 6, 'Ad-Aware': 6, 'ALYac': 6, 'MAX': 6, 'BitDefender': 6, 'Arcabit': 6, 'Sangfor Engine Zero': 5, 'McAfee': 3, 'McAfee-GW-Edition': 3, 'Symantec': 3, 'TrendMicro-HouseCall': 2, 'TrendMicro': 2, 'Zillya': 1, 'Sophos': 1, 'Fortinet': 1, 'Kingsoft': 1, 'Zoner': 1, 'ESET-NOD32': 1, 'VirIT': 1, 'Lionic': 1, 'Microsoft': 1, 'Jiangmin': 1, 'MaxSecure': 1, 'ClamAV': 1, 'VBA32': 1, 'ViRobot': 1, 'Antiy-AVL': 1, 'DrWeb': 1, 'Rising': 1, 'K7AntiVirus': 1, 'F-Secure': 1, 'Gridinsoft (no cloud)': 1, 'Yandex': 1, 'Comodo': 1, 'TACHYON': 1, 'Cynet': 1, 'K7GW': 1, 'Malwarebytes': 1, 'Avira (no cloud)': 1, 'Tencent': 1, 'NANO-Antivirus': 1, 'QuickHeal': 1, 'AhnLab-V3': 1, 'Bkav Pro': 1, 'SUPERAntiSpyware': 1, 'Avast': 1, 'Baidu': 1, 'Panda': 1, 'Cyren': 1, 'Acronis (Static ML)': 1, 'BitDefenderTheta': 1}
    MAX = 0

    for k in VENDORS_WEIGHT:
        MAX += VENDORS_WEIGHT[k]

    # patch for only counting 
    # MAX=60
    print("MAX", MAX)
    print(pods)
    from io import StringIO

    CS = [
        'C0', 'C1', 'C2', 'C3'
    ]
    for f, podnames  in pods:
        acceptances = []
        rejections = []
        ratios =[]
        xs = []
        last = {

        }
        fig, axs = plt.subplots(2)
        ax1, ax3 = axs

        ax2 = ax1.twinx()

        ax1.set_title(f)
        ax2.set_title(f)
        ax3.set_title(f)

        H = 0
        for j, (pod, beta, peek) in enumerate(podnames):
            H += 1
            try:
                r = subprocess.check_output([
                    "kubectl",
                    "logs",
                    pod,
                    "main"
                ])
            except Exception as e:
                print(e)
                continue

            r = r.decode()
            cont = r
            lines = r.split("\n")

            resilience = [

            ]
            oracle_calls = []
            rewards = []
            acceptance = 0
            rejection = 0
            pass_ = []
            currents = []
            for i, l in enumerate(lines):
                try:
                    if "non_benign" in l:
                        # get the number of passed in the next line

                        next_ = lines[i + 1]
                        # parse this and the next as csv
                        csv = f"{l}\n{next_}"
                        df = pd.read_csv(StringIO(csv), sep=",")

                        next_ = next_.split(",")
                        n = int(next_[2])

                        bin_res = []
                        for k in VENDORS_WEIGHT:
                            if k in df.iloc[0]:
                                if df.iloc[0][k] not in WHITELIST:
                                    bin_res.append(f"{k} {df.iloc[0][k]}")

                        resilience.append(bin_res)

                        pass_.append(n)
                    elif "!sterr" in l:
                        nl = l.replace("!sterr ", "")
                        nl = nl.replace("'", "")
                        oracle_calls.append(1)
                        rewards.append(int(nl))

                    elif "Accepting" in l: #or "Rejecting" in l:
                        acceptance += 1
                        # next line is important
                        next_ = lines[i + 1]
                        next_ = next_.split("|")

                        # print(next_, l)
                        call = int(next_[1])
                        reward = int(next_[2])
                        current = next_[5]

                        oracle_calls.append(call)
                        rewards.append(reward)
                        currents.append(current)

                        if beta not in last:
                            last[beta] = []
                        if acceptance + rejection > 0:
                            last[beta].append(acceptance/(acceptance + rejection))

                    elif "Rejecting" in l:
                        rejection += 1

                        if beta not in last:
                            last[beta] = []
                        if acceptance + rejection > 0:
                            last[beta].append(acceptance/(acceptance + rejection))
                    elif "BINGO" in l:
                        prev = lines[i - 1]
                        prev = prev.replace("stderr ", "")
                        prev = eval(prev)
                        prev = bytes(prev)
                        prev = prev.decode()
                        prev = int(prev)


                        pass_.append(MAX-prev)
                        oracle_calls.append(oracle_calls[-1] + 1)
                        rewards.append(prev)

                except Exception as e:
                    print(e)

            ax1.plot(oracle_calls, rewards, '--o', label=f"b:{beta} p:{peek}", alpha=0.1)
            #for o in oracle_calls:
            #    ax1.vlines(o, ymin=0, ymax=MAX, alpha=0.1)
            ax1.legend()
            ax2.plot(list(range(len(pass_))), pass_, '-o',  label=f"b:{beta} p:{peek}", alpha=0.1)
            #ax2.legend()
            ax2.set_ylim(0)

            bars = ax3.bar(
                [x for x in list(range(len(resilience)))],
                [ len(x)  for x in resilience ],
                label=f"b:{beta} p:{peek}",
                alpha=0.1,
                edgecolor=CS[j%len(CS)]
            )
            ax3.legend()

            for r, rect in zip(resilience, bars):
                if len(r) < 0:
                    height = rect.get_height()
                    t = "\n".join(r)
                    print()
                    print(t)
                    ax3.text(rect.get_x() + 10*(H - 1) + rect.get_width() / 2.0, height, f'{t}', ha='center', va='bottom', fontsize=7)

            try:
                print("Reward", rewards[-1], "Concrete transformations", len(rewards))
            except:
                pass
            print(beta, acceptance, rejection)
            if len(rewards) > 0:
                print("Rem", rewards[-1])
            acceptances.append(acceptance)
            rejections.append(rejection)


            # Save data for later
            data = json.dumps(dict( acceptances=acceptances, 
                                                          rejections=rejections, rewards=rewards, pending=pass_, oracle_callls=oracle_calls, current=currents ), indent=4)
            
            # if previous
            if not os.path.exists(f"logs/{f}.{beta}.{pod}.data.reward.json"):
                open(f"logs/{f}.{beta}.{pod}.data.reward.json", 'w').write(data)
            else:
                # replace only if better
                c = open(f"logs/{f}.{beta}.{pod}.data.reward.json", 'r').read()
                if len(c) < len(data):
                    open(f"logs/{f}.{beta}.{pod}.data.reward.json", 'w').write(data)
                    open(f"logs/{f}.{beta}.{pod}.logs.reward.txt", 'w').write(cont)

        plt.tight_layout()
        plt.legend()
        plt.show()
        plt.title(f)
        for k, items in last.items():
            plt.plot(
                list(range(len(items))),
                items,
                '--o',
                alpha=0.2,
                label=k
            )

        plt.legend()
        plt.show()
            #print(r)
   
        
    time.sleep(300)
# Out:
# (0:file:9d30e7f065cd00a47d8e10e27acc443a33977176484ca11077f08fc20b1a672c.wasm)  reward-mutate
#    │ └─┬─● select-oracle(0:beta:0.01,oracle:reward_5,peek:1,seed:4)                               select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-840345692   16h
#    │   ├─● select-oracle(1:beta:1.1,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-4280802684  16h
#    │   └─● select-oracle(2:beta:0.3,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │     └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-2460285818  16h
#    ├─●
# ['reward-mutate-33-968kh-840345692', 'reward-mutate-33-968kh-4280802684', 'reward-mutate-33-968kh-2460285818']
# 9d30e7f065cd00a47d8e10e27acc443a33977176484ca11077f08fc20b1a672c.wasm [['0.01', '1'], ['1.1', '1'], ['0.3', '1']] ['reward-mutate-33-968kh-840345692', 'reward-mutate-33-968kh-4280802684', 'reward-mutate-33-968kh-2460285818']
# (1:file:dceaf65bf86d2de5bc460eef3b3c858ccdc82f478469752555e95c749324e7e2.wasm)  reward-mutate
#    │ └─┬─● select-oracle(0:beta:0.01,oracle:reward_5,peek:1,seed:4)                               select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-136836731   16h
#    │   ├─● select-oracle(1:beta:1.1,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-3532019049  16h
#    │   └─● select-oracle(2:beta:0.3,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │     └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-516647919   16h
#    ├─●
# ['reward-mutate-33-968kh-136836731', 'reward-mutate-33-968kh-3532019049', 'reward-mutate-33-968kh-516647919']
# dceaf65bf86d2de5bc460eef3b3c858ccdc82f478469752555e95c749324e7e2.wasm [['0.01', '1'], ['1.1', '1'], ['0.3', '1']] ['reward-mutate-33-968kh-136836731', 'reward-mutate-33-968kh-3532019049', 'reward-mutate-33-968kh-516647919']
# (2:file:006b2fb61de05aa4fec89f479ce45b6295c6080d6ec4bd919059c39fa2b93b31.wasm)  reward-mutate
#    │ └─┬─● select-oracle(0:beta:0.01,oracle:reward_5,peek:1,seed:4)                               select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-2401812702  16h
#    │   ├─● select-oracle(1:beta:1.1,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-1908891922  16h
#    │   └─● select-oracle(2:beta:0.3,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │     └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-2917977520  16h
#    ├─●
# ['reward-mutate-33-968kh-2401812702', 'reward-mutate-33-968kh-1908891922', 'reward-mutate-33-968kh-2917977520']
# 006b2fb61de05aa4fec89f479ce45b6295c6080d6ec4bd919059c39fa2b93b31.wasm [['0.01', '1'], ['1.1', '1'], ['0.3', '1']] ['reward-mutate-33-968kh-2401812702', 'reward-mutate-33-968kh-1908891922', 'reward-mutate-33-968kh-2917977520']
# (3:file:942be4f7a78a50453f8949a0a20e1ae66a5b84a67db712fab66d3a9541087519.wasm)  reward-mutate
#    │ └─┬─● select-oracle(0:beta:0.01,oracle:reward_5,peek:1,seed:4)                               select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-4100076971  16h
#    │   ├─● select-oracle(1:beta:1.1,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-3418303961  16h
#    │   └─● select-oracle(2:beta:0.3,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │     └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-421157215   16h
#    ├─●
# ['reward-mutate-33-968kh-4100076971', 'reward-mutate-33-968kh-3418303961', 'reward-mutate-33-968kh-421157215']
# 942be4f7a78a50453f8949a0a20e1ae66a5b84a67db712fab66d3a9541087519.wasm [['0.01', '1'], ['1.1', '1'], ['0.3', '1']] ['reward-mutate-33-968kh-4100076971', 'reward-mutate-33-968kh-3418303961', 'reward-mutate-33-968kh-421157215']
# (4:file:5bc5334382f650c8a7cc38d651b86db06eb755b64662eaef42c6040cf879f0ce.wasm)  reward-mutate
#    │ └─┬─● select-oracle(0:beta:0.01,oracle:reward_5,peek:1,seed:4)                               select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-260104925   16h
#    │   ├─● select-oracle(1:beta:1.1,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-2598918591  16h
#    │   └─● select-oracle(2:beta:0.3,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │     └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)                       analyzer-template
#    │         └─● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(1)                  analyzer-template       reward-mutate-33-968kh-146324864   12h
#    ├─●
# ['reward-mutate-33-968kh-260104925', 'reward-mutate-33-968kh-2598918591', 'reward-mutate-33-968kh-146324864']
# 5bc5334382f650c8a7cc38d651b86db06eb755b64662eaef42c6040cf879f0ce.wasm [['0.01', '1'], ['1.1', '1'], ['0.3', '1']] ['reward-mutate-33-968kh-260104925', 'reward-mutate-33-968kh-2598918591', 'reward-mutate-33-968kh-146324864']
# (5:file:fb15929fb454d62f2dbabb306d9b73b3b1fe4526e6b4a76a7a23519273c6c519.wasm)  reward-mutate
#    │ └─┬─● select-oracle(0:beta:0.01,oracle:reward_5,peek:1,seed:4)                               select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-4059756803  16h
#    │   ├─● select-oracle(1:beta:1.1,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-3150224673  16h
#    │   └─● select-oracle(2:beta:0.3,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │     └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-3743323463  16h
#    ├─●
# ['reward-mutate-33-968kh-4059756803', 'reward-mutate-33-968kh-3150224673', 'reward-mutate-33-968kh-3743323463']
# fb15929fb454d62f2dbabb306d9b73b3b1fe4526e6b4a76a7a23519273c6c519.wasm [['0.01', '1'], ['1.1', '1'], ['0.3', '1']] ['reward-mutate-33-968kh-4059756803', 'reward-mutate-33-968kh-3150224673', 'reward-mutate-33-968kh-3743323463']
# (6:file:f0b244090f9e4a9f599a68f42d7a89e003026202324cf86c6cd4a46ad8c98da8.wasm)  reward-mutate
#    │ └─┬─● select-oracle(0:beta:0.01,oracle:reward_5,peek:1,seed:4)                               select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-2780701272  16h
#    │   ├─● select-oracle(1:beta:1.1,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-2801644976  16h
#    │   └─● select-oracle(2:beta:0.3,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │     └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-2246938222  16h
#    ├─●
# ['reward-mutate-33-968kh-2780701272', 'reward-mutate-33-968kh-2801644976', 'reward-mutate-33-968kh-2246938222']
# f0b244090f9e4a9f599a68f42d7a89e003026202324cf86c6cd4a46ad8c98da8.wasm [['0.01', '1'], ['1.1', '1'], ['0.3', '1']] ['reward-mutate-33-968kh-2780701272', 'reward-mutate-33-968kh-2801644976', 'reward-mutate-33-968kh-2246938222']
# (7:file:d2141ff28b1c81a90177319d3f4ddc17ab5c493d165be73a4af7256474a4ed58.wasm)  reward-mutate
#    │ └─┬─● select-oracle(0:beta:0.01,oracle:reward_5,peek:1,seed:4)                               select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-1600289999  16h
#    │   ├─● select-oracle(1:beta:1.1,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-859359669   16h
#    │   └─● select-oracle(2:beta:0.3,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │     └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-1504021467  16h
#    └─●
# ['reward-mutate-33-968kh-1600289999', 'reward-mutate-33-968kh-859359669', 'reward-mutate-33-968kh-1504021467']
# d2141ff28b1c81a90177319d3f4ddc17ab5c493d165be73a4af7256474a4ed58.wasm [['0.01', '1'], ['1.1', '1'], ['0.3', '1']] ['reward-mutate-33-968kh-1600289999', 'reward-mutate-33-968kh-859359669', 'reward-mutate-33-968kh-1504021467']
# (8:file:a27b45ef89b961b8c8ff78b6ab580ce0d866647c3ae03c4ab0f37ba15c433f8f.wasm)  reward-mutate
#      └───● select-oracle(0:beta:0.01,oracle:reward_5,peek:1,seed:4)                               select-oracle-template
#          └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-3892150460  16h
#
# This workflow does not have security context set. You can run your workflow pods more securely by setting it.
# Learn more at https://argoproj.github.io/argo-workflows/workflow-pod-security-context/
#
# ['reward-mutate-33-968kh-3892150460']
# a27b45ef89b961b8c8ff78b6ab580ce0d866647c3ae03c4ab0f37ba15c433f8f.wasm [['0.01', '1']] ['reward-mutate-33-968kh-3892150460']
# MAX 147
# [['9d30e7f065cd00a47d8e10e27acc443a33977176484ca11077f08fc20b1a672c.wasm', [['reward-mutate-33-968kh-840345692', '0.01', '1'], ['reward-mutate-33-968kh-4280802684', '1.1', '1'], ['reward-mutate-33-968kh-2460285818', '0.3', '1']]], ['dceaf65bf86d2de5bc460eef3b3c858ccdc82f478469752555e95c749324e7e2.wasm', [['reward-mutate-33-968kh-136836731', '0.01', '1'], ['reward-mutate-33-968kh-3532019049', '1.1', '1'], ['reward-mutate-33-968kh-516647919', '0.3', '1']]], ['006b2fb61de05aa4fec89f479ce45b6295c6080d6ec4bd919059c39fa2b93b31.wasm', [['reward-mutate-33-968kh-2401812702', '0.01', '1'], ['reward-mutate-33-968kh-1908891922', '1.1', '1'], ['reward-mutate-33-968kh-2917977520', '0.3', '1']]], ['942be4f7a78a50453f8949a0a20e1ae66a5b84a67db712fab66d3a9541087519.wasm', [['reward-mutate-33-968kh-4100076971', '0.01', '1'], ['reward-mutate-33-968kh-3418303961', '1.1', '1'], ['reward-mutate-33-968kh-421157215', '0.3', '1']]], ['5bc5334382f650c8a7cc38d651b86db06eb755b64662eaef42c6040cf879f0ce.wasm', [['reward-mutate-33-968kh-260104925', '0.01', '1'], ['reward-mutate-33-968kh-2598918591', '1.1', '1'], ['reward-mutate-33-968kh-146324864', '0.3', '1']]], ['fb15929fb454d62f2dbabb306d9b73b3b1fe4526e6b4a76a7a23519273c6c519.wasm', [['reward-mutate-33-968kh-4059756803', '0.01', '1'], ['reward-mutate-33-968kh-3150224673', '1.1', '1'], ['reward-mutate-33-968kh-3743323463', '0.3', '1']]], ['f0b244090f9e4a9f599a68f42d7a89e003026202324cf86c6cd4a46ad8c98da8.wasm', [['reward-mutate-33-968kh-2780701272', '0.01', '1'], ['reward-mutate-33-968kh-2801644976', '1.1', '1'], ['reward-mutate-33-968kh-2246938222', '0.3', '1']]], ['d2141ff28b1c81a90177319d3f4ddc17ab5c493d165be73a4af7256474a4ed58.wasm', [['reward-mutate-33-968kh-1600289999', '0.01', '1'], ['reward-mutate-33-968kh-859359669', '1.1', '1'], ['reward-mutate-33-968kh-1504021467', '0.3', '1']]], ['a27b45ef89b961b8c8ff78b6ab580ce0d866647c3ae03c4ab0f37ba15c433f8f.wasm', [['reward-mutate-33-968kh-3892150460', '0.01', '1']]]]
# Reward 54 Concrete transformations 5
# 0.01 4 0
# Rem 54
# Reward 107 Concrete transformations 4
# 1.1 3 26
# Rem 107
# Reward 107 Concrete transformations 4
# 0.3 3 26
# Rem 107
# Reward 131 Concrete transformations 41
# 0.01 40 0
# Rem 131
# Reward 131 Concrete transformations 41
# 1.1 40 0
# Rem 131
# Reward 131 Concrete transformations 41
# 0.3 40 0
# Rem 131
# Reward 111 Concrete transformations 3
# 0.01 2 0
# Rem 111
# Reward 127 Concrete transformations 2
# 1.1 1 21
# Rem 127
# Reward 127 Concrete transformations 2
# 0.3 1 14
# Rem 127
# Reward 131 Concrete transformations 2
# 0.01 1 0
# Rem 131
# Reward 131 Concrete transformations 2
# 1.1 1 0
# Rem 131
# Reward 131 Concrete transformations 2
# 0.3 1 0
# Rem 131
# Reward 131 Concrete transformations 22
# 0.01 21 0
# Rem 131
# list index out of range
# list index out of range
# Reward 139 Concrete transformations 16
# 1.1 16 378
# Rem 139
# list index out of range
# Reward 139 Concrete transformations 15
# 0.3 15 34
# Rem 139
# Reward 126 Concrete transformations 2
# 0.01 1 0
# Rem 126
# Reward 127 Concrete transformations 1
# 1.1 0 5
# Rem 127
# list index out of range
# Reward 126 Concrete transformations 9
# 0.3 9 1
# Rem 126
# list index out of range
# Reward 131 Concrete transformations 26
# 0.01 26 0
# Rem 131
# Reward 131 Concrete transformations 29
# 1.1 28 1
# Rem 131
# Reward 131 Concrete transformations 29
# 0.3 28 1
# Rem 131
# Reward 98 Concrete transformations 2
# 0.01 1 0
# Rem 98
# Reward 111 Concrete transformations 4
# 1.1 3 17
# Rem 111
# Reward 98 Concrete transformations 9
# 0.3 8 1
# Rem 98
# 0.01 0 0
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# (0:file:9d30e7f065cd00a47d8e10e27acc443a33977176484ca11077f08fc20b1a672c.wasm)  reward-mutate
#    │ └─┬─● select-oracle(0:beta:0.01,oracle:reward_5,peek:1,seed:4)                               select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-840345692   16h
#    │   ├─● select-oracle(1:beta:1.1,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-4280802684  16h
#    │   └─● select-oracle(2:beta:0.3,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │     └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-2460285818  16h
#    ├─●
# ['reward-mutate-33-968kh-840345692', 'reward-mutate-33-968kh-4280802684', 'reward-mutate-33-968kh-2460285818']
# 9d30e7f065cd00a47d8e10e27acc443a33977176484ca11077f08fc20b1a672c.wasm [['0.01', '1'], ['1.1', '1'], ['0.3', '1']] ['reward-mutate-33-968kh-840345692', 'reward-mutate-33-968kh-4280802684', 'reward-mutate-33-968kh-2460285818']
# (1:file:dceaf65bf86d2de5bc460eef3b3c858ccdc82f478469752555e95c749324e7e2.wasm)  reward-mutate
#    │ └─┬─● select-oracle(0:beta:0.01,oracle:reward_5,peek:1,seed:4)                               select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-136836731   16h
#    │   ├─● select-oracle(1:beta:1.1,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-3532019049  16h
#    │   └─● select-oracle(2:beta:0.3,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │     └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-516647919   16h
#    ├─●
# ['reward-mutate-33-968kh-136836731', 'reward-mutate-33-968kh-3532019049', 'reward-mutate-33-968kh-516647919']
# dceaf65bf86d2de5bc460eef3b3c858ccdc82f478469752555e95c749324e7e2.wasm [['0.01', '1'], ['1.1', '1'], ['0.3', '1']] ['reward-mutate-33-968kh-136836731', 'reward-mutate-33-968kh-3532019049', 'reward-mutate-33-968kh-516647919']
# (2:file:006b2fb61de05aa4fec89f479ce45b6295c6080d6ec4bd919059c39fa2b93b31.wasm)  reward-mutate
#    │ └─┬─● select-oracle(0:beta:0.01,oracle:reward_5,peek:1,seed:4)                               select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-2401812702  16h
#    │   ├─● select-oracle(1:beta:1.1,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-1908891922  16h
#    │   └─● select-oracle(2:beta:0.3,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │     └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-2917977520  16h
#    ├─●
# ['reward-mutate-33-968kh-2401812702', 'reward-mutate-33-968kh-1908891922', 'reward-mutate-33-968kh-2917977520']
# 006b2fb61de05aa4fec89f479ce45b6295c6080d6ec4bd919059c39fa2b93b31.wasm [['0.01', '1'], ['1.1', '1'], ['0.3', '1']] ['reward-mutate-33-968kh-2401812702', 'reward-mutate-33-968kh-1908891922', 'reward-mutate-33-968kh-2917977520']
# (3:file:942be4f7a78a50453f8949a0a20e1ae66a5b84a67db712fab66d3a9541087519.wasm)  reward-mutate
#    │ └─┬─● select-oracle(0:beta:0.01,oracle:reward_5,peek:1,seed:4)                               select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-4100076971  16h
#    │   ├─● select-oracle(1:beta:1.1,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-3418303961  16h
#    │   └─● select-oracle(2:beta:0.3,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │     └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-421157215   16h
#    ├─●
# ['reward-mutate-33-968kh-4100076971', 'reward-mutate-33-968kh-3418303961', 'reward-mutate-33-968kh-421157215']
# 942be4f7a78a50453f8949a0a20e1ae66a5b84a67db712fab66d3a9541087519.wasm [['0.01', '1'], ['1.1', '1'], ['0.3', '1']] ['reward-mutate-33-968kh-4100076971', 'reward-mutate-33-968kh-3418303961', 'reward-mutate-33-968kh-421157215']
# (4:file:5bc5334382f650c8a7cc38d651b86db06eb755b64662eaef42c6040cf879f0ce.wasm)  reward-mutate
#    │ └─┬─● select-oracle(0:beta:0.01,oracle:reward_5,peek:1,seed:4)                               select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-260104925   16h
#    │   ├─● select-oracle(1:beta:1.1,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-2598918591  16h
#    │   └─● select-oracle(2:beta:0.3,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │     └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)                       analyzer-template
#    │         └─● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(1)                  analyzer-template       reward-mutate-33-968kh-146324864   12h
#    ├─●
# ['reward-mutate-33-968kh-260104925', 'reward-mutate-33-968kh-2598918591', 'reward-mutate-33-968kh-146324864']
# 5bc5334382f650c8a7cc38d651b86db06eb755b64662eaef42c6040cf879f0ce.wasm [['0.01', '1'], ['1.1', '1'], ['0.3', '1']] ['reward-mutate-33-968kh-260104925', 'reward-mutate-33-968kh-2598918591', 'reward-mutate-33-968kh-146324864']
# (5:file:fb15929fb454d62f2dbabb306d9b73b3b1fe4526e6b4a76a7a23519273c6c519.wasm)  reward-mutate
#    │ └─┬─● select-oracle(0:beta:0.01,oracle:reward_5,peek:1,seed:4)                               select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-4059756803  16h
#    │   ├─● select-oracle(1:beta:1.1,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-3150224673  16h
#    │   └─● select-oracle(2:beta:0.3,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │     └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-3743323463  16h
#    ├─●
# ['reward-mutate-33-968kh-4059756803', 'reward-mutate-33-968kh-3150224673', 'reward-mutate-33-968kh-3743323463']
# fb15929fb454d62f2dbabb306d9b73b3b1fe4526e6b4a76a7a23519273c6c519.wasm [['0.01', '1'], ['1.1', '1'], ['0.3', '1']] ['reward-mutate-33-968kh-4059756803', 'reward-mutate-33-968kh-3150224673', 'reward-mutate-33-968kh-3743323463']
# (6:file:f0b244090f9e4a9f599a68f42d7a89e003026202324cf86c6cd4a46ad8c98da8.wasm)  reward-mutate
#    │ └─┬─● select-oracle(0:beta:0.01,oracle:reward_5,peek:1,seed:4)                               select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-2780701272  16h
#    │   ├─● select-oracle(1:beta:1.1,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-2801644976  16h
#    │   └─● select-oracle(2:beta:0.3,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │     └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-2246938222  16h
#    ├─●
# ['reward-mutate-33-968kh-2780701272', 'reward-mutate-33-968kh-2801644976', 'reward-mutate-33-968kh-2246938222']
# f0b244090f9e4a9f599a68f42d7a89e003026202324cf86c6cd4a46ad8c98da8.wasm [['0.01', '1'], ['1.1', '1'], ['0.3', '1']] ['reward-mutate-33-968kh-2780701272', 'reward-mutate-33-968kh-2801644976', 'reward-mutate-33-968kh-2246938222']
# (7:file:d2141ff28b1c81a90177319d3f4ddc17ab5c493d165be73a4af7256474a4ed58.wasm)  reward-mutate
#    │ └─┬─● select-oracle(0:beta:0.01,oracle:reward_5,peek:1,seed:4)                               select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-1600289999  16h
#    │   ├─● select-oracle(1:beta:1.1,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │   │ └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-859359669   16h
#    │   └─● select-oracle(2:beta:0.3,oracle:reward_5,peek:1,seed:4)                                select-oracle-template
#    │     └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-1504021467  16h
#    └─●
# ['reward-mutate-33-968kh-1600289999', 'reward-mutate-33-968kh-859359669', 'reward-mutate-33-968kh-1504021467']
# d2141ff28b1c81a90177319d3f4ddc17ab5c493d165be73a4af7256474a4ed58.wasm [['0.01', '1'], ['1.1', '1'], ['0.3', '1']] ['reward-mutate-33-968kh-1600289999', 'reward-mutate-33-968kh-859359669', 'reward-mutate-33-968kh-1504021467']
# (8:file:a27b45ef89b961b8c8ff78b6ab580ce0d866647c3ae03c4ab0f37ba15c433f8f.wasm)  reward-mutate
#      └───● select-oracle(0:beta:0.01,oracle:reward_5,peek:1,seed:4)                               select-oracle-template
#          └───● execute-analyzer(0:dbconn:reward_5,features:wasm-mutate/all)(0)                    analyzer-template       reward-mutate-33-968kh-3892150460  16h
#
# This workflow does not have security context set. You can run your workflow pods more securely by setting it.
# Learn more at https://argoproj.github.io/argo-workflows/workflow-pod-security-context/
#
# ['reward-mutate-33-968kh-3892150460']
# a27b45ef89b961b8c8ff78b6ab580ce0d866647c3ae03c4ab0f37ba15c433f8f.wasm [['0.01', '1']] ['reward-mutate-33-968kh-3892150460']
# MAX 147
# [['9d30e7f065cd00a47d8e10e27acc443a33977176484ca11077f08fc20b1a672c.wasm', [['reward-mutate-33-968kh-840345692', '0.01', '1'], ['reward-mutate-33-968kh-4280802684', '1.1', '1'], ['reward-mutate-33-968kh-2460285818', '0.3', '1']]], ['dceaf65bf86d2de5bc460eef3b3c858ccdc82f478469752555e95c749324e7e2.wasm', [['reward-mutate-33-968kh-136836731', '0.01', '1'], ['reward-mutate-33-968kh-3532019049', '1.1', '1'], ['reward-mutate-33-968kh-516647919', '0.3', '1']]], ['006b2fb61de05aa4fec89f479ce45b6295c6080d6ec4bd919059c39fa2b93b31.wasm', [['reward-mutate-33-968kh-2401812702', '0.01', '1'], ['reward-mutate-33-968kh-1908891922', '1.1', '1'], ['reward-mutate-33-968kh-2917977520', '0.3', '1']]], ['942be4f7a78a50453f8949a0a20e1ae66a5b84a67db712fab66d3a9541087519.wasm', [['reward-mutate-33-968kh-4100076971', '0.01', '1'], ['reward-mutate-33-968kh-3418303961', '1.1', '1'], ['reward-mutate-33-968kh-421157215', '0.3', '1']]], ['5bc5334382f650c8a7cc38d651b86db06eb755b64662eaef42c6040cf879f0ce.wasm', [['reward-mutate-33-968kh-260104925', '0.01', '1'], ['reward-mutate-33-968kh-2598918591', '1.1', '1'], ['reward-mutate-33-968kh-146324864', '0.3', '1']]], ['fb15929fb454d62f2dbabb306d9b73b3b1fe4526e6b4a76a7a23519273c6c519.wasm', [['reward-mutate-33-968kh-4059756803', '0.01', '1'], ['reward-mutate-33-968kh-3150224673', '1.1', '1'], ['reward-mutate-33-968kh-3743323463', '0.3', '1']]], ['f0b244090f9e4a9f599a68f42d7a89e003026202324cf86c6cd4a46ad8c98da8.wasm', [['reward-mutate-33-968kh-2780701272', '0.01', '1'], ['reward-mutate-33-968kh-2801644976', '1.1', '1'], ['reward-mutate-33-968kh-2246938222', '0.3', '1']]], ['d2141ff28b1c81a90177319d3f4ddc17ab5c493d165be73a4af7256474a4ed58.wasm', [['reward-mutate-33-968kh-1600289999', '0.01', '1'], ['reward-mutate-33-968kh-859359669', '1.1', '1'], ['reward-mutate-33-968kh-1504021467', '0.3', '1']]], ['a27b45ef89b961b8c8ff78b6ab580ce0d866647c3ae03c4ab0f37ba15c433f8f.wasm', [['reward-mutate-33-968kh-3892150460', '0.01', '1']]]]
# Reward 54 Concrete transformations 5
# 0.01 4 0
# Rem 54
# Reward 107 Concrete transformations 4
# 1.1 3 26
# Rem 107
# Reward 107 Concrete transformations 4
# 0.3 3 26
# Rem 107
# Reward 131 Concrete transformations 41
# 0.01 40 0
# Rem 131
# Reward 131 Concrete transformations 41
# 1.1 40 0
# Rem 131
# Reward 131 Concrete transformations 41
# 0.3 40 0
# Rem 131
# Reward 111 Concrete transformations 3
# 0.01 2 0
# Rem 111
# Reward 127 Concrete transformations 2
# 1.1 1 21
# Rem 127
# Reward 127 Concrete transformations 2
# 0.3 1 15
# Rem 127
# Reward 131 Concrete transformations 2
# 0.01 1 0
# Rem 131
# Reward 131 Concrete transformations 2
# 1.1 1 0
# Rem 131
# Reward 131 Concrete transformations 2
# 0.3 1 0
# Rem 131
# Reward 131 Concrete transformations 22
# 0.01 21 0
# Rem 131
# list index out of range
# list index out of range
# Reward 139 Concrete transformations 16
# 1.1 16 378
# Rem 139
# list index out of range
# Reward 139 Concrete transformations 15
# 0.3 15 34
# Rem 139
# Reward 126 Concrete transformations 2
# 0.01 1 0
# Rem 126
# Reward 127 Concrete transformations 1
# 1.1 0 5
# Rem 127
# list index out of range
# Reward 126 Concrete transformations 9
# 0.3 9 1
# Rem 126
# list index out of range
# Reward 131 Concrete transformations 26
# 0.01 26 0
# Rem 131
# Reward 131 Concrete transformations 29
# 1.1 28 1
# Rem 131
# Reward 131 Concrete transformations 29
# 0.3 28 1
# Rem 131
# Reward 98 Concrete transformations 2
# 0.01 1 0
# Rem 98
# Reward 111 Concrete transformations 4
# 1.1 3 17
# Rem 111
# Reward 98 Concrete transformations 9
# 0.3 8 1
# Rem 98
# 0.01 0 0
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [20], in <cell line: 8>()
#     207     plt.show()
#     208         #print(r)
# --> 211 time.sleep(300)
#
# KeyboardInterrupt:
